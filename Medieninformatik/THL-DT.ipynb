# %%
from functions import *
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import shap
from sklearn.model_selection import train_test_split
from collections import Counter

# %% [markdown]
# ## Data Preprocessing

# %%
path_1 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Dataset/THL1.csv"
path_2 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Dataset/THL2.csv"
path_3 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Dataset/THL3.csv"

THL_1 = pd.read_csv(path_1, sep=';')
THL_1.drop(columns=['Unnamed: 0'], inplace=True)
THL_2 = pd.read_csv(path_2, sep=';')
THL_2.drop(columns=['Unnamed: 0'], inplace=True)
THL_3 = pd.read_csv(path_3, sep=',')

# %%
## set modules
module1 = ['M01_1_N', 'M02_1_N', 'M03_1_N', 'M04_1_N', 'M05_1_N', 'M06_1_N']

module2 = [
            'M01_2_N', 'M02_2_N', 'M03_2_N', 'M04_2_N', 'M05_2_N', 'M06_2_N',
            'M07_2_N', 'M08_2_N', 'M09_2_N', 'M10_2_N', 'M11_2_N', 'M12_2_N',]

module3 = ['M01_3_N', 'M02_3_N', 'M03_3_N', 'M04_3_N', 'M05_3_N', 'M06_3_N',
            'M07_3_N', 'M08_3_N', 'M09_3_N', 'M10_3_N', 'M11_3_N', 'M12_3_N',
            'M13_3_N', 'M14_3_N', 'M15_3_N', 'M16_3_N', 'M17_3_N']

# %% [markdown]
# ### Train test split function

# %% [markdown]
# ### Search Space / Param Grid

# %%
from hyperopt import *
search_space = {
    'criterion': hp.choice('criterion', ['entropy']),           # Choose between Gini & Entropy
    'max_depth': hp.choice('max_depth', list(range(4, 20))),   # Either unlimited or between 3-20
    'max_features': hp.choice('max_features', ['sqrt', 'log2']),  # Feature selection method
    'class_weight': 'balanced',       # Handle class imbalance
    'ccp_alpha': hp.uniform('ccp_alpha', 0.01, 0.02),  # Regularization term (log scale, ~exp(-5) to exp(0)),
}

# %% [markdown]
# ## BHT semester 1

# %%
# Count occurrences of each unique value in the 'status' column
counter_1 = Counter(THL_1['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_1[1]} | 0: {counter_1[0]}')
hpo = ModelTrainer(random_state=42)
x, y = hpo.split_data(THL_1, module1)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 423 | 0: 54

# %%
hpo = ModelTrainer(random_state=42)
models_1, feature_importance_1 = hpo.cross_validation_hpo(x=x, y=y, search_space=search_space, folds=5, algo='dt')
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 36.34trial/s, best loss: -0.7969466393522584]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               04
# 	 actual 1            11               74
#
# Model parameters:
# {'ccp_alpha': 0.012737822244736744, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 75.34759%
# Validation accuracy.: 84.37500%
# Sensitivity score (for 1): 87.05882%
# Specificity score (for 0): 63.63636%
# F1 score.: 90.79755%
# False prediction: 15.62500%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 30.71trial/s, best loss: -0.7969307872402693]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               02
# 	 actual 1            15               70
#
# Model parameters:
# {'ccp_alpha': 0.017096710224273493, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 82.08556%
# Validation accuracy.: 82.29167%
# Sensitivity score (for 1): 82.35294%
# Specificity score (for 0): 81.81818%
# F1 score.: 89.17197%
# False prediction: 17.70833%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  8.99trial/s, best loss: -0.7866659350307288]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               02
# 	 actual 1            18               67
#
# Model parameters:
# {'ccp_alpha': 0.01973427791410548, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 79.41176%
# Validation accuracy.: 78.94737%
# Sensitivity score (for 1): 78.82353%
# Specificity score (for 0): 80.00000%
# F1 score.: 87.01299%
# False prediction: 21.05263%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.04trial/s, best loss: -0.7949443956687152]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               03
# 	 actual 1            17               67
#
# Model parameters:
# {'ccp_alpha': 0.016742809172066202, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 76.24459%
# Validation accuracy.: 78.94737%
# Sensitivity score (for 1): 79.76190%
# Specificity score (for 0): 72.72727%
# F1 score.: 87.01299%
# False prediction: 21.05263%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 11.12trial/s, best loss: -0.7536264754658081]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            10               01
# 	 actual 1            10               74
#
# Model parameters:
# {'ccp_alpha': 0.016173797382805218, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 19, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 89.50216%
# Validation accuracy.: 88.42105%
# Sensitivity score (for 1): 88.09524%
# Specificity score (for 0): 90.90909%
# F1 score.: 93.08176%
# False prediction: 11.57895%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 80.51833%
# Standard Deviation of Balanced Accuracy: +/- 5.087
#
# Mean Accuracy: 82.59649%
# Standard Deviation of Accuracy: +/- 3.572
#
# Mean Sensitivity: 83.21849%
# Standard Deviation of Sensitivity: +/- 3.756
#
# Mean Specificity: 77.81818%
# Standard Deviation of Specificity: +/- 9.156
#
# Mean False Predictions: 17.40351%
# Standard Deviation of False Predictions: +/- 3.572
# best model is from 5 fold: DecisionTreeClassifier(ccp_alpha=0.016173797382805218, class_weight='balanced',
#                        criterion='entropy', max_depth=19, max_features='log2',
#                        random_state=42)

# %%
feature_importance_1
# Out:
# <style type="text/css">
# #T_90bec_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_90bec_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 49.2%, transparent 49.2%);
# }
# #T_90bec_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 36.6%, transparent 36.6%);
# }
# #T_90bec_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 18.0%, transparent 18.0%);
# }
# #T_90bec_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 7.6%, transparent 7.6%);
# }
# #T_90bec_row5_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_90bec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90bec_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_90bec_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90bec_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_90bec_row0_col0" class="data row0 col0" >M04_1_N</td>
#       <td id="T_90bec_row0_col1" class="data row0 col1" >0.473095</td>
#     </tr>
#     <tr>
#       <th id="T_90bec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90bec_row1_col0" class="data row1 col0" >M02_1_N</td>
#       <td id="T_90bec_row1_col1" class="data row1 col1" >0.232660</td>
#     </tr>
#     <tr>
#       <th id="T_90bec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90bec_row2_col0" class="data row2 col0" >M03_1_N</td>
#       <td id="T_90bec_row2_col1" class="data row2 col1" >0.173222</td>
#     </tr>
#     <tr>
#       <th id="T_90bec_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_90bec_row3_col0" class="data row3 col0" >M01_1_N</td>
#       <td id="T_90bec_row3_col1" class="data row3 col1" >0.084985</td>
#     </tr>
#     <tr>
#       <th id="T_90bec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90bec_row4_col0" class="data row4 col0" >M05_1_N</td>
#       <td id="T_90bec_row4_col1" class="data row4 col1" >0.036037</td>
#     </tr>
#     <tr>
#       <th id="T_90bec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90bec_row5_col0" class="data row5 col0" >M06_1_N</td>
#       <td id="T_90bec_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer = shap.TreeExplainer(models_1['model'], models_1['x_train'])
shap_values = explainer(models_1['x_test'])

plt.title('Shap Feature Importance (sem1)', fontsize=16)
shap.plots.bar(shap_values[...,1])

# %%
shap.plots.violin(shap_values[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values[...,1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iGE081T2A863MYKZT6X1G'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7012140645131828, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "explanations": [{"outValue": 0.9148169864386679, "simIndex": 46.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 47.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 48.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 45.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 49.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 44.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 50.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.026009398237651804, "simIndex": 4.0, "features": {"0": {"effect": -0.10869653906673193, "value": 1.3}, "1": {"effect": -0.24980188757181168, "value": 1.0}, "2": {"effect": -0.011173411384224891, "value": 5.1}, "3": {"effect": -0.23645851030945778, "value": 1.3}, "4": {"effect": -0.06907431794330478, "value": 1.3}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 43.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9148169864386679, "simIndex": 51.0, "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.5036603325277926, "simIndex": 83.0, "features": {"0": {"effect": 0.0209989944845438, "value": 5.1}, ...

# %%
hpo.plot_shap_force(model=models_1, shap_values=shap_values, student_index=11, link='logit', model_name='dt')
# Out:
# Student index 11 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.085, Probability [1]: 0.915
# <div id='iPABYYWUBGY1IMVTKXKWI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7012140645131828, "outValue": 0.9148169864386679, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.04573691830039024, "value": 5.1}, "1": {"effect": 0.06602560792118312, "value": 5.1}, "2": {"effect": 0.036861754506826404, "value": 5.1}, "3": {"effect": 0.05216425865888596, "value": 5.1}, "4": {"effect": 0.012814382538199425, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPABYYWUBGY1IMVTKXKWI')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=24, model_name='dt', link='logit')
# Out:
# Student index 24 grades:
#          grades
# M01_1_N     2.0
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     2.3
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 0.663, Probability [1]: 0.337
# <div id='iFF5Y4IUGNCB0TRX55LUR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7012140645131828, "outValue": 0.33659491513375056, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": -0.20562031600624323, "value": 2.0}, "1": {"effect": 0.0442576951533556, "value": 5.1}, "2": {"effect": 0.00615121029317379, "value": 5.1}, "3": {"effect": -0.21009299993515015, "value": 2.3}, "4": {"effect": 0.0006852611154317856, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iFF5Y4IUGNCB0TRX55LUR')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=10, model_name='dt', link='logit')
# Out:
# Student index 10 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     1.0
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.496, Probability [1]: 0.504
# <div id='i0KNDVVBSJIAW0QM85QKA'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7012140645131828, "outValue": 0.5036603325277926, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.0209989944845438, "value": 5.1}, "1": {"effect": 0.039231900908052925, "value": 5.1}, "2": {"effect": 0.023088006526231764, "value": 5.1}, "3": {"effect": 0.03222315862774849, "value": 5.1}, "4": {"effect": -0.3130957925319672, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i0KNDVVBSJIAW0QM85QKA')
#   );
# </script>

# %% [markdown]
# ## THL semester 2

# %%
# Count occurrences of each unique value in the 'status' column
counter_2 = Counter(THL_2['status'])
print(f'Quantity of Drop Out and Degree in THL-2: \n 1: {counter_2[1]} | 0: {counter_2[0]}')

hpo2 = ModelTrainer(random_state=42)
x, y = hpo2.split_data(THL_2, module2)
# Out:
# Quantity of Drop Out and Degree in THL-2:
#  1: 256 | 0: 54

# %%
hpo2 = ModelTrainer(random_state=42)
models_2, feature_importance_2 = hpo2.cross_validation_hpo(x=x, y=y, search_space=search_space, folds=5, algo='dt')
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 29.37trial/s, best loss: -0.77130081300813]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               02
# 	 actual 1            02               50
#
# Model parameters:
# {'ccp_alpha': 0.01815760714812889, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 16, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 88.07692%
# Validation accuracy.: 93.54839%
# Sensitivity score (for 1): 96.15385%
# Specificity score (for 0): 80.00000%
# F1 score.: 96.15385%
# False prediction: 6.45161%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 16.93trial/s, best loss: -0.7862466124661246]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            02               09
# 	 actual 1            06               45
#
# Model parameters:
# {'ccp_alpha': 0.010678882000913355, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 53.20856%
# Validation accuracy.: 75.80645%
# Sensitivity score (for 1): 88.23529%
# Specificity score (for 0): 18.18182%
# F1 score.: 85.71429%
# False prediction: 24.19355%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 13.97trial/s, best loss: -0.7834688346883468]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               04
# 	 actual 1            10               41
#
# Model parameters:
# {'ccp_alpha': 0.012851599135514199, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 72.01426%
# Validation accuracy.: 77.41935%
# Sensitivity score (for 1): 80.39216%
# Specificity score (for 0): 63.63636%
# F1 score.: 85.41667%
# False prediction: 22.58065%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 15.49trial/s, best loss: -0.7934959349593494]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               03
# 	 actual 1            09               42
#
# Model parameters:
# {'ccp_alpha': 0.017219810871716472, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 77.54011%
# Validation accuracy.: 80.64516%
# Sensitivity score (for 1): 82.35294%
# Specificity score (for 0): 72.72727%
# F1 score.: 87.50000%
# False prediction: 19.35484%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 17.59trial/s, best loss: -0.7904132791327914]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               04
# 	 actual 1            04               47
#
# Model parameters:
# {'ccp_alpha': 0.012675973465562183, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 77.89661%
# Validation accuracy.: 87.09677%
# Sensitivity score (for 1): 92.15686%
# Specificity score (for 0): 63.63636%
# F1 score.: 92.15686%
# False prediction: 12.90323%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 73.74729%
# Standard Deviation of Balanced Accuracy: +/- 11.505
#
# Mean Accuracy: 82.90323%
# Standard Deviation of Accuracy: +/- 6.579
#
# Mean Sensitivity: 87.85822%
# Standard Deviation of Sensitivity: +/- 5.890
#
# Mean Specificity: 59.63636%
# Standard Deviation of Specificity: +/- 21.617
#
# Mean False Predictions: 17.09677%
# Standard Deviation of False Predictions: +/- 6.579
# best model is from 1 fold: DecisionTreeClassifier(ccp_alpha=0.01815760714812889, class_weight='balanced',
#                        criterion='entropy', max_depth=16, max_features='log2',
#                        random_state=42)

# %%
feature_importance_2
# Out:
# <style type="text/css">
# #T_4b8b5_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_4b8b5_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 75.7%, transparent 75.7%);
# }
# #T_4b8b5_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 51.1%, transparent 51.1%);
# }
# #T_4b8b5_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 42.5%, transparent 42.5%);
# }
# #T_4b8b5_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 28.6%, transparent 28.6%);
# }
# #T_4b8b5_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.0%, transparent 21.0%);
# }
# #T_4b8b5_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 13.4%, transparent 13.4%);
# }
# #T_4b8b5_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 7.8%, transparent 7.8%);
# }
# #T_4b8b5_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 7.1%, transparent 7.1%);
# }
# #T_4b8b5_row9_col1, #T_4b8b5_row10_col1, #T_4b8b5_row11_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_4b8b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b8b5_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_4b8b5_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b8b5_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_4b8b5_row0_col0" class="data row0 col0" >M05_2_N</td>
#       <td id="T_4b8b5_row0_col1" class="data row0 col1" >0.287941</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b8b5_row1_col0" class="data row1 col0" >M02_2_N</td>
#       <td id="T_4b8b5_row1_col1" class="data row1 col1" >0.218013</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_4b8b5_row2_col0" class="data row2 col0" >M07_2_N</td>
#       <td id="T_4b8b5_row2_col1" class="data row2 col1" >0.147000</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_4b8b5_row3_col0" class="data row3 col0" >M09_2_N</td>
#       <td id="T_4b8b5_row3_col1" class="data row3 col1" >0.122332</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_4b8b5_row4_col0" class="data row4 col0" >M11_2_N</td>
#       <td id="T_4b8b5_row4_col1" class="data row4 col1" >0.082481</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b8b5_row5_col0" class="data row5 col0" >M06_2_N</td>
#       <td id="T_4b8b5_row5_col1" class="data row5 col1" >0.060596</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4b8b5_row6_col0" class="data row6 col0" >M08_2_N</td>
#       <td id="T_4b8b5_row6_col1" class="data row6 col1" >0.038541</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_4b8b5_row7_col0" class="data row7 col0" >M04_2_N</td>
#       <td id="T_4b8b5_row7_col1" class="data row7 col1" >0.022600</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row8" class="row_heading level0 row8" >2</th>
#       <td id="T_4b8b5_row8_col0" class="data row8 col0" >M03_2_N</td>
#       <td id="T_4b8b5_row8_col1" class="data row8 col1" >0.020496</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row9" class="row_heading level0 row9" >0</th>
#       <td id="T_4b8b5_row9_col0" class="data row9 col0" >M01_2_N</td>
#       <td id="T_4b8b5_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_4b8b5_row10_col0" class="data row10 col0" >M10_2_N</td>
#       <td id="T_4b8b5_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4b8b5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4b8b5_row11_col0" class="data row11 col0" >M12_2_N</td>
#       <td id="T_4b8b5_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer2 = shap.TreeExplainer(models_2['model'], models_2['x_train'])
shap_values2 = explainer2(models_2['x_test'])

plt.title('Shap Feature Importance (sem2)', fontsize=16)
shap.plots.bar(shap_values2[...,1])

# %%
shap.plots.violin(shap_values2[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values2[...,1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iWFPMEAEJCR8CHVWHFRXO'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7385146066616817, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "explanations": [{"outValue": 0.999999996263121, "simIndex": 11.0, "features": {"0": {"effect": 0.0, "value": 1.7}, "1": {"effect": 0.12964140452444553, "value": 5.1}, "2": {"effect": -0.020088558942079546, "value": 5.1}, "3": {"effect": -0.003205031603574753, "value": 3.3}, "4": {"effect": -0.008836461901664735, "value": 1.7}, "5": {"effect": 0.013087593838572503, "value": 5.1}, "6": {"effect": 0.028287094589322805, "value": 5.1}, "7": {"effect": 0.04061041831970215, "value": 5.1}, "8": {"effect": 0.06285017371177673, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.019138757064938547, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.044176705039624675, "simIndex": 60.0, "features": {"0": {"effect": 0.0, "value": 1.7}, "1": {"effect": -0.35266918525099755, "value": 3.0}, "2": {"effect": 0.006402160450816155, "value": 1.3}, "3": {"effect": -0.008293490707874298, "value": 1.0}, "4": {"effect": -0.018199375048279762, "value": 1.7}, "5": {"effect": -0.04697149634361267, "value": 1.7}, "6": {"effect": -0.11696816004812717, "value": 1.3}, "7": {"effect": 0.013270440101623536, "value": 5.1}, "8": {"effect": 0.01951865039765835, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": -0.19042744517326354, "value": 1.0}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000077183886, "simIndex": 25.0, "features": {"0": {"effect": 0.0, "value": 5.1}, "1": {"effect": 0.09487284936010837, "value": 5.1}, "2": {"effect": -0.019917831718921662, "value": 5.1}, "3": {"effect": -0.009775752723217011, "value": 5.1}, "4": {"effect": 0.030118391811847688, "value": 5.1}, "5": {"effect": 0.017348092943429948, "value": 5.1}, "6": {"effect": 0.021591051891446115, "value": 5.1}, "7": {"effect": 0.01750329703092575, "value": 5.1}, "8": {"effect": 0.049328433386981486, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.06041686907410622, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000077183886, "simIndex": 24.0, "features": {"0": {"effect": 0.0, "value": 5.1}, "1": {"effect": 0.09487284936010837, "value": 5.1}, "2": {"effect": -0.019917831718921662, "value": 5.1}, "3": {"effect": -0.009775752723217011, "value": 5.1}, "4": {"effect": 0.030118391811847688, "value": 5.1}, "5": {"effect": 0.017348092943429948, "value": 5.1}, "6": {"effect": 0.021591051891446115, "value": 5.1}, "7": {"effect": 0.01750329703092575, "value": 5.1}, "8": {"effect": 0.049328433386981486, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.06041686907410622, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000077183886, "simIndex": 23.0, "features": {"0": {"effect": 0.0, "value": 5.1}, "1": {"effect": 0.09487284936010837, "value": 5.1}, "2": {"effect": -0.019917831718921662, "value": 5.1}, "3": {"effect": -0.009775752723217011, "value": 5.1}, "4": {"effect": 0.030118391811847688, "value": 5.1}, "5": {"effect": 0.017348092943429948, "value": 5.1}, "6": {"effect": 0.021591051891446115, "value": 5.1}, "7": {"effect": 0.01750329703092575, "value": 5.1}, "8": {"effect": 0.049328433386981486, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.06041686907410622, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9999999708007616, "simIndex": 50.0, "features": {"0": {"effect": 0.0, "value": 2.0}, "1": {"effect": 0.0007338825426995754, "value": 2.0}, "2": {"effect": 0.04777951197698713, "value": 1.3}, "3": {"effect": 0.006195151135325432, "value": 4.0}, "4": {"effect": 0.022787058651447298, "value": 1.7}, "5": {"effect": -0.014068269729614257, "value": 1.7}, "6": {"effect": 0.07008464455604553, "value": 5.1}, "7": {"effe ...

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=33, link='logit', model_name='dt')
# Out:
# Student index 33 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     2.3
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='iHEC61JQC7KY23I46AA8E'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7385146066616817, "outValue": 1.0000000001001699, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"1": {"effect": 0.05406457083299756, "value": 5.1}, "2": {"effect": 0.012087795659899711, "value": 2.3}, "3": {"effect": -0.006167261898517609, "value": 5.1}, "4": {"effect": 0.030239965915679932, "value": 5.1}, "5": {"effect": 0.017348092943429948, "value": 5.1}, "6": {"effect": 0.02648255951702595, "value": 5.1}, "7": {"effect": 0.019559748768806458, "value": 5.1}, "8": {"effect": 0.04472663812339306, "value": 5.1}, "10": {"effect": 0.06314328357577324, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iHEC61JQC7KY23I46AA8E')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=11, link='logit', model_name='dt')
# Out:
# Student index 11 grades:
#          grades
# M01_2_N     4.0
# M02_2_N     1.3
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     1.3
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     1.3
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='iZ6XOB8J6SOY6RG2YUSGI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7385146066616817, "outValue": 1.000000009133999, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"1": {"effect": 0.07977364379912615, "value": 1.3}, "2": {"effect": -0.016909464206546546, "value": 5.1}, "3": {"effect": -0.006813521161675453, "value": 5.1}, "4": {"effect": 0.07376340806484222, "value": 1.3}, "5": {"effect": 0.011790424026548863, "value": 5.1}, "6": {"effect": 0.06869298368692398, "value": 5.1}, "7": {"effect": -0.06146373845636845, "value": 1.3}, "8": {"effect": 0.09591857021674514, "value": 5.1}, "10": {"effect": 0.01673309650272131, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZ6XOB8J6SOY6RG2YUSGI')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=2, link='logit',model_name='dt')
# Out:
# Student index 2 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='i628O126JPWYV67YVND04'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7385146066616817, "outValue": 1.0000000077183886, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"1": {"effect": 0.09487284936010837, "value": 5.1}, "2": {"effect": -0.019917831718921662, "value": 5.1}, "3": {"effect": -0.009775752723217011, "value": 5.1}, "4": {"effect": 0.030118391811847688, "value": 5.1}, "5": {"effect": 0.017348092943429948, "value": 5.1}, "6": {"effect": 0.021591051891446115, "value": 5.1}, "7": {"effect": 0.01750329703092575, "value": 5.1}, "8": {"effect": 0.049328433386981486, "value": 5.1}, "10": {"effect": 0.06041686907410622, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i628O126JPWYV67YVND04')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=5, link='logit', model_name='dt')
# Out:
# Student index 5 grades:
#          grades
# M01_2_N     2.0
# M02_2_N     2.0
# M03_2_N     1.3
# M04_2_N     4.0
# M05_2_N     1.7
# M06_2_N     1.7
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='iRYMV208XRMYXPWTVGX2W'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7385146066616817, "outValue": 0.9999999708007616, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"1": {"effect": 0.0007338825426995754, "value": 2.0}, "2": {"effect": 0.04777951197698713, "value": 1.3}, "3": {"effect": 0.006195151135325432, "value": 4.0}, "4": {"effect": 0.022787058651447298, "value": 1.7}, "5": {"effect": -0.014068269729614257, "value": 1.7}, "6": {"effect": 0.07008464455604553, "value": 5.1}, "7": {"effect": 0.013270440101623536, "value": 5.1}, "8": {"effect": 0.09564437665045261, "value": 5.1}, "10": {"effect": 0.019058568254113197, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRYMV208XRMYXPWTVGX2W')
#   );
# </script>

# %% [markdown]
# ## BHT semester 3

# %%
# Count occurrences of each unique value in the 'status' column
counter_3 = Counter(THL_3['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_3[1]} | 0: {counter_3[0]}')
hpo3 = ModelTrainer(random_state=42)
x, y = hpo3.split_data(THL_3, module3)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 168 | 0: 54

# %%
hpo3 = ModelTrainer(random_state=42)
models_3, feature_importance_3 = hpo3.cross_validation_hpo(x=x, y=y, search_space=search_space, folds=5, algo='dt')
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 18.44trial/s, best loss: -0.8309472934472935]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            06               05
# 	 actual 1            02               32
#
# Model parameters:
# {'ccp_alpha': 0.01705023126314982, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 74.33155%
# Validation accuracy.: 84.44444%
# Sensitivity score (for 1): 94.11765%
# Specificity score (for 0): 54.54545%
# F1 score.: 90.14085%
# False prediction: 15.55556%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 17.91trial/s, best loss: -0.7428062678062679]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               02
# 	 actual 1            09               25
#
# Model parameters:
# {'ccp_alpha': 0.015202043492005771, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 77.67380%
# Validation accuracy.: 75.55556%
# Sensitivity score (for 1): 73.52941%
# Specificity score (for 0): 81.81818%
# F1 score.: 81.96721%
# False prediction: 24.44444%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.69trial/s, best loss: -0.7602564102564102]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               03
# 	 actual 1            05               29
#
# Model parameters:
# {'ccp_alpha': 0.019913170135185024, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 15, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 77.64706%
# Validation accuracy.: 81.81818%
# Sensitivity score (for 1): 85.29412%
# Specificity score (for 0): 70.00000%
# F1 score.: 87.87879%
# False prediction: 18.18182%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.16trial/s, best loss: -0.7236111111111111]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            10               01
# 	 actual 1            08               25
#
# Model parameters:
# {'ccp_alpha': 0.01796754367617768, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 6, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 83.33333%
# Validation accuracy.: 79.54545%
# Sensitivity score (for 1): 75.75758%
# Specificity score (for 0): 90.90909%
# F1 score.: 84.74576%
# False prediction: 20.45455%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 10.02trial/s, best loss: -0.7435185185185185]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               03
# 	 actual 1            05               28
#
# Model parameters:
# {'ccp_alpha': 0.01624463996067927, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 11, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# Balanced acc.: 78.78788%
# Validation accuracy.: 81.81818%
# Sensitivity score (for 1): 84.84848%
# Specificity score (for 0): 72.72727%
# F1 score.: 87.50000%
# False prediction: 18.18182%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 78.35472%
# Standard Deviation of Balanced Accuracy: +/- 2.903
#
# Mean Accuracy: 80.63636%
# Standard Deviation of Accuracy: +/- 2.977
#
# Mean Sensitivity: 82.70945%
# Standard Deviation of Sensitivity: +/- 7.403
#
# Mean Specificity: 74.00000%
# Standard Deviation of Specificity: +/- 12.191
#
# Mean False Predictions: 19.36364%
# Standard Deviation of False Predictions: +/- 2.977
# best model is from 4 fold: DecisionTreeClassifier(ccp_alpha=0.01796754367617768, class_weight='balanced',
#                        criterion='entropy', max_depth=6, max_features='log2',
#                        random_state=42)

# %%
feature_importance_3
# Out:
# <style type="text/css">
# #T_d7fde_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_d7fde_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 18.0%, transparent 18.0%);
# }
# #T_d7fde_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 17.7%, transparent 17.7%);
# }
# #T_d7fde_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 14.2%, transparent 14.2%);
# }
# #T_d7fde_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 13.1%, transparent 13.1%);
# }
# #T_d7fde_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 8.7%, transparent 8.7%);
# }
# #T_d7fde_row6_col1, #T_d7fde_row7_col1, #T_d7fde_row8_col1, #T_d7fde_row9_col1, #T_d7fde_row10_col1, #T_d7fde_row11_col1, #T_d7fde_row12_col1, #T_d7fde_row13_col1, #T_d7fde_row14_col1, #T_d7fde_row15_col1, #T_d7fde_row16_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_d7fde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7fde_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_d7fde_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7fde_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d7fde_row0_col0" class="data row0 col0" >M02_3_N</td>
#       <td id="T_d7fde_row0_col1" class="data row0 col1" >0.582322</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_d7fde_row1_col0" class="data row1 col0" >M16_3_N</td>
#       <td id="T_d7fde_row1_col1" class="data row1 col1" >0.105020</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_d7fde_row2_col0" class="data row2 col0" >M09_3_N</td>
#       <td id="T_d7fde_row2_col1" class="data row2 col1" >0.102853</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_d7fde_row3_col0" class="data row3 col0" >M06_3_N</td>
#       <td id="T_d7fde_row3_col1" class="data row3 col1" >0.082854</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_d7fde_row4_col0" class="data row4 col0" >M01_3_N</td>
#       <td id="T_d7fde_row4_col1" class="data row4 col1" >0.076205</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_d7fde_row5_col0" class="data row5 col0" >M15_3_N</td>
#       <td id="T_d7fde_row5_col1" class="data row5 col1" >0.050747</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_d7fde_row6_col0" class="data row6 col0" >M05_3_N</td>
#       <td id="T_d7fde_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_d7fde_row7_col0" class="data row7 col0" >M07_3_N</td>
#       <td id="T_d7fde_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_d7fde_row8_col0" class="data row8 col0" >M08_3_N</td>
#       <td id="T_d7fde_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_d7fde_row9_col0" class="data row9 col0" >M04_3_N</td>
#       <td id="T_d7fde_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_d7fde_row10_col0" class="data row10 col0" >M10_3_N</td>
#       <td id="T_d7fde_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row11" class="row_heading level0 row11" >10</th>
#       <td id="T_d7fde_row11_col0" class="data row11 col0" >M11_3_N</td>
#       <td id="T_d7fde_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row12" class="row_heading level0 row12" >11</th>
#       <td id="T_d7fde_row12_col0" class="data row12 col0" >M12_3_N</td>
#       <td id="T_d7fde_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row13" class="row_heading level0 row13" >12</th>
#       <td id="T_d7fde_row13_col0" class="data row13 col0" >M13_3_N</td>
#       <td id="T_d7fde_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row14" class="row_heading level0 row14" >13</th>
#       <td id="T_d7fde_row14_col0" class="data row14 col0" >M14_3_N</td>
#       <td id="T_d7fde_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row15" class="row_heading level0 row15" >2</th>
#       <td id="T_d7fde_row15_col0" class="data row15 col0" >M03_3_N</td>
#       <td id="T_d7fde_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fde_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d7fde_row16_col0" class="data row16 col0" >M17_3_N</td>
#       <td id="T_d7fde_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Shap Global explainations
import shap
explainer3 = shap.TreeExplainer(models_3['model'], models_3['x_train'])
shap_values3 = explainer3(models_3['x_test'])

plt.title('Shap Feature Importance (sem3)', fontsize=16)
shap.plots.bar(shap_values3[..., 1])

# %%
shap.plots.violin(shap_values3[..., 1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values3[..., 1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iX3SNMRD37L2ES9YES1QK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6536586288743862, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "explanations": [{"outValue": 1.0000000058495648, "simIndex": 12.0, "features": {"0": {"effect": 0.032247556447982786, "value": 5.1}, "1": {"effect": 0.1048938548564911, "value": 5.1}, "2": {"effect": 0.0, "value": 1.7}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.0, "value": 5.1}, "5": {"effect": 0.036895251870155334, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.13305230140686036, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.0, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.004239511191844941, "value": 5.1}, "15": {"effect": 0.035012901201844214, "value": 5.1}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000058495648, "simIndex": 11.0, "features": {"0": {"effect": 0.032247556447982786, "value": 5.1}, "1": {"effect": 0.1048938548564911, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.0, "value": 5.1}, "5": {"effect": 0.036895251870155334, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.13305230140686036, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.0, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.004239511191844941, "value": 5.1}, "15": {"effect": 0.035012901201844214, "value": 5.1}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.12816691782411427, "simIndex": 28.0, "features": {"0": {"effect": 0.004397394061088562, "value": 2.3}, "1": {"effect": -0.21316302984952926, "value": 1.7}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 0.0, "value": 1.3}, "5": {"effect": -0.10078640282154083, "value": 1.7}, "6": {"effect": 0.0, "value": 1.3}, "7": {"effect": 0.0, "value": 1.3}, "8": {"effect": -0.14651249080896378, "value": 1.7}, "9": {"effect": 0.0, "value": 1.7}, "10": {"effect": 0.0, "value": 1.7}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 1.7}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": 0.000964125543832779, "value": 5.1}, "15": {"effect": -0.07039130717515946, "value": 1.0}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000058495648, "simIndex": 10.0, "features": {"0": {"effect": 0.032247556447982786, "value": 4.0}, "1": {"effect": 0.1048938548564911, "value": 5.1}, "2": {"effect": 0.0, "value": 2.7}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.0, "value": 5.1}, "5": {"effect": 0.036895251870155334, "value": 5.0}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.13305230140686036, "value": 3.3}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.0, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.004239511191844941, "value": 5.1}, "15": {"effect": 0.035012901201844214, "value": 5.1}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.12816691596146912, "simIndex": 38.0, "features": {"0": {"effect": 0.006596091091632843, "value": 2.7}, "1": {"effect": -0.356787301376462, "value": 2.3}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.0, "value": 5.1}, "5": {"effect": -0.22058185160160065, "value": 3.0}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.02105719327926636, "value": 5.1}, "9": {"effect": 0.0, "value": 4.0}, "10": {" ...

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=1, model_name='dt')
# Out:
# Student index 1 grades:
#          grades
# M01_3_N     5.1
# M02_3_N     5.1
# M03_3_N     5.1
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='iUPOSHVIOXE8PVOOP98T9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6536586288743862, "outValue": 1.0000000058495648, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": 0.032247556447982786, "value": 5.1}, "1": {"effect": 0.1048938548564911, "value": 5.1}, "5": {"effect": 0.036895251870155334, "value": 5.1}, "8": {"effect": 0.13305230140686036, "value": 5.1}, "14": {"effect": 0.004239511191844941, "value": 5.1}, "15": {"effect": 0.035012901201844214, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iUPOSHVIOXE8PVOOP98T9')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=4, model_name='dt')
# Out:
# Student index 4 grades:
#          grades
# M01_3_N     2.7
# M02_3_N     2.3
# M03_3_N     5.1
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     3.0
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     4.0
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 0, Prediction: [0], Probability [0]: 0.872, Probability [1]: 0.128
# <div id='iSXZV80QSYYKD513EQ4HY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6536586288743862, "outValue": 0.12816691596146912, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": 0.006596091091632843, "value": 2.7}, "1": {"effect": -0.356787301376462, "value": 2.3}, "5": {"effect": -0.22058185160160065, "value": 3.0}, "8": {"effect": 0.02105719327926636, "value": 5.1}, "14": {"effect": 0.0016244855523109437, "value": 5.1}, "15": {"effect": 0.022599670141935348, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iSXZV80QSYYKD513EQ4HY')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=14, model_name='dt')
# Out:
# Student index 14 grades:
#          grades
# M01_3_N     1.0
# M02_3_N     1.0
# M03_3_N     1.0
# M04_3_N     1.0
# M05_3_N     1.7
# M06_3_N     1.0
# M07_3_N     5.1
# M08_3_N     1.7
# M09_3_N     5.1
# M10_3_N     1.0
# M11_3_N     1.0
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     1.3
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     1.3
# Status: 0, Prediction: [0], Probability [0]: 0.872, Probability [1]: 0.128
# <div id='iPBV2MB0IRF0JAI23YUVY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6536586288743862, "outValue": 0.1281669308626303, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": -0.10114006340503692, "value": 1.0}, "1": {"effect": -0.2424550435692072, "value": 1.0}, "5": {"effect": -0.22058185160160065, "value": 1.0}, "8": {"effect": 0.014461104869842529, "value": 5.1}, "14": {"effect": 0.0016244855523109437, "value": 5.1}, "15": {"effect": 0.022599670141935348, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPBV2MB0IRF0JAI23YUVY')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=24, model_name='dt')
# Out:
# Student index 24 grades:
#          grades
# M01_3_N     3.3
# M02_3_N     2.3
# M03_3_N     1.7
# M04_3_N     3.0
# M05_3_N     1.3
# M06_3_N     2.7
# M07_3_N     5.1
# M08_3_N     1.0
# M09_3_N     2.3
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     2.7
# M15_3_N     5.1
# M16_3_N     2.0
# M17_3_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 0.872, Probability [1]: 0.128
# <div id='iJ5P1LK2A58APM6Q6ARTR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6536586288743862, "outValue": 0.12816691782411427, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": 0.004397394061088562, "value": 3.3}, "1": {"effect": -0.21316302984952926, "value": 2.3}, "5": {"effect": -0.10078640282154083, "value": 2.7}, "8": {"effect": -0.14651249080896378, "value": 2.3}, "14": {"effect": 0.000964125543832779, "value": 5.1}, "15": {"effect": -0.07039130717515946, "value": 2.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJ5P1LK2A58APM6Q6ARTR')
#   );
# </script>
