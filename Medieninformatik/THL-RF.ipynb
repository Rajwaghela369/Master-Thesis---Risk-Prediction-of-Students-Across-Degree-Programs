# %%
from functions import *
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import shap
from sklearn.model_selection import train_test_split
from collections import Counter

# %% [markdown]
# ## Data Preprocessing

# %%
path_1 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Dataset/THL1.csv"
path_2 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Dataset/THL2.csv"
path_3 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Dataset/THL3.csv"

THL_1 = pd.read_csv(path_1, sep=';')
THL_1.drop(columns=['Unnamed: 0'], inplace=True)
THL_2 = pd.read_csv(path_2, sep=';')
THL_2.drop(columns=['Unnamed: 0'], inplace=True)
THL_3 = pd.read_csv(path_3, sep=',')

# %% [markdown]
# data standardizing functions

# %%
## set modules
module1 = ['M01_1_N', 'M02_1_N', 'M03_1_N', 'M04_1_N', 'M05_1_N', 'M06_1_N']

module2 = [
            'M01_2_N', 'M02_2_N', 'M03_2_N', 'M04_2_N', 'M05_2_N', 'M06_2_N',
            'M07_2_N', 'M08_2_N', 'M09_2_N', 'M10_2_N', 'M11_2_N', 'M12_2_N',]

module3 = ['M01_3_N', 'M02_3_N', 'M03_3_N', 'M04_3_N', 'M05_3_N', 'M06_3_N',
            'M07_3_N', 'M08_3_N', 'M09_3_N', 'M10_3_N', 'M11_3_N', 'M12_3_N',
            'M13_3_N', 'M14_3_N', 'M15_3_N', 'M16_3_N', 'M17_3_N']

# %% [markdown]
# ### Train test split function

# %% [markdown]
# ### Search Space / Param Grid

# %%
'''from hyperopt import *
search_space = {
    'n_estimators': hp.choice('n_estimators', np.arange(5, 50, 5)),  # Smaller number of trees for small datasets
    'max_depth': hp.choice('max_depth', np.arange(3, 20, 1)),  # Limit depth to prevent overfitting
    'max_features': hp.choice('max_features', ['sqrt', 'log2']),  # Control the number of features considered
    'min_samples_split': hp.uniform('min_samples_split', 0.05, 1),  # Increase to avoid splitting on very small samples
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.05, 1),  # Ensure min_samples_leaf is an integer
    'bootstrap': hp.choice('bootstrap', [True]),  # Set bootstrap to True to avoid overfitting
    'criterion': hp.choice('criterion', ['gini', 'entropy']),  # Criterion for splitting nodes
    'oob_score': hp.choice('oob_score', [True, False]),  # Out-of-bag samples estimation for validation
    'class_weight': 'balanced',
    'ccp_alpha': hp.loguniform('ccp_alpha', -7,0)
}'''
# Out:
# "from hyperopt import *\nsearch_space = {\n    'n_estimators': hp.choice('n_estimators', np.arange(5, 50, 5)),  # Smaller number of trees for small datasets\n    'max_depth': hp.choice('max_depth', np.arange(3, 20, 1)),  # Limit depth to prevent overfitting\n    'max_features': hp.choice('max_features', ['sqrt', 'log2']),  # Control the number of features considered\n    'min_samples_split': hp.uniform('min_samples_split', 0.05, 1),  # Increase to avoid splitting on very small samples\n    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.05, 1),  # Ensure min_samples_leaf is an integer\n    'bootstrap': hp.choice('bootstrap', [True]),  # Set bootstrap to True to avoid overfitting\n    'criterion': hp.choice('criterion', ['gini', 'entropy']),  # Criterion for splitting nodes\n    'oob_score': hp.choice('oob_score', [True, False]),  # Out-of-bag samples estimation for validation\n    'class_weight': 'balanced',\n    'ccp_alpha': hp.loguniform('ccp_alpha', -7,0)\n}"

# %%
from hyperopt import *
search_space = {
    'n_estimators': hp.choice('n_estimators', np.arange(5, 20, 2)),  # Smaller number of trees for small datasets
    'max_depth': hp.choice('max_depth', np.arange(4, 10)),  # Limit depth to prevent overfitting
    'max_features': hp.choice('max_features', [None]),  # Control the number of features considered
    'bootstrap': hp.choice('bootstrap', [True]),  # Set bootstrap to True to avoid overfitting
    'criterion': hp.choice('criterion', ['entropy']),  # Criterion for splitting node    
    'min_impurity_decrease': hp.uniform('min_impurity_decrease', 0.001, 0.03),
    'ccp_alpha': hp.uniform('ccp_alpha', 0.05, 0.13),
    'oob_score': hp.choice('oob_score', [True]),  # Out-of-bag samples estimation for validation
    'class_weight': 'balanced',
}

# %% [markdown]
# ## THL semester 1

# %%
# Count occurrences of each unique value in the 'status' column
counter_1 = Counter(THL_1['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_1[1]} | 0: {counter_1[0]}')
hpo = ModelTrainer(random_state=42)
x, y = hpo.split_data(THL_1, module1)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 423 | 0: 54

# %%
models_1, feature_importance1 = hpo.cross_validation_hpo(
    x=x, y=y,
    search_space=search_space, 
    algo='rf'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  4.04trial/s, best loss: -0.819659057652912]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            06               05
# 	 actual 1            18               67
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.11024380115515726, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.016344571828915327, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 5, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 66.68449%
# Validation accuracy.: 76.04167%
# Sensitivity score (for 1): 78.82353%
# Specificity score (for 0): 54.54545%
# F1 score.: 85.35032%
# False prediction: 23.95833%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  3.63trial/s, best loss: -0.8203285045361428]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               03
# 	 actual 1            12               73
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.10367110934553471, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.01120936490163911, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 9, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 79.30481%
# Validation accuracy.: 84.37500%
# Sensitivity score (for 1): 85.88235%
# Specificity score (for 0): 72.72727%
# F1 score.: 90.68323%
# False prediction: 15.62500%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  4.07trial/s, best loss: -0.7741403277729002]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               02
# 	 actual 1            11               74
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.06438889437194066, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 6, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0082639245214161, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 15, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 83.52941%
# Validation accuracy.: 86.31579%
# Sensitivity score (for 1): 87.05882%
# Specificity score (for 0): 80.00000%
# F1 score.: 91.92547%
# False prediction: 13.68421%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  3.86trial/s, best loss: -0.807482196858843]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               03
# 	 actual 1            20               64
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.07071463020692512, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.008061567271684649, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 74.45887%
# Validation accuracy.: 75.78947%
# Sensitivity score (for 1): 76.19048%
# Specificity score (for 0): 72.72727%
# F1 score.: 84.76821%
# False prediction: 24.21053%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  4.55trial/s, best loss: -0.781523753780119]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            10               01
# 	 actual 1            08               76
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.07052417163291348, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.02493289601027469, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 13, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 90.69264%
# Validation accuracy.: 90.52632%
# Sensitivity score (for 1): 90.47619%
# Specificity score (for 0): 90.90909%
# F1 score.: 94.40994%
# False prediction: 9.47368%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 78.93405%
# Standard Deviation of Balanced Accuracy: +/- 8.119
#
# Mean Accuracy: 82.60965%
# Standard Deviation of Accuracy: +/- 5.817
#
# Mean Sensitivity: 83.68627%
# Standard Deviation of Sensitivity: +/- 5.332
#
# Mean Specificity: 74.18182%
# Standard Deviation of Specificity: +/- 11.861
#
# Mean False Predictions: 17.39035%
# Standard Deviation of False Predictions: +/- 5.817
#
# best model is from 5 fold: RandomForestClassifier(ccp_alpha=0.07052417163291348, class_weight='balanced',
#                        criterion='entropy', max_depth=5, max_features=None,
#                        min_impurity_decrease=0.02493289601027469,
#                        n_estimators=13, oob_score=True, random_state=42)

# %%
feature_importance1
# Out:
# <style type="text/css">
# #T_043d8_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_043d8_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 53.2%, transparent 53.2%);
# }
# #T_043d8_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 50.4%, transparent 50.4%);
# }
# #T_043d8_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 18.1%, transparent 18.1%);
# }
# #T_043d8_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 8.5%, transparent 8.5%);
# }
# #T_043d8_row5_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_043d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_043d8_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_043d8_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_043d8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_043d8_row0_col0" class="data row0 col0" >M02_1_N</td>
#       <td id="T_043d8_row0_col1" class="data row0 col1" >0.434403</td>
#     </tr>
#     <tr>
#       <th id="T_043d8_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_043d8_row1_col0" class="data row1 col0" >M04_1_N</td>
#       <td id="T_043d8_row1_col1" class="data row1 col1" >0.231171</td>
#     </tr>
#     <tr>
#       <th id="T_043d8_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_043d8_row2_col0" class="data row2 col0" >M01_1_N</td>
#       <td id="T_043d8_row2_col1" class="data row2 col1" >0.219138</td>
#     </tr>
#     <tr>
#       <th id="T_043d8_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_043d8_row3_col0" class="data row3 col0" >M03_1_N</td>
#       <td id="T_043d8_row3_col1" class="data row3 col1" >0.078476</td>
#     </tr>
#     <tr>
#       <th id="T_043d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_043d8_row4_col0" class="data row4 col0" >M05_1_N</td>
#       <td id="T_043d8_row4_col1" class="data row4 col1" >0.036812</td>
#     </tr>
#     <tr>
#       <th id="T_043d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_043d8_row5_col0" class="data row5 col0" >M06_1_N</td>
#       <td id="T_043d8_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer = shap.TreeExplainer(models_1['model'], models_1['x_train'])
shap_values = explainer(models_1['x_test'])

plt.title('Shap Feature Importance (sem1)', fontsize=16)
shap.plots.bar(shap_values[...,1])

# %%
shap.plots.violin(shap_values[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values[...,1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iB9HXGU4BW06BEN81I1KY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6787747747931686, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "explanations": [{"outValue": 0.8548685567189065, "simIndex": 53.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 52.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 51.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 54.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 50.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 55.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 49.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.11369885234311794, "simIndex": 7.0, "features": {"0": {"effect": -0.1323235237598419, "value": 1.3}, "1": {"effect": -0.2660447533987462, "value": 1.0}, "2": {"effect": 0.004857350122183562, "value": 5.1}, "3": {"effect": -0.1449415861722082, "value": 1.3}, "4": {"effect": -0.026623409241437912, "value": 1.3}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 56.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8548685567189065, "simIndex": 48.0, "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7769631553921905, "simIndex": 86.0, "features": {"0": {"effect": 0.03482890531420708, "value": 5.1}, "1": {"effe ...

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=14, link='identity', model_name='rf')
# Out:
# Student index 14 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     1.0
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     1.7
# Status: 1, Prediction: [1], Probability [0]: 0.299, Probability [1]: 0.701
# <div id='iGFH6BLI5BV2WQJ6JQM5U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6787747747931686, "outValue": 0.7012798040840832, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.06243861940689385, "value": 5.1}, "2": {"effect": -0.12387183852493763, "value": 1.0}, "3": {"effect": 0.030140901571139692, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iGFH6BLI5BV2WQJ6JQM5U')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=4, link='identity', model_name='rf')
# Out:
# Student index 4 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.145, Probability [1]: 0.855
# <div id='iPMC9NN62C8346Z3CJV8U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6787747747931686, "outValue": 0.8548685567189065, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.03808928936719894, "value": 5.1}, "1": {"effect": 0.07294718127697707, "value": 5.1}, "2": {"effect": 0.015085586309432984, "value": 5.1}, "3": {"effect": 0.03426366750150919, "value": 5.1}, "4": {"effect": 0.01570805747061968, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPMC9NN62C8346Z3CJV8U')
#   );
# </script>

# %% [markdown]
# ## THL semester 2

# %%
# Count occurrences of each unique value in the 'status' column
counter_2 = Counter(THL_2['status'])
print(f'Quantity of Drop Out and Degree in THL-2: \n 1: {counter_2[1]} | 0: {counter_2[0]}')
hpo2 = ModelTrainer(random_state=42)
x2, y2 = hpo2.split_data(THL_2, module2)
# Out:
# Quantity of Drop Out and Degree in THL-2:
#  1: 256 | 0: 54

# %%
models_2, feature_importance2 = hpo2.cross_validation_hpo(
    x=x2, y=y2,
    search_space=search_space, 
    algo='rf'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  3.18trial/s, best loss: -0.8020121951219512]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               01
# 	 actual 1            07               45
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.11685572625512701, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.008185826912531162, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 19, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 88.26923%
# Validation accuracy.: 87.09677%
# Sensitivity score (for 1): 86.53846%
# Specificity score (for 0): 90.00000%
# F1 score.: 91.83673%
# False prediction: 12.90323%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  3.88trial/s, best loss: -0.8625338753387535]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               04
# 	 actual 1            11               40
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.09721242061420232, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.02363337413575255, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 15, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 71.03387%
# Validation accuracy.: 75.80645%
# Sensitivity score (for 1): 78.43137%
# Specificity score (for 0): 63.63636%
# F1 score.: 84.21053%
# False prediction: 24.19355%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  6.92trial/s, best loss: -0.8125677506775068]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               00
# 	 actual 1            15               36
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.08804942124196061, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.010024659306842338, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 85.29412%
# Validation accuracy.: 75.80645%
# Sensitivity score (for 1): 70.58824%
# Specificity score (for 0): 100.00000%
# F1 score.: 82.75862%
# False prediction: 24.19355%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  7.95trial/s, best loss: -0.8347899728997289]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               03
# 	 actual 1            09               42
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.08799244987772598, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.029072328553334942, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 19, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 77.54011%
# Validation accuracy.: 80.64516%
# Sensitivity score (for 1): 82.35294%
# Specificity score (for 0): 72.72727%
# F1 score.: 87.50000%
# False prediction: 19.35484%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 10.68trial/s, best loss: -0.7820121951219512]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               02
# 	 actual 1            07               44
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.05696323460380024, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0023365605914814312, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 5, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 84.04635%
# Validation accuracy.: 85.48387%
# Sensitivity score (for 1): 86.27451%
# Specificity score (for 0): 81.81818%
# F1 score.: 90.72165%
# False prediction: 14.51613%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 81.23673%
# Standard Deviation of Balanced Accuracy: +/- 6.190
#
# Mean Accuracy: 80.96774%
# Standard Deviation of Accuracy: +/- 4.719
#
# Mean Sensitivity: 80.83710%
# Standard Deviation of Sensitivity: +/- 5.919
#
# Mean Specificity: 81.63636%
# Standard Deviation of Specificity: +/- 12.732
#
# Mean False Predictions: 19.03226%
# Standard Deviation of False Predictions: +/- 4.719
#
# best model is from 1 fold: RandomForestClassifier(ccp_alpha=0.11685572625512701, class_weight='balanced',
#                        criterion='entropy', max_depth=9, max_features=None,
#                        min_impurity_decrease=0.008185826912531162,
#                        n_estimators=19, oob_score=True, random_state=42)

# %%
feature_importance2
# Out:
# <style type="text/css">
# #T_471fa_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_471fa_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 87.4%, transparent 87.4%);
# }
# #T_471fa_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 45.2%, transparent 45.2%);
# }
# #T_471fa_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.3%, transparent 11.3%);
# }
# #T_471fa_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 8.0%, transparent 8.0%);
# }
# #T_471fa_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 3.5%, transparent 3.5%);
# }
# #T_471fa_row6_col1, #T_471fa_row7_col1, #T_471fa_row8_col1, #T_471fa_row9_col1, #T_471fa_row10_col1, #T_471fa_row11_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_471fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_471fa_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_471fa_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_471fa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_471fa_row0_col0" class="data row0 col0" >M02_2_N</td>
#       <td id="T_471fa_row0_col1" class="data row0 col1" >0.391556</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_471fa_row1_col0" class="data row1 col0" >M11_2_N</td>
#       <td id="T_471fa_row1_col1" class="data row1 col1" >0.342074</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_471fa_row2_col0" class="data row2 col0" >M05_2_N</td>
#       <td id="T_471fa_row2_col1" class="data row2 col1" >0.177162</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_471fa_row3_col0" class="data row3 col0" >M06_2_N</td>
#       <td id="T_471fa_row3_col1" class="data row3 col1" >0.044158</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_471fa_row4_col0" class="data row4 col0" >M09_2_N</td>
#       <td id="T_471fa_row4_col1" class="data row4 col1" >0.031332</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_471fa_row5_col0" class="data row5 col0" >M01_2_N</td>
#       <td id="T_471fa_row5_col1" class="data row5 col1" >0.013718</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_471fa_row6_col0" class="data row6 col0" >M03_2_N</td>
#       <td id="T_471fa_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_471fa_row7_col0" class="data row7 col0" >M04_2_N</td>
#       <td id="T_471fa_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_471fa_row8_col0" class="data row8 col0" >M07_2_N</td>
#       <td id="T_471fa_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_471fa_row9_col0" class="data row9 col0" >M08_2_N</td>
#       <td id="T_471fa_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_471fa_row10_col0" class="data row10 col0" >M10_2_N</td>
#       <td id="T_471fa_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_471fa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_471fa_row11_col0" class="data row11 col0" >M12_2_N</td>
#       <td id="T_471fa_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer2 = shap.TreeExplainer(models_2['model'], models_2['x_train'])
shap_values2 = explainer2(models_2['x_test'])

plt.title('Shap Feature Importance (sem2)', fontsize=16)
shap.plots.bar(shap_values2[...,1])

# %%
shap.plots.violin(shap_values2[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values2[...,1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iTHI4ZZC9Q8IWTZZ33ZRX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6632356719936469, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "explanations": [{"outValue": 0.6887875889971146, "simIndex": 22.0, "features": {"0": {"effect": -0.01954277985729277, "value": 1.7}, "1": {"effect": 0.10355134753510356, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 3.3}, "4": {"effect": -0.136670157648623, "value": 1.7}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.010799289867281913, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.05135009227320552, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.14255124754116322, "simIndex": 6.0, "features": {"0": {"effect": -0.009279305543750525, "value": 1.7}, "1": {"effect": -0.17522377851419152, "value": 3.0}, "2": {"effect": 0.0, "value": 1.3}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": -0.07394039827398956, "value": 1.7}, "5": {"effect": -0.022216342855244875, "value": 1.7}, "6": {"effect": 0.0, "value": 1.3}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.0034593605622649194, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": -0.2434839598275721, "value": 1.0}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9270748304187544, "simIndex": 45.0, "features": {"0": {"effect": 0.006186203695833683, "value": 5.1}, "1": {"effect": 0.10914871140383184, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.05585382476449013, "value": 5.1}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.010799289867281913, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.06578700385987758, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9270748304187544, "simIndex": 44.0, "features": {"0": {"effect": 0.006186203695833683, "value": 5.1}, "1": {"effect": 0.10914871140383184, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.05585382476449013, "value": 5.1}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.010799289867281913, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.06578700385987758, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9270748304187544, "simIndex": 43.0, "features": {"0": {"effect": 0.006186203695833683, "value": 5.1}, "1": {"effect": 0.10914871140383184, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.05585382476449013, "value": 5.1}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.010799289867281913, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.06578700385987758, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.31923731572769964, "simIndex": 18.0, "features": {"0": {"effect": -0.01954277985729277, "value": 2.0}, "1": {"effect": -0.19866453851573168, "value": 2.0}, "2": {"effect": 0.0, "value": 1.3}, "3": {"effect": 0.0, "value": 4.0}, "4": {"effect": -0.1257779898121953, "value": 1.7}, "5": {"effect": -0.046483425050973894, "value": 1.7}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.007129843458533287, "value": 5.1}, "9": {"effect": 0.0, "value": 5.1}, "10": {"effect": 0.03934053351171315, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.8937162273361572, "simIndex": 28.0, "features": {"0": {"effect": 0.0061862036 ...

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=16, link='identity', model_name='rf')
# Out:
# Student index 16 grades:
#          grades
# M01_2_N     4.0
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.073, Probability [1]: 0.927
# <div id='iH92Y7G24WDPTRYSAV02X'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6632356719936469, "outValue": 0.9270748304187544, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.006186203695833683, "value": 4.0}, "1": {"effect": 0.10914871140383184, "value": 5.1}, "4": {"effect": 0.05585382476449013, "value": 5.1}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "8": {"effect": 0.010799289867281913, "value": 5.1}, "10": {"effect": 0.06578700385987758, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iH92Y7G24WDPTRYSAV02X')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=11, link='identity', model_name='rf')
# Out:
# Student index 11 grades:
#          grades
# M01_2_N     4.0
# M02_2_N     1.3
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     1.3
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     1.3
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 0.584, Probability [1]: 0.416
# <div id='i9YIC0967C2LAH65WMT5C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6632356719936469, "outValue": 0.4157144013217875, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.006186203695833683, "value": 4.0}, "1": {"effect": -0.19866453851573168, "value": 1.3}, "4": {"effect": -0.1257779898121953, "value": 1.3}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "8": {"effect": 0.007129843458533287, "value": 5.1}, "10": {"effect": 0.04754108566790819, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i9YIC0967C2LAH65WMT5C')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=12, link='identity', model_name='rf')
# Out:
# Student index 12 grades:
#          grades
# M01_2_N     2.3
# M02_2_N     3.0
# M03_2_N     1.0
# M04_2_N     1.0
# M05_2_N     1.7
# M06_2_N     1.0
# M07_2_N     2.0
# M08_2_N     2.0
# M09_2_N     1.7
# M10_2_N     3.0
# M11_2_N     1.0
# M12_2_N     5.1
# Status: 0, Prediction: [0], Probability [0]: 0.857, Probability [1]: 0.143
# <div id='iA2MQRH51NK1KFYSR19F1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6632356719936469, "outValue": 0.14255124646548567, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.009279305543750525, "value": 2.3}, "1": {"effect": -0.16421544051729142, "value": 3.0}, "4": {"effect": -0.07394039827398956, "value": 1.7}, "5": {"effect": -0.022216342855244875, "value": 1.0}, "8": {"effect": -0.02358319342136383, "value": 1.7}, "10": {"effect": -0.227449744916521, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iA2MQRH51NK1KFYSR19F1')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=26, link='identity', model_name='rf')
# Out:
# Student index 26 grades:
#          grades
# M01_2_N     2.3
# M02_2_N     1.3
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.432, Probability [1]: 0.568
# <div id='iP1S4L3Z2WNZ9LSTGZ02R'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6632356719936469, "outValue": 0.5675074066951165, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.01954277985729277, "value": 2.3}, "1": {"effect": -0.20819518445059657, "value": 1.3}, "4": {"effect": 0.051617981716990474, "value": 5.1}, "5": {"effect": 0.016064124833792447, "value": 5.1}, "8": {"effect": 0.007129843458533287, "value": 5.1}, "10": {"effect": 0.05719774900004268, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iP1S4L3Z2WNZ9LSTGZ02R')
#   );
# </script>

# %% [markdown]
# ## THL semester 3

# %%
# Count occurrences of each unique value in the 'status' column
counter_3 = Counter(THL_3['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_3[1]} | 0: {counter_3[0]}')
hpo3 = ModelTrainer(random_state=79)
x3, y3 = hpo3.split_data(THL_3, module3)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 168 | 0: 54

# %%
models_3, feature_importance3 = hpo3.cross_validation_hpo(
    x=x3, y=y3,
    search_space=search_space, 
    algo='rf'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  6.46trial/s, best loss: -0.8571225071225073]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            06               05
# 	 actual 1            04               30
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.1043360682280916, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.016557935844926517, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 13, 'n_jobs': None, 'oob_score': True, 'random_state': 79, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 71.39037%
# Validation accuracy.: 80.00000%
# Sensitivity score (for 1): 88.23529%
# Specificity score (for 0): 54.54545%
# F1 score.: 86.95652%
# False prediction: 20.00000%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  8.96trial/s, best loss: -0.8100783475783476]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               02
# 	 actual 1            10               24
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.12785801306582945, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.021729080723958193, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': True, 'random_state': 79, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 76.20321%
# Validation accuracy.: 73.33333%
# Sensitivity score (for 1): 70.58824%
# Specificity score (for 0): 81.81818%
# F1 score.: 80.00000%
# False prediction: 26.66667%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  9.31trial/s, best loss: -0.8319444444444443]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               01
# 	 actual 1            03               31
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.08399644367214718, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.027396963559515725, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 19, 'n_jobs': None, 'oob_score': True, 'random_state': 79, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 90.58824%
# Validation accuracy.: 90.90909%
# Sensitivity score (for 1): 91.17647%
# Specificity score (for 0): 90.00000%
# F1 score.: 93.93939%
# False prediction: 9.09091%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:01<00:00,  9.09trial/s, best loss: -0.8240740740740741]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               00
# 	 actual 1            04               29
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.1001596668621757, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.02321444586575661, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 7, 'n_jobs': None, 'oob_score': True, 'random_state': 79, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 93.93939%
# Validation accuracy.: 90.90909%
# Sensitivity score (for 1): 87.87879%
# Specificity score (for 0): 100.00000%
# F1 score.: 93.54839%
# False prediction: 9.09091%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 10.42trial/s, best loss: -0.850462962962963]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               02
# 	 actual 1            04               29
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.11429700273266931, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 6, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.01741596421331485, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 9, 'n_jobs': None, 'oob_score': True, 'random_state': 79, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 84.84848%
# Validation accuracy.: 86.36364%
# Sensitivity score (for 1): 87.87879%
# Specificity score (for 0): 81.81818%
# F1 score.: 90.62500%
# False prediction: 13.63636%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 83.39394%
# Standard Deviation of Balanced Accuracy: +/- 8.496
#
# Mean Accuracy: 84.30303%
# Standard Deviation of Accuracy: +/- 6.788
#
# Mean Sensitivity: 85.15152%
# Standard Deviation of Sensitivity: +/- 7.386
#
# Mean Specificity: 81.63636%
# Standard Deviation of Specificity: +/- 15.107
#
# Mean False Predictions: 15.69697%
# Standard Deviation of False Predictions: +/- 6.788
#
# best model is from 4 fold: RandomForestClassifier(ccp_alpha=0.1001596668621757, class_weight='balanced',
#                        criterion='entropy', max_depth=7, max_features=None,
#                        min_impurity_decrease=0.02321444586575661,
#                        n_estimators=7, oob_score=True, random_state=79)

# %%
feature_importance3
# Out:
# <style type="text/css">
# #T_eefa3_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_eefa3_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 84.3%, transparent 84.3%);
# }
# #T_eefa3_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 56.9%, transparent 56.9%);
# }
# #T_eefa3_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 10.7%, transparent 10.7%);
# }
# #T_eefa3_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 7.5%, transparent 7.5%);
# }
# #T_eefa3_row5_col1, #T_eefa3_row6_col1, #T_eefa3_row7_col1, #T_eefa3_row8_col1, #T_eefa3_row9_col1, #T_eefa3_row10_col1, #T_eefa3_row11_col1, #T_eefa3_row12_col1, #T_eefa3_row13_col1, #T_eefa3_row14_col1, #T_eefa3_row15_col1, #T_eefa3_row16_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_eefa3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eefa3_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_eefa3_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eefa3_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_eefa3_row0_col0" class="data row0 col0" >M10_3_N</td>
#       <td id="T_eefa3_row0_col1" class="data row0 col1" >0.385351</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_eefa3_row1_col0" class="data row1 col0" >M16_3_N</td>
#       <td id="T_eefa3_row1_col1" class="data row1 col1" >0.324903</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_eefa3_row2_col0" class="data row2 col0" >M02_3_N</td>
#       <td id="T_eefa3_row2_col1" class="data row2 col1" >0.219317</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_eefa3_row3_col0" class="data row3 col0" >M09_3_N</td>
#       <td id="T_eefa3_row3_col1" class="data row3 col1" >0.041362</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_eefa3_row4_col0" class="data row4 col0" >M11_3_N</td>
#       <td id="T_eefa3_row4_col1" class="data row4 col1" >0.029067</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_eefa3_row5_col0" class="data row5 col0" >M15_3_N</td>
#       <td id="T_eefa3_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row6" class="row_heading level0 row6" >13</th>
#       <td id="T_eefa3_row6_col0" class="data row6 col0" >M14_3_N</td>
#       <td id="T_eefa3_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_eefa3_row7_col0" class="data row7 col0" >M13_3_N</td>
#       <td id="T_eefa3_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_eefa3_row8_col0" class="data row8 col0" >M12_3_N</td>
#       <td id="T_eefa3_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row9" class="row_heading level0 row9" >0</th>
#       <td id="T_eefa3_row9_col0" class="data row9 col0" >M01_3_N</td>
#       <td id="T_eefa3_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row10" class="row_heading level0 row10" >7</th>
#       <td id="T_eefa3_row10_col0" class="data row10 col0" >M08_3_N</td>
#       <td id="T_eefa3_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row11" class="row_heading level0 row11" >6</th>
#       <td id="T_eefa3_row11_col0" class="data row11 col0" >M07_3_N</td>
#       <td id="T_eefa3_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row12" class="row_heading level0 row12" >5</th>
#       <td id="T_eefa3_row12_col0" class="data row12 col0" >M06_3_N</td>
#       <td id="T_eefa3_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row13" class="row_heading level0 row13" >4</th>
#       <td id="T_eefa3_row13_col0" class="data row13 col0" >M05_3_N</td>
#       <td id="T_eefa3_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row14" class="row_heading level0 row14" >3</th>
#       <td id="T_eefa3_row14_col0" class="data row14 col0" >M04_3_N</td>
#       <td id="T_eefa3_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row15" class="row_heading level0 row15" >2</th>
#       <td id="T_eefa3_row15_col0" class="data row15 col0" >M03_3_N</td>
#       <td id="T_eefa3_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eefa3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_eefa3_row16_col0" class="data row16 col0" >M17_3_N</td>
#       <td id="T_eefa3_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Shap Global explainations
import shap
explainer3 = shap.TreeExplainer(models_3['model'], models_3['x_train'])
shap_values3 = explainer3(models_3['x_test'])

plt.title('Shap Feature Importance (sem3)', fontsize=16)
shap.plots.bar(shap_values3[..., 1])

# %%
shap.plots.violin(shap_values3[..., 1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values3[..., 1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i0LFPWI5SMZSZT3BD3SY4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7263579881087923, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "explanations": [{"outValue": 0.9534687079013371, "simIndex": 33.0, "features": {"0": {"effect": 0.0, "value": 1.7}, "1": {"effect": 0.07206689428538084, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 3.3}, "4": {"effect": 0.0, "value": 1.7}, "5": {"effect": 0.0, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.00763442300260067, "value": 5.1}, "9": {"effect": 0.07011325798928737, "value": 5.1}, "10": {"effect": 0.007785310298204422, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.0, "value": 5.1}, "15": {"effect": 0.06951083421707153, "value": 5.1}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.09966762716779942, "simIndex": 1.0, "features": {"0": {"effect": 0.0, "value": 2.7}, "1": {"effect": -0.04318961497396231, "value": 4.0}, "2": {"effect": 0.0, "value": 1.7}, "3": {"effect": 0.0, "value": 2.0}, "4": {"effect": 0.0, "value": 5.1}, "5": {"effect": 0.0, "value": 3.3}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": -0.04035337872803211, "value": 1.7}, "9": {"effect": -0.27516499705612657, "value": 3.7}, "10": {"effect": 0.0012292595207691194, "value": 5.0}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.0, "value": 5.1}, "15": {"effect": -0.26921162970364093, "value": 1.7}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7624548878044867, "simIndex": 44.0, "features": {"0": {"effect": 0.0, "value": 3.3}, "1": {"effect": 0.07206689428538084, "value": 5.1}, "2": {"effect": 0.0, "value": 1.3}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 0.0, "value": 2.3}, "5": {"effect": 0.0, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": -0.08943181231617928, "value": 1.3}, "9": {"effect": 0.04910173811018467, "value": 5.1}, "10": {"effect": -0.06515075460076332, "value": 2.3}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.0, "value": 5.1}, "15": {"effect": 0.06951083421707153, "value": 5.1}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9534687079013371, "simIndex": 34.0, "features": {"0": {"effect": 0.0, "value": 5.1}, "1": {"effect": 0.07206689428538084, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.0, "value": 2.3}, "5": {"effect": 0.0, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.00763442300260067, "value": 5.1}, "9": {"effect": 0.07011325798928737, "value": 5.1}, "10": {"effect": 0.007785310298204422, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": 0.0, "value": 5.1}, "14": {"effect": 0.0, "value": 5.1}, "15": {"effect": 0.06951083421707153, "value": 5.1}, "16": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9534687079013371, "simIndex": 35.0, "features": {"0": {"effect": 0.0, "value": 5.1}, "1": {"effect": 0.07206689428538084, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.0, "value": 5.1}, "4": {"effect": 0.0, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 5.1}, "8": {"effect": 0.00763442300260067, "value": 5.1}, "9": {"effect": 0.07011325798928737, "value": 5.1}, "10": {"effect": 0.007785310298204422, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}, "12": ...

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=1, link='identity', model_name='rf')
# Out:
# Student index 1 grades:
#          grades
# M01_3_N     2.7
# M02_3_N     4.0
# M03_3_N     1.7
# M04_3_N     2.0
# M05_3_N     5.1
# M06_3_N     3.3
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     1.7
# M10_3_N     3.7
# M11_3_N     5.0
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     1.7
# M17_3_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 0.900, Probability [1]: 0.100
# <div id='i3G83T9YMA9THZCPIV10S'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7263579881087923, "outValue": 0.09966762716779942, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": -0.04318961497396231, "value": 4.0}, "8": {"effect": -0.04035337872803211, "value": 1.7}, "9": {"effect": -0.27516499705612657, "value": 3.7}, "10": {"effect": 0.0012292595207691194, "value": 5.0}, "15": {"effect": -0.26921162970364093, "value": 1.7}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i3G83T9YMA9THZCPIV10S')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=4, link='identity', model_name='rf')
# Out:
# Student index 4 grades:
#          grades
# M01_3_N     5.1
# M02_3_N     5.1
# M03_3_N     5.1
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.047, Probability [1]: 0.953
# <div id='iJCS38KQMR9QUAPT9DUGS'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7263579881087923, "outValue": 0.9534687079013371, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": 0.07206689428538084, "value": 5.1}, "8": {"effect": 0.00763442300260067, "value": 5.1}, "9": {"effect": 0.07011325798928737, "value": 5.1}, "10": {"effect": 0.007785310298204422, "value": 5.1}, "15": {"effect": 0.06951083421707153, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJCS38KQMR9QUAPT9DUGS')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=5, link='identity', model_name='rf')
# Out:
# Student index 5 grades:
#          grades
# M01_3_N     5.1
# M02_3_N     5.1
# M03_3_N     5.1
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.047, Probability [1]: 0.953
# <div id='iL10J63MYO149P0D00QQ3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7263579881087923, "outValue": 0.9534687079013371, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": 0.07206689428538084, "value": 5.1}, "8": {"effect": 0.00763442300260067, "value": 5.1}, "9": {"effect": 0.07011325798928737, "value": 5.1}, "10": {"effect": 0.007785310298204422, "value": 5.1}, "15": {"effect": 0.06951083421707153, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iL10J63MYO149P0D00QQ3')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=6, link='identity', model_name='rf')
# Out:
# Student index 6 grades:
#          grades
# M01_3_N     1.3
# M02_3_N     1.7
# M03_3_N     1.0
# M04_3_N     1.7
# M05_3_N     1.7
# M06_3_N     1.0
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     1.3
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     1.3
# M17_3_N     5.1
# Status: 0, Prediction: [0], Probability [0]: 0.583, Probability [1]: 0.417
# <div id='iMVRYI4XJRDLZMATJCPH1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.7263579881087923, "outValue": 0.4166477331415796, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": -0.09610197395086288, "value": 1.7}, "8": {"effect": -0.08943181231617928, "value": 1.3}, "9": {"effect": 0.06383118100464344, "value": 5.1}, "10": {"effect": 0.007785310298204422, "value": 5.1}, "15": {"effect": -0.19579296000301838, "value": 1.3}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMVRYI4XJRDLZMATJCPH1')
#   );
# </script>
