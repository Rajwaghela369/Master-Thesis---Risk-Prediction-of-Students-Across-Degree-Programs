# %%
from functions import *
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import shap
from sklearn.model_selection import train_test_split
from collections import Counter

# %% [markdown]
# ## Data Preprocessing

# %%
path_1 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/BHT1_merged.csv"
path_2 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/BHT2_merged.csv"
path_3 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/BHT3_merged.csv"

BHT_1 = pd.read_csv(path_1, sep=',')
BHT_2 = pd.read_csv(path_2, sep=',')
BHT_3 = pd.read_csv(path_3, sep=',')

# %%
## set modules
module1 = ['M01_1_N', 'M02_1_N', 'M03_1_N', 'M04_1_N', 'M05_1_N', 'M06_1_N']

module2 = [
            'M01_2_N', 'M02_2_N', 'M03_2_N', 'M04_2_N', 'M05_2_N', 'M06_2_N',
            'M07_2_N', 'M08_2_N', 'M09_2_N', 'M10_2_N', 'M11_2_N', 'M12_2_N',]

module3 = ['M01_3_N', 'M02_3_N', 'M03_3_N', 'M04_3_N', 'M05_3_N', 'M06_3_N',
            'M07_3_N', 'M08_3_N', 'M09_3_N', 'M10_3_N', 'M11_3_N', 'M12_3_N',
            'M13_3_N', 'M14_3_N', 'M15_3_N', 'M16_3_N', 'M17_3_N']

# %% [markdown]
# ### Search Space / Param Grid

# %%
from hyperopt import *
search_space = {
    'criterion': hp.choice('criterion', ['entropy']),           # Choose between Gini & Entropy
    'max_features': hp.choice('max_features', [None]),  # Feature selection method
    'min_impurity_decrease': hp.uniform('min_impurity_decrease', 0.001, 0.02),
    'ccp_alpha': hp.uniform('ccp_alpha', 0.001, 0.02),
    'class_weight': 'balanced',       # Handle class imbalance
}

# %% [markdown]
# ## BHT semester 1

# %%
# Count occurrences of each unique value in the 'status' column
counter_1 = Counter(BHT_1['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_1[1]} | 0: {counter_1[0]}')
hpo = ModelTrainer(random_state=72)
x, y = hpo.split_data(BHT_1, module1)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 280 | 0: 59

# %%
model_1, feature_importance_1 = hpo.cross_validation_hpo(
    x=x, y=y,
    search_space=search_space, 
    folds=5,
    algo='dt'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 70.38trial/s, best loss: -0.7290404040404039]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               04
# 	 actual 1            22               34
#
# Model parameters:
# {'ccp_alpha': 0.009415406179158179, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.016751232997337866, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 72, 'splitter': 'best'}
#
# Balanced acc.: 63.69048%
# Validation accuracy.: 61.76471%
# Sensitivity score (for 1): 60.71429%
# Specificity score (for 0): 66.66667%
# F1 score.: 72.34043%
# False prediction: 38.23529%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 69.85trial/s, best loss: -0.6685353535353535]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            05               07
# 	 actual 1            13               43
#
# Model parameters:
# {'ccp_alpha': 0.0068221228617095335, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.014940191116882991, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 72, 'splitter': 'best'}
#
# Balanced acc.: 59.22619%
# Validation accuracy.: 70.58824%
# Sensitivity score (for 1): 76.78571%
# Specificity score (for 0): 41.66667%
# F1 score.: 81.13208%
# False prediction: 29.41176%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 73.66trial/s, best loss: -0.6905555555555555]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            06               06
# 	 actual 1            10               46
#
# Model parameters:
# {'ccp_alpha': 0.006532932095043745, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.016516806117849028, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 72, 'splitter': 'best'}
#
# Balanced acc.: 66.07143%
# Validation accuracy.: 76.47059%
# Sensitivity score (for 1): 82.14286%
# Specificity score (for 0): 50.00000%
# F1 score.: 85.18519%
# False prediction: 23.52941%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 75.23trial/s, best loss: -0.6757070707070707]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               04
# 	 actual 1            19               37
#
# Model parameters:
# {'ccp_alpha': 0.006731101691642528, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01917776907138736, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 72, 'splitter': 'best'}
#
# Balanced acc.: 66.36905%
# Validation accuracy.: 66.17647%
# Sensitivity score (for 1): 66.07143%
# Specificity score (for 0): 66.66667%
# F1 score.: 76.28866%
# False prediction: 33.82353%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 66.59trial/s, best loss: -0.667020202020202]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            10               01
# 	 actual 1            16               40
#
# Model parameters:
# {'ccp_alpha': 0.004987373368093246, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01915105159430959, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 72, 'splitter': 'best'}
#
# Balanced acc.: 81.16883%
# Validation accuracy.: 74.62687%
# Sensitivity score (for 1): 71.42857%
# Specificity score (for 0): 90.90909%
# F1 score.: 82.47423%
# False prediction: 25.37313%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 67.30519%
# Standard Deviation of Balanced Accuracy: +/- 7.388
#
# Mean Accuracy: 69.92537%
# Standard Deviation of Accuracy: +/- 5.404
#
# Mean Sensitivity: 71.42857%
# Standard Deviation of Sensitivity: +/- 7.576
#
# Mean Specificity: 63.18182%
# Standard Deviation of Specificity: +/- 16.910
#
# Mean False Predictions: 30.07463%
# Standard Deviation of False Predictions: +/- 5.404
# best model is from 5 fold: DecisionTreeClassifier(ccp_alpha=0.004987373368093246, class_weight='balanced',
#                        criterion='entropy',
#                        min_impurity_decrease=0.01915105159430959,
#                        random_state=72)

# %%
feature_importance_1
# Out:
# <style type="text/css">
# #T_3b0a3_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_3b0a3_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 39.6%, transparent 39.6%);
# }
# #T_3b0a3_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 29.8%, transparent 29.8%);
# }
# #T_3b0a3_row3_col1, #T_3b0a3_row4_col1, #T_3b0a3_row5_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_3b0a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b0a3_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_3b0a3_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b0a3_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_3b0a3_row0_col0" class="data row0 col0" >M05_1_N</td>
#       <td id="T_3b0a3_row0_col1" class="data row0 col1" >0.590442</td>
#     </tr>
#     <tr>
#       <th id="T_3b0a3_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_3b0a3_row1_col0" class="data row1 col0" >M01_1_N</td>
#       <td id="T_3b0a3_row1_col1" class="data row1 col1" >0.233635</td>
#     </tr>
#     <tr>
#       <th id="T_3b0a3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3b0a3_row2_col0" class="data row2 col0" >M04_1_N</td>
#       <td id="T_3b0a3_row2_col1" class="data row2 col1" >0.175923</td>
#     </tr>
#     <tr>
#       <th id="T_3b0a3_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_3b0a3_row3_col0" class="data row3 col0" >M02_1_N</td>
#       <td id="T_3b0a3_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b0a3_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_3b0a3_row4_col0" class="data row4 col0" >M03_1_N</td>
#       <td id="T_3b0a3_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b0a3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3b0a3_row5_col0" class="data row5 col0" >M06_1_N</td>
#       <td id="T_3b0a3_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer = shap.TreeExplainer(model_1['model'], model_1['x_train'])
shap_values = explainer(model_1['x_test'])

plt.title('Shap Feature Importance (sem1)', fontsize=16)
shap.plots.bar(shap_values[...,1])

# %%
shap.plots.violin(shap_values[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values[...,1], link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iUZT6TDCWV57A16SITLCD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5733289924030143, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "explanations": [{"outValue": 0.7165991895412045, "simIndex": 45.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000124935942, "simIndex": 63.0, "features": {"0": {"effect": 0.14253679513931275, "value": 1.3}, "1": {"effect": 0.0, "value": 1.7}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.09419275313615799, "value": 5.1}, "4": {"effect": 0.18994147181510926, "value": 5.1}, "5": {"effect": 0.0, "value": 1.7}}}, {"outValue": 0.7165991895412045, "simIndex": 44.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7165991895412045, "simIndex": 43.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7165991895412045, "simIndex": 46.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7165991895412045, "simIndex": 42.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 1.0}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 1.0000000124935942, "simIndex": 64.0, "features": {"0": {"effect": 0.14253679513931275, "value": 1.7}, "1": {"effect": 0.0, "value": 1.0}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.09419275313615799, "value": 5.1}, "4": {"effect": 0.18994147181510926, "value": 5.1}, "5": {"effect": 0.0, "value": 1.0}}}, {"outValue": 0.7165991895412045, "simIndex": 47.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7165991895412045, "simIndex": 41.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.7165991895412045, "simIndex": 48.0, "features": {"0": {"effect": -0.03348277576267719, "value": 5.1}, "1": {"effect": 0.0, "value": 5.1}, "2": {"effect": 0.0, "value": 5.1}, "3": {"effect": 0.010444357693195343, "value": 5.1}, "4": {"effect": 0.16630861520767212, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.30326595199750245, "simIndex": 15.0, "features": {"0": {"effect": -0.013091727644205093, "value": 1.7}, "1": {"effect": 0.0, "value": 2.7}, "2": {"effect": 0.0, "value": 1.0}, "3": {"effect": -0.036994170546531674, "value": 1.7}, "4": {"effect": -0.21997714221477507, "value": 2.0}, "5": {"effect": 0.0, "value": 2.0}}}, {"outValue": 0.31707314786957086, "simIndex": 24.0, "features": {"0": {"effect": -0.11031894445419312, "value" ...

# %%
hpo.plot_shap_force(model=model_1, shap_values=shap_values, student_index=11, link='logit', model_name='dt')
# Out:
# Student index 11 grades:
#          grades
# M01_1_N     2.7
# M02_1_N     1.0
# M03_1_N     5.1
# M04_1_N     2.7
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 0.683, Probability [1]: 0.317
# <div id='iLZUPQX71G24KI2ZEAUS3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5733289924030143, "outValue": 0.31707314786957086, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": -0.11031894445419312, "value": 2.7}, "3": {"effect": -0.21617263346910476, "value": 2.7}, "4": {"effect": 0.07023573338985444, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iLZUPQX71G24KI2ZEAUS3')
#   );
# </script>

# %%
hpo.plot_shap_force(model=model_1, shap_values=shap_values, student_index=24, link='logit', model_name='dt')
# Out:
# Student index 24 grades:
#          grades
# M01_1_N     1.7
# M02_1_N     1.7
# M03_1_N     1.3
# M04_1_N     2.7
# M05_1_N     1.7
# M06_1_N     1.3
# Status: 0, Prediction: [0], Probability [0]: 0.697, Probability [1]: 0.303
# <div id='iL37NAR3VRO4H99ISWYWR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5733289924030143, "outValue": 0.30326595199750245, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": -0.013091727644205093, "value": 1.7}, "3": {"effect": -0.036994170546531674, "value": 2.7}, "4": {"effect": -0.21997714221477507, "value": 1.7}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iL37NAR3VRO4H99ISWYWR')
#   );
# </script>

# %%
hpo.plot_shap_force(model=model_1, shap_values=shap_values, student_index=10, link='logit', model_name='dt')
# Out:
# Student index 10 grades:
#          grades
# M01_1_N     1.7
# M02_1_N     2.7
# M03_1_N     1.0
# M04_1_N     1.7
# M05_1_N     2.0
# M06_1_N     2.0
# Status: 1, Prediction: [0], Probability [0]: 0.697, Probability [1]: 0.303
# <div id='i5SSV986DXNQMKYV34A32'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5733289924030143, "outValue": 0.30326595199750245, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": -0.013091727644205093, "value": 1.7}, "3": {"effect": -0.036994170546531674, "value": 1.7}, "4": {"effect": -0.21997714221477507, "value": 2.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i5SSV986DXNQMKYV34A32')
#   );
# </script>

# %% [markdown]
# ## BHT semester 2

# %%
# Count occurrences of each unique value in the 'status' column
counter_2 = Counter(BHT_2['status'])
print(f'Quantity of Drop Out and Degree in THL-2: \n 1: {counter_2[1]} | 0: {counter_2[0]}')
hpo2 = ModelTrainer(random_state=64)
x2, y2 = hpo2.split_data(BHT_2, module2)
# Out:
# Quantity of Drop Out and Degree in THL-2:
#  1: 190 | 0: 47

# %%
models_2, feature_importance_2 = hpo2.cross_validation_hpo(
    x=x2, y=y2,
    search_space=search_space, 
    folds=5,
    algo='dt'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 66.98trial/s, best loss: -0.6615399385560675]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            04               06
# 	 actual 1            09               29
#
# Model parameters:
# {'ccp_alpha': 0.008131155068386622, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.018224955917609323, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 64, 'splitter': 'best'}
#
# Balanced acc.: 58.15789%
# Validation accuracy.: 68.75000%
# Sensitivity score (for 1): 76.31579%
# Specificity score (for 0): 40.00000%
# F1 score.: 79.45205%
# False prediction: 31.25000%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 69.30trial/s, best loss: -0.610668202764977]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            03               07
# 	 actual 1            05               33
#
# Model parameters:
# {'ccp_alpha': 0.012214996544802983, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01752943387250193, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 64, 'splitter': 'best'}
#
# Balanced acc.: 58.42105%
# Validation accuracy.: 75.00000%
# Sensitivity score (for 1): 86.84211%
# Specificity score (for 0): 30.00000%
# F1 score.: 84.61538%
# False prediction: 25.00000%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 69.54trial/s, best loss: -0.6486827956989247]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               02
# 	 actual 1            10               28
#
# Model parameters:
# {'ccp_alpha': 0.01953704278472124, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01450524831717898, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 64, 'splitter': 'best'}
#
# Balanced acc.: 75.73099%
# Validation accuracy.: 74.46809%
# Sensitivity score (for 1): 73.68421%
# Specificity score (for 0): 77.77778%
# F1 score.: 82.35294%
# False prediction: 25.53191%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 67.87trial/s, best loss: -0.6010061443932412]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            04               05
# 	 actual 1            09               29
#
# Model parameters:
# {'ccp_alpha': 0.007228994574322603, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.018259217590104217, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 64, 'splitter': 'best'}
#
# Balanced acc.: 60.38012%
# Validation accuracy.: 70.21277%
# Sensitivity score (for 1): 76.31579%
# Specificity score (for 0): 44.44444%
# F1 score.: 80.55556%
# False prediction: 29.78723%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 70.26trial/s, best loss: -0.6276344086021506]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            04               05
# 	 actual 1            02               36
#
# Model parameters:
# {'ccp_alpha': 0.018178295943511523, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01893308447600616, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 64, 'splitter': 'best'}
#
# Balanced acc.: 69.59064%
# Validation accuracy.: 85.10638%
# Sensitivity score (for 1): 94.73684%
# Specificity score (for 0): 44.44444%
# F1 score.: 91.13924%
# False prediction: 14.89362%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 64.45614%
# Standard Deviation of Balanced Accuracy: +/- 7.017
#
# Mean Accuracy: 74.70745%
# Standard Deviation of Accuracy: +/- 5.727
#
# Mean Sensitivity: 81.57895%
# Standard Deviation of Sensitivity: +/- 7.982
#
# Mean Specificity: 47.33333%
# Standard Deviation of Specificity: +/- 16.111
#
# Mean False Predictions: 25.29255%
# Standard Deviation of False Predictions: +/- 5.727
# best model is from 3 fold: DecisionTreeClassifier(ccp_alpha=0.01953704278472124, class_weight='balanced',
#                        criterion='entropy',
#                        min_impurity_decrease=0.01450524831717898,
#                        random_state=64)

# %%
feature_importance_2
# Out:
# <style type="text/css">
# #T_f776d_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_f776d_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 46.0%, transparent 46.0%);
# }
# #T_f776d_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 40.2%, transparent 40.2%);
# }
# #T_f776d_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 30.6%, transparent 30.6%);
# }
# #T_f776d_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 29.3%, transparent 29.3%);
# }
# #T_f776d_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 29.1%, transparent 29.1%);
# }
# #T_f776d_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 15.1%, transparent 15.1%);
# }
# #T_f776d_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 14.8%, transparent 14.8%);
# }
# #T_f776d_row8_col1, #T_f776d_row9_col1, #T_f776d_row10_col1, #T_f776d_row11_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_f776d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f776d_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_f776d_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f776d_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_f776d_row0_col0" class="data row0 col0" >M07_2_N</td>
#       <td id="T_f776d_row0_col1" class="data row0 col1" >0.327675</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_f776d_row1_col0" class="data row1 col0" >M10_2_N</td>
#       <td id="T_f776d_row1_col1" class="data row1 col1" >0.150839</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_f776d_row2_col0" class="data row2 col0" >M01_2_N</td>
#       <td id="T_f776d_row2_col1" class="data row2 col1" >0.131699</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_f776d_row3_col0" class="data row3 col0" >M02_2_N</td>
#       <td id="T_f776d_row3_col1" class="data row3 col1" >0.100389</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_f776d_row4_col0" class="data row4 col0" >M04_2_N</td>
#       <td id="T_f776d_row4_col1" class="data row4 col1" >0.096111</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_f776d_row5_col0" class="data row5 col0" >M03_2_N</td>
#       <td id="T_f776d_row5_col1" class="data row5 col1" >0.095343</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_f776d_row6_col0" class="data row6 col0" >M11_2_N</td>
#       <td id="T_f776d_row6_col1" class="data row6 col1" >0.049501</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_f776d_row7_col0" class="data row7 col0" >M05_2_N</td>
#       <td id="T_f776d_row7_col1" class="data row7 col1" >0.048444</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_f776d_row8_col0" class="data row8 col0" >M06_2_N</td>
#       <td id="T_f776d_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_f776d_row9_col0" class="data row9 col0" >M08_2_N</td>
#       <td id="T_f776d_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row10" class="row_heading level0 row10" >8</th>
#       <td id="T_f776d_row10_col0" class="data row10 col0" >M09_2_N</td>
#       <td id="T_f776d_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f776d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f776d_row11_col0" class="data row11 col0" >M12_2_N</td>
#       <td id="T_f776d_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer2 = shap.TreeExplainer(models_2['model'], models_2['x_train'])
shap_values2 = explainer2(models_2['x_test'])

plt.title('Shap Feature Importance (sem2)', fontsize=16)
shap.plots.bar(shap_values2[...,1])

# %%
shap.plots.violin(shap_values2[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values2[...,1], link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i5SZD0AH4ZKHB5RIYAUVM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6575262054507344, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"],
'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6575262054507344, "outValue": 0.13207547091736482, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.07036667004227638, "value": 2.0}, "1": {"effect": -0.21399846479296683, "value": 2.3}, "2": {"effect": -0.15455890499055386, "value": 1.7}, "3": {"effect": -0.08596665918827057, "value": 3.0}, "4": {"effect": -0.035851852148771284, "value": 2.7}, "6": {"effect": -0.029052633345127105, "value": 2.7}, "9": {"effect": -0.059166667759418486, "value": 4.0}, "10": {"effect": -0.017222222350537778, "value": 3.3}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i3FUH69S537S52Z80G0FS')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, shap_values=shap_values2, student_index=11, link='logit', model_name='dt')
# Out:
# Student index 11 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 0, Prediction: [1], Probability [0]: 0.222, Probability [1]: 0.778
# <div id='iY1RIBAPVR34S2I0D56YY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6575262054507344, "outValue": 0.7777777895596533, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.14693703271448613, "value": 5.1}, "1": {"effect": 0.049276452511548996, "value": 5.1}, "2": {"effect": 0.04457274347543717, "value": 5.1}, "3": {"effect": 0.07187777772545814, "value": 5.1}, "4": {"effect": 0.02948148177936673, "value": 5.1}, "6": {"effect": -0.0027420634031295778, "value": 5.1}, "9": {"effect": 0.06861111357808113, "value": 5.1}, "10": {"effect": 0.006111111156642437, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iY1RIBAPVR34S2I0D56YY')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, shap_values=shap_values2, student_index=2, link='logit', model_name='dt')
# Out:
# Student index 2 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.222, Probability [1]: 0.778
# <div id='iHRU89HJ0ZAE5QFPM5O3A'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6575262054507344, "outValue": 0.7777777895596533, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.14693703271448613, "value": 5.1}, "1": {"effect": 0.049276452511548996, "value": 5.1}, "2": {"effect": 0.04457274347543717, "value": 5.1}, "3": {"effect": 0.07187777772545814, "value": 5.1}, "4": {"effect": 0.02948148177936673, "value": 5.1}, "6": {"effect": -0.0027420634031295778, "value": 5.1}, "9": {"effect": 0.06861111357808113, "value": 5.1}, "10": {"effect": 0.006111111156642437, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iHRU89HJ0ZAE5QFPM5O3A')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, shap_values=shap_values2, student_index=5, link='logit', model_name='dt')
# Out:
# Student index 5 grades:
#          grades
# M01_2_N     1.3
# M02_2_N     1.7
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='iO7VOIMZU8QPE47IG7OG1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6575262054507344, "outValue": 0.9999999996353595, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.08626295823603869, "value": 1.3}, "1": {"effect": -0.019235290549695493, "value": 1.7}, "2": {"effect": 0.08087861374020576, "value": 5.1}, "3": {"effect": 0.06122592657804489, "value": 5.1}, "4": {"effect": 0.05644444487988949, "value": 5.1}, "6": {"effect": 0.062452696561813355, "value": 5.1}, "9": {"effect": 0.00833333358168602, "value": 5.1}, "10": {"effect": 0.006111111156642437, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iO7VOIMZU8QPE47IG7OG1')
#   );
# </script>

# %% [markdown]
# ## BHT semester 3

# %%
# Count occurrences of each unique value in the 'status' column
counter_3 = Counter(BHT_3['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_3[1]} | 0: {counter_3[0]}')
hpo3 = ModelTrainer(random_state=65)
x3, y3 = hpo3.split_data(BHT_3, module3)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 134 | 0: 48

# %%
models_3, feature_importance_3 = hpo3.cross_validation_hpo(
    x=x3, y=y3,
    search_space=search_space, 
    folds=5,
    algo='dt'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 60.98trial/s, best loss: -0.6998917748917748]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            06               04
# 	 actual 1            06               21
#
# Model parameters:
# {'ccp_alpha': 0.012216384035279776, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.009754221598124863, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 65, 'splitter': 'best'}
#
# Balanced acc.: 68.88889%
# Validation accuracy.: 72.97297%
# Sensitivity score (for 1): 77.77778%
# Specificity score (for 0): 60.00000%
# F1 score.: 80.76923%
# False prediction: 27.02703%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 72.80trial/s, best loss: -0.6116883116883117]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            05               05
# 	 actual 1            04               23
#
# Model parameters:
# {'ccp_alpha': 0.016155168113870615, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.011304979249737737, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 65, 'splitter': 'best'}
#
# Balanced acc.: 67.59259%
# Validation accuracy.: 75.67568%
# Sensitivity score (for 1): 85.18519%
# Specificity score (for 0): 50.00000%
# F1 score.: 83.63636%
# False prediction: 24.32432%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 73.48trial/s, best loss: -0.6238095238095238]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            03               06
# 	 actual 1            03               24
#
# Model parameters:
# {'ccp_alpha': 0.006767947908071954, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.019940415231472115, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 65, 'splitter': 'best'}
#
# Balanced acc.: 61.11111%
# Validation accuracy.: 75.00000%
# Sensitivity score (for 1): 88.88889%
# Specificity score (for 0): 33.33333%
# F1 score.: 84.21053%
# False prediction: 25.00000%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 72.81trial/s, best loss: -0.6203463203463203]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            05               04
# 	 actual 1            06               21
#
# Model parameters:
# {'ccp_alpha': 0.01893171666111964, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01628013106815573, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 65, 'splitter': 'best'}
#
# Balanced acc.: 66.66667%
# Validation accuracy.: 72.22222%
# Sensitivity score (for 1): 77.77778%
# Specificity score (for 0): 55.55556%
# F1 score.: 80.76923%
# False prediction: 27.77778%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 65.24trial/s, best loss: -0.6950757575757576]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            03               07
# 	 actual 1            08               18
#
# Model parameters:
# {'ccp_alpha': 0.019784692421218497, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.006974746763135385, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 65, 'splitter': 'best'}
#
# Balanced acc.: 49.61538%
# Validation accuracy.: 58.33333%
# Sensitivity score (for 1): 69.23077%
# Specificity score (for 0): 30.00000%
# F1 score.: 70.58824%
# False prediction: 41.66667%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 62.77493%
# Standard Deviation of Balanced Accuracy: +/- 7.095
#
# Mean Accuracy: 70.84084%
# Standard Deviation of Accuracy: +/- 6.381
#
# Mean Sensitivity: 79.77208%
# Standard Deviation of Sensitivity: +/- 6.804
#
# Mean Specificity: 45.77778%
# Standard Deviation of Specificity: +/- 11.996
#
# Mean False Predictions: 29.15916%
# Standard Deviation of False Predictions: +/- 6.381
# best model is from 1 fold: DecisionTreeClassifier(ccp_alpha=0.012216384035279776, class_weight='balanced',
#                        criterion='entropy',
#                        min_impurity_decrease=0.009754221598124863,
#                        random_state=65)

# %%
feature_importance_3
# Out:
# <style type="text/css">
# #T_3cd3f_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_3cd3f_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 63.2%, transparent 63.2%);
# }
# #T_3cd3f_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 52.7%, transparent 52.7%);
# }
# #T_3cd3f_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 40.6%, transparent 40.6%);
# }
# #T_3cd3f_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 33.9%, transparent 33.9%);
# }
# #T_3cd3f_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 28.4%, transparent 28.4%);
# }
# #T_3cd3f_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 16.8%, transparent 16.8%);
# }
# #T_3cd3f_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 13.6%, transparent 13.6%);
# }
# #T_3cd3f_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 9.7%, transparent 9.7%);
# }
# #T_3cd3f_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 6.2%, transparent 6.2%);
# }
# #T_3cd3f_row10_col1, #T_3cd3f_row11_col1, #T_3cd3f_row12_col1, #T_3cd3f_row13_col1, #T_3cd3f_row14_col1, #T_3cd3f_row15_col1, #T_3cd3f_row16_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_3cd3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cd3f_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_3cd3f_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cd3f_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_3cd3f_row0_col0" class="data row0 col0" >M10_3_N</td>
#       <td id="T_3cd3f_row0_col1" class="data row0 col1" >0.273916</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_3cd3f_row1_col0" class="data row1 col0" >M13_3_N</td>
#       <td id="T_3cd3f_row1_col1" class="data row1 col1" >0.173042</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_3cd3f_row2_col0" class="data row2 col0" >M01_3_N</td>
#       <td id="T_3cd3f_row2_col1" class="data row2 col1" >0.144361</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_3cd3f_row3_col0" class="data row3 col0" >M12_3_N</td>
#       <td id="T_3cd3f_row3_col1" class="data row3 col1" >0.111343</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_3cd3f_row4_col0" class="data row4 col0" >M03_3_N</td>
#       <td id="T_3cd3f_row4_col1" class="data row4 col1" >0.092919</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_3cd3f_row5_col0" class="data row5 col0" >M04_3_N</td>
#       <td id="T_3cd3f_row5_col1" class="data row5 col1" >0.077659</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_3cd3f_row6_col0" class="data row6 col0" >M02_3_N</td>
#       <td id="T_3cd3f_row6_col1" class="data row6 col1" >0.045950</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_3cd3f_row7_col0" class="data row7 col0" >M11_3_N</td>
#       <td id="T_3cd3f_row7_col1" class="data row7 col1" >0.037197</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_3cd3f_row8_col0" class="data row8 col0" >M08_3_N</td>
#       <td id="T_3cd3f_row8_col1" class="data row8 col1" >0.026587</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_3cd3f_row9_col0" class="data row9 col0" >M09_3_N</td>
#       <td id="T_3cd3f_row9_col1" class="data row9 col1" >0.017025</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row10" class="row_heading level0 row10" >6</th>
#       <td id="T_3cd3f_row10_col0" class="data row10 col0" >M07_3_N</td>
#       <td id="T_3cd3f_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row11" class="row_heading level0 row11" >5</th>
#       <td id="T_3cd3f_row11_col0" class="data row11 col0" >M06_3_N</td>
#       <td id="T_3cd3f_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_3cd3f_row12_col0" class="data row12 col0" >M05_3_N</td>
#       <td id="T_3cd3f_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3cd3f_row13_col0" class="data row13 col0" >M14_3_N</td>
#       <td id="T_3cd3f_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3cd3f_row14_col0" class="data row14 col0" >M15_3_N</td>
#       <td id="T_3cd3f_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3cd3f_row15_col0" class="data row15 col0" >M16_3_N</td>
#       <td id="T_3cd3f_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cd3f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3cd3f_row16_col0" class="data row16 col0" >M17_3_N</td>
#       <td id="T_3cd3f_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Shap Global explainations
import shap
explainer3 = shap.TreeExplainer(models_3['model'], models_3['x_train'])
shap_values3 = explainer3(models_3['x_test'])

plt.title('Shap Feature Importance (sem3)', fontsize=16)
shap.plots.bar(shap_values3[..., 1])

# %%
shap.plots.violin(shap_values3[..., 1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values3[..., 1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='
"value": 2.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iWA5Z0TABWM6LBVM2A28V')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, shap_values=shap_values3, student_index=14, link='identity', model_name='dt')
# Out:
# Student index 14 grades:
#          grades
# M01_3_N     2.0
# M02_3_N     2.0
# M03_3_N     2.0
# M04_3_N     3.0
# M05_3_N     1.7
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     2.0
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.000, Probability [1]: 1.000
# <div id='iNUUGSEZBZ3CTGQYQLQ7M'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6898903680501178, "outValue": 0.999999995893021, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": 0.01878543209284544, "value": 2.0}, "1": {"effect": -0.011999999955296516, "value": 2.0}, "2": {"effect": -0.011166666224598885, "value": 2.0}, "3": {"effect": -0.030000000298023223, "value": 3.0}, "4": {"effect": 0.056666667386889455, "value": 1.7}, "5": {"effect": -0.007999999523162842, "value": 5.1}, "7": {"effect": 0.010000000298023224, "value": 5.1}, "8": {"effect": 0.17294139999896288, "value": 5.1}, "9": {"effect": -0.007500000223517418, "value": 2.0}, "10": {"effect": -0.0030000000074505806, "value": 5.1}, "11": {"effect": 0.011333333514630794, "value": 5.1}, "12": {"effect": 0.11652701526880264, "value": 5.1}, "13": {"effect": 0.045355780124664305, "value": 5.1}, "14": {"effect": 0.0030000000074505806, "value": 5.1}, "15": {"effect": -0.04750000111758709, "value": 5.1}, "16": {"effect": -0.0053333334997296335, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iNUUGSEZBZ3CTGQYQLQ7M')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, shap_values=shap_values3, student_index=24, link='identity', model_name='dt')
# Out:
# Student index 24 grades:
#          grades
# M01_3_N     3.3
# M02_3_N     2.3
# M03_3_N     5.1
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     2.3
# M15_3_N     5.1
# M16_3_N     4.0
# M17_3_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 1.000, Probability [1]: 0.000
# <div id='iKOZKR1DRIVFR5HB003UQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6898903680501178, "outValue": -4.516760965245226e-09, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": -0.003305535167455673, "value": 3.3}, "1": {"effect": -0.22233333304524422, "value": 2.3}, "2": {"effect": -0.07749999910593033, "value": 5.1}, "3": {"effect": 0.0030000007152557375, "value": 5.1}, "4": {"effect": -0.1650000010430813, "value": 5.1}, "5": {"effect": -0.0454999989271164, "value": 5.1}, "7": {"effect": 0.018333333432674407, "value": 5.1}, "8": {"effect": 0.04872070025652647, "value": 5.1}, "9": {"effect": 0.017500000223517418, "value": 5.1}, "10": {"effect": -0.01350000023841858, "value": 5.1}, "11": {"effect": 0.008333333432674409, "value": 5.1}, "12": {"effect": 0.004166666492819786, "value": 5.1}, "13": {"effect": -0.2776388728618622, "value": 2.3}, "14": {"effect": 0.0030000000074505806, "value": 5.1}, "15": {"effect": 0.017166666761040686, "value": 4.0}, "16": {"effect": -0.0053333334997296335, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iKOZKR1DRIVFR5HB003UQ')
#   );
# </script>
