# %%
from functions import *
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import shap
from collections import Counter

# %% [markdown]
# ## Data Preprocessing

# %%
path_1 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL1_merged.csv"
path_2 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL2_merged.csv"
path_3 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL3_merged.csv"

THL_1 = pd.read_csv(path_1, sep=',')
THL_2 = pd.read_csv(path_2, sep=',')
THL_3 = pd.read_csv(path_3, sep=',')

# %%
## set modules
module1 = ['M01_1_N', 'M02_1_N', 'M03_1_N', 'M04_1_N', 'M05_1_N', 'M06_1_N']

module2 = [
            'M01_2_N', 'M02_2_N', 'M03_2_N', 'M04_2_N', 'M05_2_N', 'M06_2_N',
            'M07_2_N', 'M08_2_N', 'M09_2_N', 'M10_2_N', 'M11_2_N', 'M12_2_N',]

module3 = ['M01_3_N', 'M02_3_N', 'M03_3_N', 'M04_3_N', 'M05_3_N', 'M06_3_N',
            'M07_3_N', 'M08_3_N', 'M09_3_N', 'M10_3_N', 'M11_3_N', 'M12_3_N',
            'M13_3_N', 'M14_3_N', 'M15_3_N', 'M16_3_N', 'M17_3_N']

# %% [markdown]
# ### Train test split function

# %% [markdown]
# ### Search Space / Param Grid

# %%
from hyperopt import *
search_space = {
    'fit_intercept': hp.choice('fit_intercept', [True]),
    'solver': hp.choice('solver', ['liblinear', 'lbfgs']),
    'C': hp.uniform('C', 0.018, 0.03),
    'penalty': hp.choice('penalty', ['l2']),
    'class_weight':'balanced',
}

# %% [markdown]
# ## THL semester 1

# %%
# Count occurrences of each unique value in the 'status' column
counter_1 = Counter(THL_1['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_1[1]} | 0: {counter_1[0]}')
hpo = ModelTrainer(random_state=42)
x, y = hpo.split_data(THL_1, module1)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 502 | 0: 118

# %%
models_1, feature_importance = hpo.cross_validation_hpo(
    x=x, y=y,
    search_space=search_space, 
    folds=5,
    algo='lr'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 58.55trial/s, best loss: -0.7333698830409356]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            16               07
# 	 actual 1            25               76
#
# Model parameters:
# {'C': 0.02354975725927989, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 72.40637%
# Validation accuracy.: 74.19355%
# Sensitivity score (for 1): 75.24752%
# Specificity score (for 0): 69.56522%
# F1 score.: 82.60870%
# False prediction: 25.80645%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 54.94trial/s, best loss: -0.7001730019493178]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            16               07
# 	 actual 1            15               86
#
# Model parameters:
# {'C': 0.028149881215223244, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 77.35687%
# Validation accuracy.: 82.25806%
# Sensitivity score (for 1): 85.14851%
# Specificity score (for 0): 69.56522%
# F1 score.: 88.65979%
# False prediction: 17.74194%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 46.00trial/s, best loss: -0.7419111435997402]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            17               07
# 	 actual 1            20               80
#
# Model parameters:
# {'C': 0.025711676679706457, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 75.41667%
# Validation accuracy.: 78.22581%
# Sensitivity score (for 1): 80.00000%
# Specificity score (for 0): 70.83333%
# F1 score.: 85.56150%
# False prediction: 21.77419%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 35.07trial/s, best loss: -0.7123196881091618]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            20               04
# 	 actual 1            30               70
#
# Model parameters:
# {'C': 0.026503022509473003, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 76.66667%
# Validation accuracy.: 72.58065%
# Sensitivity score (for 1): 70.00000%
# Specificity score (for 0): 83.33333%
# F1 score.: 80.45977%
# False prediction: 27.41935%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 53.05trial/s, best loss: -0.7510908057179988]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               11
# 	 actual 1            27               73
#
# Model parameters:
# {'C': 0.023962330588116688, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 63.58333%
# Validation accuracy.: 69.35484%
# Sensitivity score (for 1): 73.00000%
# Specificity score (for 0): 54.16667%
# F1 score.: 79.34783%
# False prediction: 30.64516%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 73.08598%
# Standard Deviation of Balanced Accuracy: +/- 5.045
#
# Mean Accuracy: 75.32258%
# Standard Deviation of Accuracy: +/- 4.493
#
# Mean Sensitivity: 76.67921%
# Standard Deviation of Sensitivity: +/- 5.347
#
# Mean Specificity: 69.49275%
# Standard Deviation of Specificity: +/- 9.255
#
# Mean False Predictions: 24.67742%
# Standard Deviation of False Predictions: +/- 4.493
#
# best model is from 2 fold: LogisticRegression(C=0.028149881215223244, class_weight='balanced')

# %%
feature_importance
# Out:
# <style type="text/css">
# #T_28047_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
# }
# #T_28047_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 98.2%, transparent 98.2%);
# }
# #T_28047_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 97.8%, transparent 97.8%);
# }
# #T_28047_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 76.3%, transparent 76.3%);
# }
# #T_28047_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 76.2%, transparent 76.2%);
# }
# #T_28047_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 72.2%, transparent 72.2%);
# }
# </style>
# <table id="T_28047">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28047_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_28047_level0_col1" class="col_heading level0 col1" >coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28047_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28047_row0_col0" class="data row0 col0" >M01_1_N</td>
#       <td id="T_28047_row0_col1" class="data row0 col1" >0.295200</td>
#     </tr>
#     <tr>
#       <th id="T_28047_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28047_row1_col0" class="data row1 col0" >M02_1_N</td>
#       <td id="T_28047_row1_col1" class="data row1 col1" >0.284290</td>
#     </tr>
#     <tr>
#       <th id="T_28047_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_28047_row2_col0" class="data row2 col0" >M05_1_N</td>
#       <td id="T_28047_row2_col1" class="data row2 col1" >0.282350</td>
#     </tr>
#     <tr>
#       <th id="T_28047_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28047_row3_col0" class="data row3 col0" >M04_1_N</td>
#       <td id="T_28047_row3_col1" class="data row3 col1" >0.155040</td>
#     </tr>
#     <tr>
#       <th id="T_28047_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_28047_row4_col0" class="data row4 col0" >M06_1_N</td>
#       <td id="T_28047_row4_col1" class="data row4 col1" >0.154710</td>
#     </tr>
#     <tr>
#       <th id="T_28047_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_28047_row5_col0" class="data row5 col0" >M03_1_N</td>
#       <td id="T_28047_row5_col1" class="data row5 col1" >0.131320</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer = shap.Explainer(models_1['model'], models_1['x_train'])
shap_values = explainer(models_1['x_test'])

plt.title('Shap Feature Importance (sem1)', fontsize=16)
shap.plots.bar(shap_values)

# %%
shap.plots.violin(shap_values, show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values, link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i1A37HHK0GN9OX4Z7XVWR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.3888124113024105, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "explanations": [{"outValue": 1.1418448353731088, "simIndex": 65.0, "features": {"0": {"effect": 0.18686072351563646, "value": 5.1}, "1": {"effect": 0.18820092989669093, "value": 5.1}, "2": {"effect": 0.06999519238693024, "value": 5.1}, "3": {"effect": 0.0403116752051291, "value": 5.1}, "4": {"effect": 0.22248899906166744, "value": 5.1}, "5": {"effect": 0.045174904004644224, "value": 5.1}}}, {"outValue": 1.1418448353731088, "simIndex": 66.0, "features": {"0": {"effect": 0.18686072351563646, "value": 5.1}, "1": {"effect": 0.18820092989669093, "value": 5.1}, "2": {"effect": 0.06999519238693024, "value": 5.1}, "3": {"effect": 0.0403116752051291, "value": 5.1}, "4": {"effect": 0.22248899906166744, "value": 5.1}, "5": {"effect": 0.045174904004644224, "value": 5.1}}}, {"outValue": 1.1418448353731088, "simIndex": 67.0, "features": {"0": {"effect": 0.18686072351563646, "value": 5.1}, "1": {"effect": 0.18820092989669093, "value": 5.1}, "2": {"effect": 0.06999519238693024, "value": 5.1}, "3": {"effect": 0.0403116752051291, "value": 5.1}, "4": {"effect": 0.22248899906166744, "value": 5.1}, "5": {"effect": 0.045174904004644224, "value": 5.1}}}, {"outValue": -0.8157668286855271, "simIndex": 13.0, "features": {"0": {"effect": -0.3444967841117709, "value": 3.3}, "1": {"effect": 0.18820092989669093, "value": 5.1}, "2": {"effect": 0.06999519238693024, "value": 5.1}, "3": {"effect
"value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iAWPW4UFWCTLE669HZUTZ')
#   );
# </script>

# %% [markdown]
# ## THL semester 2

# %%
# Count occurrences of each unique value in the 'status' column
counter_2 = Counter(THL_2['status'])
print(f'Quantity of Drop Out and Degree in THL-2: \n 1: {counter_2[1]} | 0: {counter_2[0]}')
hpo2 = ModelTrainer(random_state=72)
x, y = hpo2.split_data(THL_2, module2)
# Out:
# Quantity of Drop Out and Degree in THL-2:
#  1: 315 | 0: 88

# %%
models_2, feature_importance2 = hpo2.cross_validation_hpo(
    x=x, y=y,
    search_space=search_space, 
    folds=5,
    algo='lr'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 60.09trial/s, best loss: -0.7508627450980392]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            10               08
# 	 actual 1            14               49
#
# Model parameters:
# {'C': 0.019277826671878526, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'liblinear', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 66.66667%
# Validation accuracy.: 72.83951%
# Sensitivity score (for 1): 77.77778%
# Specificity score (for 0): 55.55556%
# F1 score.: 81.66667%
# False prediction: 27.16049%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 58.58trial/s, best loss: -0.7297198879551822]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               05
# 	 actual 1            15               48
#
# Model parameters:
# {'C': 0.027644263484616346, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'liblinear', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 74.20635%
# Validation accuracy.: 75.30864%
# Sensitivity score (for 1): 76.19048%
# Specificity score (for 0): 72.22222%
# F1 score.: 82.75862%
# False prediction: 24.69136%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 62.14trial/s, best loss: -0.7334845938375351]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            15               03
# 	 actual 1            19               44
#
# Model parameters:
# {'C': 0.02771987940577081, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 76.58730%
# Validation accuracy.: 72.83951%
# Sensitivity score (for 1): 69.84127%
# Specificity score (for 0): 83.33333%
# F1 score.: 80.00000%
# False prediction: 27.16049%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 39.72trial/s, best loss: -0.7105210084033614]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            10               53
#
# Model parameters:
# {'C': 0.020038886161522013, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 74.41643%
# Validation accuracy.: 80.00000%
# Sensitivity score (for 1): 84.12698%
# Specificity score (for 0): 64.70588%
# F1 score.: 86.88525%
# False prediction: 20.00000%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 54.67trial/s, best loss: -0.7512100840336133]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            10               07
# 	 actual 1            12               51
#
# Model parameters:
# {'C': 0.02333063179188237, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 69.88796%
# Validation accuracy.: 76.25000%
# Sensitivity score (for 1): 80.95238%
# Specificity score (for 0): 58.82353%
# F1 score.: 84.29752%
# False prediction: 23.75000%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 72.35294%
# Standard Deviation of Balanced Accuracy: +/- 3.579
#
# Mean Accuracy: 75.44753%
# Standard Deviation of Accuracy: +/- 2.645
#
# Mean Sensitivity: 77.77778%
# Standard Deviation of Sensitivity: +/- 4.815
#
# Mean Specificity: 66.92810%
# Standard Deviation of Specificity: +/- 9.971
#
# Mean False Predictions: 24.55247%
# Standard Deviation of False Predictions: +/- 2.645
#
# best model is from 3 fold: LogisticRegression(C=0.02771987940577081, class_weight='balanced')

# %%
feature_importance2
# Out:
# <style type="text/css">
# #T_be330_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
# }
# #T_be330_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 99.5%, transparent 99.5%);
# }
# #T_be330_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 93.9%, transparent 93.9%);
# }
# #T_be330_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 93.4%, transparent 93.4%);
# }
# #T_be330_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 93.1%, transparent 93.1%);
# }
# #T_be330_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 91.3%, transparent 91.3%);
# }
# #T_be330_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 83.1%, transparent 83.1%);
# }
# #T_be330_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 77.2%, transparent 77.2%);
# }
# #T_be330_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 74.6%, transparent 74.6%);
# }
# #T_be330_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 62.1%, transparent 62.1%);
# }
# #T_be330_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.6%, red 49.6%, red 50.0%, transparent 50.0%);
# }
# #T_be330_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.8%, red 34.8%, red 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_be330">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be330_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_be330_level0_col1" class="col_heading level0 col1" >coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be330_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_be330_row0_col0" class="data row0 col0" >M09_2_N</td>
#       <td id="T_be330_row0_col1" class="data row0 col1" >0.251690</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_be330_row1_col0" class="data row1 col0" >M04_2_N</td>
#       <td id="T_be330_row1_col1" class="data row1 col1" >0.249380</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_be330_row2_col0" class="data row2 col0" >M05_2_N</td>
#       <td id="T_be330_row2_col1" class="data row2 col1" >0.221190</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_be330_row3_col0" class="data row3 col0" >M10_2_N</td>
#       <td id="T_be330_row3_col1" class="data row3 col1" >0.218670</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_be330_row4_col0" class="data row4 col0" >M11_2_N</td>
#       <td id="T_be330_row4_col1" class="data row4 col1" >0.217090</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be330_row5_col0" class="data row5 col0" >M06_2_N</td>
#       <td id="T_be330_row5_col1" class="data row5 col1" >0.207800</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be330_row6_col0" class="data row6 col0" >M07_2_N</td>
#       <td id="T_be330_row6_col1" class="data row6 col1" >0.166580</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row7" class="row_heading level0 row7" >0</th>
#       <td id="T_be330_row7_col0" class="data row7 col0" >M01_2_N</td>
#       <td id="T_be330_row7_col1" class="data row7 col1" >0.137010</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_be330_row8_col0" class="data row8 col0" >M02_2_N</td>
#       <td id="T_be330_row8_col1" class="data row8 col1" >0.124020</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_be330_row9_col0" class="data row9 col0" >M08_2_N</td>
#       <td id="T_be330_row9_col1" class="data row9 col1" >0.060880</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_be330_row10_col0" class="data row10 col0" >M12_2_N</td>
#       <td id="T_be330_row10_col1" class="data row10 col1" >-0.001830</td>
#     </tr>
#     <tr>
#       <th id="T_be330_level0_row11" class="row_heading level0 row11" >2</th>
#       <td id="T_be330_row11_col0" class="data row11 col0" >M03_2_N</td>
#       <td id="T_be330_row11_col1" class="data row11 col1" >-0.076520</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer2 = shap.Explainer(models_2['model'], models_2['x_train'])
shap_values2 = explainer2(models_2['x_test'])

plt.title('Shap Feature Importance (sem2)', fontsize=16)
shap.plots.bar(shap_values2)

# %%
shap.plots.violin(shap_values2, show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values2, link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i28Z1WITNUAD80QTOUS1C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     1.0
# M05_2_N     1.7
# M06_2_N     1.0
# M07_2_N     5.1
# M08_2_N     1.7
# M09_2_N     5.1
# M10_2_N     1.0
# M11_2_N     1.0
# M12_2_N     5.1
# Status: 0, Prediction: [0], Probability [0]: 0.969, Probability [1]: 0.031
# <div id='iRTV8K6LR5W6YBW999KIP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5119455912795194, "outValue": -3.4375929449269074, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.42706325045300497, "value": 1.0}, "1": {"effect": 0.1310839551543276, "value": 5.1}, "2": {"effect": -0.05731507873575926, "value": 5.1}, "3": {"effect": -0.8526456861883128, "value": 1.0}, "4": {"effect": -0.47158725191499623, "value": 1.7}, "5": {"effect": -0.7499491733966961, "value": 1.0}, "6": {"effect": 0.06663085019174918, "value": 5.1}, "7": {"effect": -0.16808736186529902, "value": 1.7}, "8": {"effect": 0.19833524036223663, "value": 5.1}, "9": {"effect": -0.7935645122454077, "value": 1.0}, "10": {"effect": -0.8253762671152641, "value": 1.0}, "11": {"effect": 1.784440588010104e-17, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRTV8K6LR5W6YBW999KIP')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=5)
# Out:
# Student index 5 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.149, Probability [1]: 0.851
# <div id='i9NJWSNMOJOJQ1EYFEDPJ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5119455912795194, "outValue": 1.744287469007214, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.134681801474271, "value": 5.1}, "1": {"effect": 0.1310839551543276, "value": 5.1}, "2": {"effect": -0.05731507873575926, "value": 5.1}, "3": {"effect": 0.16983086057158134, "value": 5.1}, "4": {"effect": 0.28047496971304525, "value": 5.1}, "5": {"effect": 0.10202966033188501, "value": 5.1}, "6": {"effect": 0.06663085019174918, "value": 5.1}, "7": {"effect": 0.03890178349580776, "value": 5.1}, "8": {"effect": 0.19833524036223663, "value": 5.1}, "9": {"effect": 0.1029950083404746, "value": 5.1}, "10": {"effect": 0.06469282682807534, "value": 5.1}, "11": {"effect": 1.784440588010104e-17, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i9NJWSNMOJOJQ1EYFEDPJ')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=6)
# Out:
# Student index 6 grades:
#          grades
# M01_2_N     3.0
# M02_2_N     5.0
# M03_2_N     5.1
# M04_2_N     4.0
# M05_2_N     5.0
# M06_2_N     5.0
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.0
# M11_2_N     1.7
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.409, Probability [1]: 0.591
# <div id='iRYRKA6UFPX3O7WSWAGGF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5119455912795194, "outValue": 0.36696707624908, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.15304127390311423, "value": 3.0}, "1": {"effect": 0.11868244567898914, "value": 5.0}, "2": {"effect": -0.05731507873575926, "value": 5.1}, "3": {"effect": -0.1044921153883902, "value": 4.0}, "4": {"effect": 0.2583554926063382, "value": 5.0}, "5": {"effect": 0.08124968877752944, "value": 5.0}, "6": {"effect": 0.06663085019174918, "value": 5.1}, "7": {"effect": 0.03890178349580776, "value": 5.1}, "8": {"effect": 0.19833524036223663, "value": 5.1}, "9": {"effect": 0.08112770296033121, "value": 5.0}, "10": {"effect": -0.6734132510761573, "value": 1.7}, "11": {"effect": 1.784440588010104e-17, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRYRKA6UFPX3O7WSWAGGF')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=10)
# Out:
# Student index 10 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.149, Probability [1]: 0.851
# <div id='iRQ0IOHCHGFISEQ51AUND'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5119455912795194, "outValue": 1.744287469007214, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.134681801474271, "value": 5.1}, "1": {"effect": 0.1310839551543276, "value": 5.1}, "2": {"effect": -0.05731507873575926, "value": 5.1}, "3": {"effect": 0.16983086057158134, "value": 5.1}, "4": {"effect": 0.28047496971304525, "value": 5.1}, "5": {"effect": 0.10202966033188501, "value": 5.1}, "6": {"effect": 0.06663085019174918, "value": 5.1}, "7": {"effect": 0.03890178349580776, "value": 5.1}, "8": {"effect": 0.19833524036223663, "value": 5.1}, "9": {"effect": 0.1029950083404746, "value": 5.1}, "10": {"effect": 0.06469282682807534, "value": 5.1}, "11": {"effect": 1.784440588010104e-17, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRQ0IOHCHGFISEQ51AUND')
#   );
# </script>

# %% [markdown]
# ## THL semester 3

# %%
# Count occurrences of each unique value in the 'status' column
counter_3 = Counter(THL_3['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_3[1]} | 0: {counter_3[0]}')
hpo3 = ModelTrainer(random_state=42)
x, y = hpo3.split_data(THL_3, module3)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 203 | 0: 85

# %%
models_3, feature_importance3 = hpo3.cross_validation_hpo(
    x=x, y=y,
    search_space=search_space, 
    folds=5,
    algo='lr'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 59.09trial/s, best loss: -0.7487595737595737]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               04
# 	 actual 1            06               35
#
# Model parameters:
# {'C': 0.01816131274725735, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 80.91822%
# Validation accuracy.: 82.75862%
# Sensitivity score (for 1): 85.36585%
# Specificity score (for 0): 76.47059%
# F1 score.: 87.50000%
# False prediction: 17.24138%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 65.52trial/s, best loss: -0.7564081751581752]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            14               03
# 	 actual 1            12               29
#
# Model parameters:
# {'C': 0.02119750720379567, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 76.54232%
# Validation accuracy.: 74.13793%
# Sensitivity score (for 1): 70.73171%
# Specificity score (for 0): 82.35294%
# F1 score.: 79.45205%
# False prediction: 25.86207%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 58.04trial/s, best loss: -0.7521665834165834]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               04
# 	 actual 1            12               29
#
# Model parameters:
# {'C': 0.01808758501200869, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 73.60115%
# Validation accuracy.: 72.41379%
# Sensitivity score (for 1): 70.73171%
# Specificity score (for 0): 76.47059%
# F1 score.: 78.37838%
# False prediction: 27.58621%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 63.16trial/s, best loss: -0.7639142107892108]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               04
# 	 actual 1            11               29
#
# Model parameters:
# {'C': 0.02148202540369184, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 74.48529%
# Validation accuracy.: 73.68421%
# Sensitivity score (for 1): 72.50000%
# Specificity score (for 0): 76.47059%
# F1 score.: 79.45205%
# False prediction: 26.31579%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 56.44trial/s, best loss: -0.7727397602397602]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            05               35
#
# Model parameters:
# {'C': 0.021292381235786306, 'class_weight': 'balanced', 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 76.10294%
# Validation accuracy.: 80.70175%
# Sensitivity score (for 1): 87.50000%
# Specificity score (for 0): 64.70588%
# F1 score.: 86.41975%
# False prediction: 19.29825%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 76.32999%
# Standard Deviation of Balanced Accuracy: +/- 2.530
#
# Mean Accuracy: 76.73926%
# Standard Deviation of Accuracy: +/- 4.165
#
# Mean Sensitivity: 77.36585%
# Standard Deviation of Sensitivity: +/- 7.462
#
# Mean Specificity: 75.29412%
# Standard Deviation of Specificity: +/- 5.764
#
# Mean False Predictions: 23.26074%
# Standard Deviation of False Predictions: +/- 4.165
#
# best model is from 1 fold: LogisticRegression(C=0.01816131274725735, class_weight='balanced')

# %%
feature_importance3
# Out:
# <style type="text/css">
# #T_aaf52_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
# }
# #T_aaf52_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 80.4%, transparent 80.4%);
# }
# #T_aaf52_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 74.1%, transparent 74.1%);
# }
# #T_aaf52_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 73.4%, transparent 73.4%);
# }
# #T_aaf52_row4_col1, #T_aaf52_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 69.5%, transparent 69.5%);
# }
# #T_aaf52_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 65.5%, transparent 65.5%);
# }
# #T_aaf52_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 64.7%, transparent 64.7%);
# }
# #T_aaf52_row8_col1, #T_aaf52_row9_col1, #T_aaf52_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 61.8%, transparent 61.8%);
# }
# #T_aaf52_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 58.9%, transparent 58.9%);
# }
# #T_aaf52_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.0%, transparent 57.0%);
# }
# #T_aaf52_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.0%, transparent 51.0%);
# }
# #T_aaf52_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 50.0%, transparent 50.0%);
# }
# #T_aaf52_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.6%, red 47.6%, red 50.0%, transparent 50.0%);
# }
# #T_aaf52_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.3%, red 45.3%, red 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_aaf52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aaf52_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_aaf52_level0_col1" class="col_heading level0 col1" >coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aaf52_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_aaf52_row0_col0" class="data row0 col0" >M16_3_N</td>
#       <td id="T_aaf52_row0_col1" class="data row0 col1" >0.314180</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_aaf52_row1_col0" class="data row1 col0" >M11_3_N</td>
#       <td id="T_aaf52_row1_col1" class="data row1 col1" >0.190890</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_aaf52_row2_col0" class="data row2 col0" >M10_3_N</td>
#       <td id="T_aaf52_row2_col1" class="data row2 col1" >0.151260</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_aaf52_row3_col0" class="data row3 col0" >M02_3_N</td>
#       <td id="T_aaf52_row3_col1" class="data row3 col1" >0.147130</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_aaf52_row4_col0" class="data row4 col0" >M07_3_N</td>
#       <td id="T_aaf52_row4_col1" class="data row4 col1" >0.122630</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_aaf52_row5_col0" class="data row5 col0" >M05_3_N</td>
#       <td id="T_aaf52_row5_col1" class="data row5 col1" >0.122400</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_aaf52_row6_col0" class="data row6 col0" >M01_3_N</td>
#       <td id="T_aaf52_row6_col1" class="data row6 col1" >0.097230</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_aaf52_row7_col0" class="data row7 col0" >M06_3_N</td>
#       <td id="T_aaf52_row7_col1" class="data row7 col1" >0.092340</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_aaf52_row8_col0" class="data row8 col0" >M08_3_N</td>
#       <td id="T_aaf52_row8_col1" class="data row8 col1" >0.074240</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row9" class="row_heading level0 row9" >16</th>
#       <td id="T_aaf52_row9_col0" class="data row9 col0" >M17_3_N</td>
#       <td id="T_aaf52_row9_col1" class="data row9 col1" >0.074050</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row10" class="row_heading level0 row10" >8</th>
#       <td id="T_aaf52_row10_col0" class="data row10 col0" >M09_3_N</td>
#       <td id="T_aaf52_row10_col1" class="data row10 col1" >0.073890</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row11" class="row_heading level0 row11" >13</th>
#       <td id="T_aaf52_row11_col0" class="data row11 col0" >M14_3_N</td>
#       <td id="T_aaf52_row11_col1" class="data row11 col1" >0.056220</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aaf52_row12_col0" class="data row12 col0" >M13_3_N</td>
#       <td id="T_aaf52_row12_col1" class="data row12 col1" >0.043920</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row13" class="row_heading level0 row13" >2</th>
#       <td id="T_aaf52_row13_col0" class="data row13 col0" >M03_3_N</td>
#       <td id="T_aaf52_row13_col1" class="data row13 col1" >0.006480</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row14" class="row_heading level0 row14" >11</th>
#       <td id="T_aaf52_row14_col0" class="data row14 col0" >M12_3_N</td>
#       <td id="T_aaf52_row14_col1" class="data row14 col1" >0.000160</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row15" class="row_heading level0 row15" >14</th>
#       <td id="T_aaf52_row15_col0" class="data row15 col0" >M15_3_N</td>
#       <td id="T_aaf52_row15_col1" class="data row15 col1" >-0.015210</td>
#     </tr>
#     <tr>
#       <th id="T_aaf52_level0_row16" class="row_heading level0 row16" >3</th>
#       <td id="T_aaf52_row16_col0" class="data row16 col0" >M04_3_N</td>
#       <td id="T_aaf52_row16_col1" class="data row16 col1" >-0.029500</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Shap Global explainations
import shap
explainer3 = shap.Explainer(models_3['model'], models_3['x_train'])
shap_values3 = explainer3(models_3['x_test'])

plt.title('Shap Feature Importance (sem3)', fontsize=16)
shap.plots.bar(shap_values3)

# %%
shap.plots.violin(shap_values3, show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values3, link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iVU2ELI6TOL3N0J0MB73M'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.45287658240465145, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "explanations": [{"outValue": 1.2577989863683219, "simIndex": 40.0, "features": {"0": {"effect": -0.2086643169089517, "value": 1.7}, "1": {"effect": 0.16448632281618086, "value": 5.1}, "2": {"effect": 0.010891937455847371, "value": 5.1}, "3": {"effect": 0.022187087877709833, "value": 3.3}, "4": {"effect": -0.22092329279536246, "value": 1.7}, "5": {"effect": 0.07535273705035828, "value": 5.1}, "6": {"effect": 0.06315472948320434, "value": 5.1}, "7": {"effect": 0.0752791909085777, "value": 5.1}, "8": {"effect": 0.08378798604619558, "value": 5.1}, "9": {"effect": 0.08742557750852467, "value": 5.1}, "10": {"effect": 0.1733266142225677, "value": 5.1}, "11": {"effect": 2.266739279962159e-06, "value": 5.1}, "12": {"effect
# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=1)
# Out:
# Student index 1 grades:
#          grades
# M01_3_N     5.1
# M02_3_N     5.1
# M03_3_N     1.7
# M04_3_N     5.1
# M05_3_N     1.7
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.180, Probability [1]: 0.820
# <div id='i6ZECVBZIO2CIUBEFN519'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.45287658240465145, "outValue": 1.5132573438269714, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": 0.12193152535126947, "value": 5.1}, "1": {"effect": 0.16448632281618086, "value": 5.1}, "2": {"effect": -0.011138156149078916, "value": 1.7}, "3": {"effect": -0.03092030331893574, "value": 5.1}, "4": {"effect": -0.22092329279536246, "value": 1.7}, "5": {"effect": 0.07535273705035828, "value": 5.1}, "6": {"effect": 0.06315472948320434, "value": 5.1}, "7": {"effect": 0.0752791909085777, "value": 5.1}, "8": {"effect": 0.08378798604619558, "value": 5.1}, "9": {"effect": 0.08742557750852467, "value": 5.1}, "10": {"effect": 0.1733266142225677, "value": 5.1}, "11": {"effect": 2.266739279962159e-06, "value": 5.1}, "12": {"effect": 0.005094517669079659, "value": 5.1}, "13": {"effect": 0.058471454570898196, "value": 5.1}, "14": {"effect": -0.00266120987758689, "value": 5.1}, "15": {"effect": 0.36350741693672006, "value": 5.1}, "16": {"effect": 0.0542033842604274, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i6ZECVBZIO2CIUBEFN519')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=9)
# Out:
# Student index 9 grades:
#          grades
# M01_3_N     5.1
# M02_3_N     4.0
# M03_3_N     3.0
# M04_3_N     3.0
# M05_3_N     2.7
# M06_3_N     2.0
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     1.7
# M10_3_N     5.0
# M11_3_N     5.0
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     1.3
# M17_3_N     5.1
# Status: 0, Prediction: [0], Probability [0]: 0.555, Probability [1]: 0.445
# <div id='iWAFGSUV7GJDGVMBX7ODD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.45287658240465145, "outValue": -0.22138852542615484, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": 0.12193152535126947, "value": 5.1}, "1": {"effect": 0.002648259222442697, "value": 4.0}, "2": {"effect": -0.002714885064842393, "value": 3.0}, "3": {"effect": 0.031038319743817423, "value": 3.0}, "4": {"effect": -0.09852811673144986, "value": 2.7}, "5": {"effect": -0.21091378850860243, "value": 2.0}, "6": {"effect": 0.06315472948320434, "value": 5.1}, "7": {"effect": 0.0752791909085777, "value": 5.1}, "8": {"effect": -0.167428197866561, "value": 1.7}, "9": {"effect": 0.07230004506760337, "value": 5.0}, "10": {"effect": 0.15423778005708666, "value": 5.0}, "11": {"effect": 2.266739279962159e-06, "value": 5.1}, "12": {"effect": 0.005094517669079659, "value": 5.1}, "13": {"effect": 0.058471454570898196, "value": 5.1}, "14": {"effect": -0.00266120987758689, "value": 5.1}, "15": {"effect": -0.8303803828554506, "value": 1.3}, "16": {"effect": 0.0542033842604274, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iWAFGSUV7GJDGVMBX7ODD')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=3)
# Out:
# Student index 3 grades:
#          grades
# M01_3_N     1.3
# M02_3_N     1.0
# M03_3_N     1.3
# M04_3_N     1.3
# M05_3_N     1.3
# M06_3_N     5.1
# M07_3_N     1.0
# M08_3_N     1.3
# M09_3_N     5.1
# M10_3_N     2.3
# M11_3_N     1.0
# M12_3_N     5.1
# M13_3_N     2.0
# M14_3_N     1.3
# M15_3_N     5.1
# M16_3_N     1.0
# M17_3_N     1.7
# Status: 0, Prediction: [0], Probability [0]: 0.964, Probability [1]: 0.036
# <div id='iM7HK28DJTVU714XTZRJX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.45287658240465145, "outValue": -3.2796334157471834, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": -0.24755794541015416, "value": 1.3}, "1": {"effect": -0.4387282778513888, "value": 1.0}, "2": {"effect": -0.013729931867305535, "value": 1.3}, "3": {"effect": 0.08119530031842714, "value": 1.3}, "4": {"effect": -0.2698813632209275, "value": 1.3}, "5": {"effect": 0.07535273705035828, "value": 5.1}, "6": {"effect": -0.4396304955287209, "value": 1.0}, "7": {"effect": -0.20683217541548213, "value": 1.3}, "8": {"effect": 0.08378798604619558, "value": 5.1}, "9": {"effect": -0.3360893308372732, "value": 2.3}, "10": {"effect": -0.6093155865621586, "value": 1.0}, "11": {"effect": 2.266739279962159e-06, "value": 5.1}, "12": {"effect": -0.1310520752115072, "value": 2.0}, "13": {"effect": -0.15517424482276918, "value": 1.3}, "14": {"effect": -0.00266120987758689, "value": 5.1}, "15": {"effect": -0.9246346828390429, "value": 1.0}, "16": {"effect": -0.1975609688617784, "value": 1.7}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iM7HK28DJTVU714XTZRJX')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=10)
# Out:
# Student index 10 grades:
#          grades
# M01_3_N     1.0
# M02_3_N     2.0
# M03_3_N     1.0
# M04_3_N     1.0
# M05_3_N     1.3
# M06_3_N     1.3
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     1.0
# M10_3_N     1.3
# M11_3_N     3.0
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     1.3
# M17_3_N     1.0
# Status: 0, Prediction: [0], Probability [0]: 0.917, Probability [1]: 0.083
# <div id='iY4MXRHNX05J2R6BHDDZ4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.45287658240465145, "outValue": -2.4009845364655784, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"0": {"effect": -0.27672816678605605, "value": 1.0}, "1": {"effect": -0.29160276549344494, "value": 2.0}, "2": {"effect": -0.015673763655975503, "value": 1.0}, "3": {"effect": 0.09004653218453473, "value": 1.0}, "4": {"effect": -0.2698813632209275, "value": 1.3}, "5": {"effect": -0.2755546168606259, "value": 1.3}, "6": {"effect": 0.06315472948320434, "value": 5.1}, "7": {"effect": 0.0752791909085777, "value": 5.1}, "8": {"effect": -0.21914917690742267, "value": 1.0}, "9": {"effect": -0.4873446552464868, "value": 1.3}, "10": {"effect": -0.22753890325253595, "value": 3.0}, "11": {"effect": 2.266739279962159e-06, "value": 5.1}, "12": {"effect": 0.005094517669079659, "value": 5.1}, "13": {"effect": 0.058471454570898196, "value": 5.1}, "14": {"effect": -0.00266120987758689, "value": 5.1}, "15": {"effect": -0.8303803828554506, "value": 1.3}, "16": {"effect": -0.24939480626929136, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iY4MXRHNX05J2R6BHDDZ4')
#   );
# </script>
