# %%
from functions import *
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import shap
from collections import Counter

# %% [markdown]
# ## Data Preprocessing

# %%
path_1 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL1_merged.csv"
path_2 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL2_merged.csv"
path_3 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL3_merged.csv"

THL_1 = pd.read_csv(path_1, sep=',')
THL_2 = pd.read_csv(path_2, sep=',')
THL_3 = pd.read_csv(path_3, sep=',')

# %%
## set modules
module1 = ['M01_1_N', 'M02_1_N', 'M03_1_N', 'M04_1_N', 'M05_1_N', 'M06_1_N']

module2 = [
            'M01_2_N', 'M02_2_N', 'M03_2_N', 'M04_2_N', 'M05_2_N', 'M06_2_N',
            'M07_2_N', 'M08_2_N', 'M09_2_N', 'M10_2_N', 'M11_2_N', 'M12_2_N',]

module3 = ['M01_3_N', 'M02_3_N', 'M03_3_N', 'M04_3_N', 'M05_3_N', 'M06_3_N',
            'M07_3_N', 'M08_3_N', 'M09_3_N', 'M10_3_N', 'M11_3_N', 'M12_3_N',
            'M13_3_N', 'M14_3_N', 'M15_3_N', 'M16_3_N', 'M17_3_N']

# %% [markdown]
# ### Train test split function

# %%
from sklearn.model_selection import StratifiedShuffleSplit

def split_df(df, features):
    X = df[features]  # Feature matrix
    y = df["status"]  # Target variable

    # Initialize StratifiedShuffleSplit with one split
    strat_split = StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=42)

    # Generate indices for training and testing sets
    for train_index, test_index in strat_split.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Search Space / Param Grid

# %%
from hyperopt import *
search_space = {
    'n_estimators': hp.choice('n_estimators', list(range(5, 100, 5))),  # Number of boosting rounds
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.8),  # Step size shrinkage
    'booster': hp.choice('booster', ['gbtree']),
    'max_depth': hp.choice('max_depth', list(range(4, 12))),  # Tree depth
    'subsample': hp.uniform('subsample', 0.4, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.4, 1),
    'reg_lambda': hp.uniform('reg_lambda', 0.01, 0.3),  # L2 regularization term on weights
    'min_child_weight': hp.uniform('min_child_weight', 0.1, 2),  # Minimum sum of instance weight in a child
    'scale_pos_weight': hp.uniform('scale_pos_weight', 0.1 , 2.5),  # Balancing class weights for imbalanced dat
}

# %% [markdown]
# ## THL semester 1

# %%
# Count occurrences of each unique value in the 'status' column
counter_1 = Counter(THL_1['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_1[1]} | 0: {counter_1[0]}')

hpo = ModelTrainer(random_state=42)
x1, y1 = hpo.split_data(THL_1, module1)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 502 | 0: 118

# %%
models_1, feature_importance1 = hpo.cross_validation_hpo(
    x=x1, y=y1,
    search_space=search_space, 
    folds=5,
    algo='xgb'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.87trial/s, best loss: -0.6735095841455491]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            12               11
# 	 actual 1            17               84
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6537622316254637, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.32447282579890907, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 1.257617718727278, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.11857008405583173, 'sampling_method': None, 'scale_pos_weight': 0.519589453981988, 'subsample': 0.7561520598406448, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 67.67111%
# Validation accuracy.: 77.41935%
# Sensitivity score (for 1): 83.16832%
# Specificity score (for 0): 52.17391%
# F1 score.: 85.71429%
# False prediction: 22.58065%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.86trial/s, best loss: -0.5832927225471085]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               14
# 	 actual 1            03               98
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.7484052937136098, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.4962518762626035, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 1.4362717307154043, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.12941915534187173, 'sampling_method': None, 'scale_pos_weight': 1.100654055818302, 'subsample': 0.49566152599936264, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 68.08007%
# Validation accuracy.: 86.29032%
# Sensitivity score (for 1): 97.02970%
# Specificity score (for 0): 39.13043%
# F1 score.: 92.01878%
# False prediction: 13.70968%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.58trial/s, best loss: -0.6731213450292397]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               13
# 	 actual 1            16               84
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6704975754729108, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.6099277074752287, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 11, 'max_leaves': None, 'min_child_weight': 0.44489144874681663, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.06199740045282043, 'sampling_method': None, 'scale_pos_weight': 0.14549232515356395, 'subsample': 0.8303363528790852, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 64.91667%
# Validation accuracy.: 76.61290%
# Sensitivity score (for 1): 84.00000%
# Specificity score (for 0): 45.83333%
# F1 score.: 85.27919%
# False prediction: 23.38710%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  4.69trial/s, best loss: -0.6834860298895385]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               15
# 	 actual 1            17               83
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.5829696295856701, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.2140305131029409, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 11, 'max_leaves': None, 'min_child_weight': 1.9975119516644446, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.13628763304037697, 'sampling_method': None, 'scale_pos_weight': 0.7512117304315463, 'subsample': 0.8690829668016291, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 60.25000%
# Validation accuracy.: 74.19355%
# Sensitivity score (for 1): 83.00000%
# Specificity score (for 0): 37.50000%
# F1 score.: 83.83838%
# False prediction: 25.80645%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.77trial/s, best loss: -0.6665253411306044]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               13
# 	 actual 1            16               84
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6370244096194495, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.07374682666116085, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 7, 'max_leaves': None, 'min_child_weight': 0.4505556117655196, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.269232005431043, 'sampling_method': None, 'scale_pos_weight': 0.4801573954054972, 'subsample': 0.9633341809342275, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 64.91667%
# Validation accuracy.: 76.61290%
# Sensitivity score (for 1): 84.00000%
# Specificity score (for 0): 45.83333%
# F1 score.: 85.27919%
# False prediction: 23.38710%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 65.16690%
# Standard Deviation of Balanced Accuracy: +/- 2.795
#
# Mean Accuracy: 78.22581%
# Standard Deviation of Accuracy: +/- 4.175
#
# Mean Sensitivity: 86.23960%
# Standard Deviation of Sensitivity: +/- 5.411
#
# Mean Specificity: 44.09420%
# Standard Deviation of Specificity: +/- 5.281
#
# Mean False Predictions: 21.77419%
# Standard Deviation of False Predictions: +/- 4.175
#
# best model is from 2 fold: XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7484052937136098, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4962518762626035,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=1.4362717307154043, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=15,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %%
feature_importance1
# Out:
# <style type="text/css">
# #T_cb528_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_cb528_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 88.7%, transparent 88.7%);
# }
# #T_cb528_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 83.6%, transparent 83.6%);
# }
# #T_cb528_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 74.6%, transparent 74.6%);
# }
# #T_cb528_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 66.6%, transparent 66.6%);
# }
# #T_cb528_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 65.5%, transparent 65.5%);
# }
# </style>
# <table id="T_cb528">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb528_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_cb528_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb528_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb528_row0_col0" class="data row0 col0" >M01_1_N</td>
#       <td id="T_cb528_row0_col1" class="data row0 col1" >0.208780</td>
#     </tr>
#     <tr>
#       <th id="T_cb528_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb528_row1_col0" class="data row1 col0" >M02_1_N</td>
#       <td id="T_cb528_row1_col1" class="data row1 col1" >0.185110</td>
#     </tr>
#     <tr>
#       <th id="T_cb528_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cb528_row2_col0" class="data row2 col0" >M04_1_N</td>
#       <td id="T_cb528_row2_col1" class="data row2 col1" >0.174592</td>
#     </tr>
#     <tr>
#       <th id="T_cb528_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T
# %%
hpo.plot_shap_force(model=models_1,
           shap_values=shap_values, 
           student_index=29, model_name='xgb')
# Out:
# Student index 29 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.022, Probability [1]: 0.978
# <div id='iRABXTOWASNML3087ZTJ0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.342823334442621, "outValue": 3.811844045886939, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.33611813865602014, "value": 5.1}, "1": {"effect": 0.34917110096663234, "value": 5.1}, "2": {"effect": 0.39978841934353115, "value": 5.1}, "3": {"effect": 0.1278527982905507, "value": 5.1}, "4": {"effect": 0.2656430994719267, "value": 5.1}, "5": {"effect": -0.009552845284342765, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iRABXTOWASNML3087ZTJ0')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=11, model_name='xgb')
# Out:
# Student index 11 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.022, Probability [1]: 0.978
# <div id='iLELB4XFEQR3QMK3UABHR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.342823334442621, "outValue": 3.811844045886939, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.33611813865602014, "value": 5.1}, "1": {"effect": 0.34917110096663234, "value": 5.1}, "2": {"effect": 0.39978841934353115, "value": 5.1}, "3": {"effect": 0.1278527982905507, "value": 5.1}, "4": {"effect": 0.2656430994719267, "value": 5.1}, "5": {"effect": -0.009552845284342765, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iLELB4XFEQR3QMK3UABHR')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=39, model_name='xgb')
# Out:
# Student index 39 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.022, Probability [1]: 0.978
# <div id='iPKXZ6F1VEHU51CH3K5UK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.342823334442621, "outValue": 3.811844045886939, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.33611813865602014, "value": 5.1}, "1": {"effect": 0.34917110096663234, "value": 5.1}, "2": {"effect": 0.39978841934353115, "value": 5.1}, "3": {"effect": 0.1278527982905507, "value": 5.1}, "4": {"effect": 0.2656430994719267, "value": 5.1}, "5": {"effect": -0.009552845284342765, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPKXZ6F1VEHU51CH3K5UK')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=46, model_name='xgb')
# Out:
# Student index 46 grades:
#          grades
# M01_1_N     5.1
# M02_1_N     5.1
# M03_1_N     5.1
# M04_1_N     5.1
# M05_1_N     5.1
# M06_1_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.022, Probability [1]: 0.978
# <div id='i4U17JNGZA4RTUAHI2WID'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.342823334442621, "outValue": 3.811844045886939, "link": "logit", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": 0.33611813865602014, "value": 5.1}, "1": {"effect": 0.34917110096663234, "value": 5.1}, "2": {"effect": 0.39978841934353115, "value": 5.1}, "3": {"effect": 0.1278527982905507, "value": 5.1}, "4": {"effect": 0.2656430994719267, "value": 5.1}, "5": {"effect": -0.009552845284342765, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i4U17JNGZA4RTUAHI2WID')
#   );
# </script>

# %% [markdown]
# ## THL semester 2

# %%
# Count occurrences of each unique value in the 'status' column
counter_2 = Counter(THL_2['status'])
print(f'Quantity of Drop Out and Degree in THL-2: \n 1: {counter_2[1]} | 0: {counter_2[0]}')
hpo2 = ModelTrainer(random_state=72)
x2, y2 = hpo2.split_data(THL_2, module2)
# Out:
# Quantity of Drop Out and Degree in THL-2:
#  1: 315 | 0: 88

# %%
models_2, feature_importance2 = hpo2.cross_validation_hpo(
    x=x2, y=y2,
    search_space=search_space, 
    folds=5,
    algo='xgb'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 10/10 [00:03<00:00,  2.76trial/s, best loss: -0.7277703081232494]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            07               11
# 	 actual 1            05               58
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.5612654730916261, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.5178774092475721, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 0.6400223069748592, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 72, 'reg_alpha': None, 'reg_lambda': 0.13944358370441953, 'sampling_method': None, 'scale_pos_weight': 0.37965433995275866, 'subsample': 0.8692793767785794, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 65.47619%
# Validation accuracy.: 80.24691%
# Sensitivity score (for 1): 92.06349%
# Specificity score (for 0): 38.88889%
# F1 score.: 87.87879%
# False prediction: 19.75309%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  3.06trial/s, best loss: -0.7527619047619047]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            16               02
# 	 actual 1            20               43
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9916335672933924, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.11845276448595256, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 9, 'max_leaves': None, 'min_child_weight': 1.4838977506413762, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 72, 'reg_alpha': None, 'reg_lambda': 0.17824816490078596, 'sampling_method': None, 'scale_pos_weight': 0.12086891370754138, 'subsample': 0.46831519748385686, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 78.57143%
# Validation accuracy.: 72.83951%
# Sensitivity score (for 1): 68.25397%
# Specificity score (for 0): 88.88889%
# F1 score.: 79.62963%
# False prediction: 27.16049%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.73trial/s, best loss: -0.7256526610644258]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            08               10
# 	 actual 1            16               47
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8402087286056305, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.6044565020194745, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 1.763295318893651, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 72, 'reg_alpha': None, 'reg_lambda': 0.04427597431901782, 'sampling_method': None, 'scale_pos_weight': 0.25877954994259744, 'subsample': 0.6199302679177902, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 59.52381%
# Validation accuracy.: 67.90123%
# Sensitivity score (for 1): 74.60317%
# Specificity score (for 0): 44.44444%
# F1 score.: 78.33333%
# False prediction: 32.09877%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:04<00:00,  2.48trial/s, best loss: -0.6798935574229692]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            09               08
# 	 actual 1            09               54
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.747551711483947, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.49598374099973325, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 1.4555183483119372, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 72, 'reg_alpha': None, 'reg_lambda': 0.04992943882690342, 'sampling_method': None, 'scale_pos_weight': 1.7388858226652137, 'subsample': 0.7013079259997205, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 69.32773%
# Validation accuracy.: 78.75000%
# Sensitivity score (for 1): 85.71429%
# Specificity score (for 0): 52.94118%
# F1 score.: 86.40000%
# False prediction: 21.25000%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  3.47trial/s, best loss: -0.6618039215686276]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            14               03
# 	 actual 1            14               49
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6170531885254609, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.22907394227348374, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 10, 'max_leaves': None, 'min_child_weight': 0.6707936641208933, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 72, 'reg_alpha': None, 'reg_lambda': 0.049244548388387994, 'sampling_method': None, 'scale_pos_weight': 0.11649729941141623, 'subsample': 0.783732021712175, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 80.06536%
# Validation accuracy.: 78.75000%
# Sensitivity score (for 1): 77.77778%
# Specificity score (for 0): 82.35294%
# F1 score.: 85.21739%
# False prediction: 21.25000%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 70.59290%
# Standard Deviation of Balanced Accuracy: +/- 7.793
#
# Mean Accuracy: 75.69753%
# Standard Deviation of Accuracy: +/- 4.654
#
# Mean Sensitivity: 79.68254%
# Standard Deviation of Sensitivity: +/- 8.363
#
# Mean Specificity: 61.50327%
# Standard Deviation of Specificity: +/- 20.300
#
# Mean False Predictions: 24.30247%
# Standard Deviation of False Predictions: +/- 4.654
#
# best model is from 5 fold: XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6170531885254609, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.22907394227348374,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=0.6707936641208933, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=40,
#               n_jobs=None, num_parallel_tree=None, random_state=72, ...)

# %%
feature_importance2
# Out:
# <style type="text/css">
# #T_03b59_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_03b59_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 83.5%, transparent 83.5%);
# }
# #T_03b59_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 81.6%, transparent 81.6%);
# }
# #T_03b59_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 73.6%, transparent 73.6%);
# }
# #T_03b59_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 53.0%, transparent 53.0%);
# }
# #T_03b59_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 50.6%, transparent 50.6%);
# }
# #T_03b59_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 49.1%, transparent 49.1%);
# }
# #T_03b59_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 39.9%, transparent 39.9%);
# }
# #T_03b59_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 39.4%, transparent 39.4%);
# }
# #T_03b59_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 35.9%, transparent 35.9%);
# }
# #T_03b59_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 29.6%, transparent 29.6%);
# }
# #T_03b59_row11_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_03b59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03b59_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_03b59_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03b59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03b59_row0_col0" class="data row0 col0" >M01_2_N</td>
#       <td id="T_03b59_row0_col1" class="data row0 col1" >0.157232</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_03b59_row1_col0" class="data row1 col0" >M10_2_N</td>
#       <td id="T_03b59_row1_col1" class="data row1 col1" >0.131318</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_03b59_row2_col0" class="data row2 col0" >M05_2_N</td>
#       <td id="T_03b59_row2_col1" class="data row2 col1" >0.128239</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_03b59_row3_col0" class="data row3 col0" >M02_2_N</td>
#       <td id="T_03b59_row3_col1" class="data row3 col1" >0.115659</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_03b59_row4_col0" class="data row4 col0" >M11_2_N</td>
#       <td id="T_03b59_row4_col1" class="data row4 col1" >0.083269</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_03b59_row5_col0" class="data row5 col0" >M09_2_N</td>
#       <td id="T_03b59_row5_col1" class="data row5 col1" >0.079514</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_03b59_row6_col0" class="data row6 col0" >M03_2_N</td>
#       <td id="T_03b59_row6_col1" class="data row6 col1" >0.077162</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03b59_row7_col0" class="data row7 col0" >M08_2_N</td>
#       <td id="T_03b59_row7_col1" class="data row7 col1" >0.062661</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_03b59_row8_col0" class="data row8 col0" >M06_2_N</td>
#       <td id="T_03b59_row8_col1" class="data row8 col1" >0.061941</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row9" class="row_heading level0 row9" >6</th>
#       <td id="T_03b59_row9_col0" class="data row9 col0" >M07_2_N</td>
#       <td id="T_03b59_row9_col1" class="data row9 col1" >0.056502</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row10" class="row_heading level0 row10" >3</th>
#       <td id="T_03b59_row10_col0" class="data row10 col0" >M04_2_N</td>
#       <td id="T_03b59_row10_col1" class="data row10 col1" >0.046501</td>
#     </tr>
#     <tr>
#       <th id="T_03b59_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_03b59_row11_col0" class="data row11 col0" >M12_2_N</td>
#       <td id="T_03b59_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer2 = shap.Explainer(models_2['model'], models_2['x_train'])
shap_values2 = explainer2(models_2['x_test'])

plt.title('Shap Feature Importance (sem2)', fontsize=16)
shap.plots.bar(shap_values2)

# %%
shap.plots.violin(shap_values2, show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values2, link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iF4CQLJ18JWJLV4LR4K0M'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 2.1587945814270237, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "explanations": [{"outValue": 0.39460153254472563, "simIndex": 78.0, "features": {"0": {"effect": -0.9486174476984889, "value": 1.7}, "1": {"effect": -0.25012719926424326, "value": 5.1}, "2": {"effect": -0.1792961268359795, "value": 5.1}, "3": {"effect": -0.20644204921089113, "value": 3.3}, "4": {"effect": -1.3207051737420261, "value": 1.7}, "5": {"effect": 0.1893589998409152, "value": 5.1}, "6": {"effect": 0.0870365026127547, "value": 5.1}, "7": {"effect": 0.11603662131354213, "value": 5.1}, "8": {"effect": 0.43755333406850694, "value": 5.1}, "9": {"effect": 0.18905954393558205, "value": 5.1}, "10": {"effect": 0.12194994609802962, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": -0.3728183609803497, "simIndex": 5.0, "features": {"0": {"effect": -1.1359962192573585, "value": 2.3}, "1": {"effect": -1.0605139917554334, "value": 1.7}, "2": {"effect": -0.208754640170373, "value": 5.1}, "3": {"effect": -0.3010676088836044, "value": 1.0}, "4": {"effect": 0.2761256890743971, "value": 5.1}, "5": {"effect": 0.17748411572538317, "value": 5.1}, "6": {"effect": 0.12792872248217463, "value": 5.1}, "7": {"effect": 0.13807791928760707, "value": 5.1}, "8": {"effect": 0.41367427211254837, "value": 5.1}, "9": {"effect": 0.09376254461705685, "value": 5.1}, "10": {"effect": -1.0523337456397712, "value": 1.0}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue

#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=5,  model_name='xgb')
# Out:
# Student index 5 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     2.7
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     1.3
# M09_2_N     2.7
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.065, Probability [1]: 0.935
# <div id='i4Z1X9JP6U6CW1ES2VE2J'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.1587945814270237, "outValue": 2.660533805254632, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.6354642645688727, "value": 5.1}, "1": {"effect": 0.20187682189512998, "value": 5.1}, "2": {"effect": 0.43770967874210326, "value": 2.7}, "3": {"effect": -0.06111448593437672, "value": 5.1}, "4": {"effect": 0.7313819201663136, "value": 5.1}, "5": {"effect": 0.15041685491800308, "value": 5.1}, "6": {"effect": 0.043743027630262075, "value": 5.1}, "7": {"effect": -1.1448266192758456, "value": 1.3}, "8": {"effect": -0.7944432594720274, "value": 2.7}, "9": {"effect": 0.2454423191770911, "value": 5.1}, "10": {"effect": 0.05608870141208172, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i4Z1X9JP6U6CW1ES2VE2J')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=6, model_name='xgb')
# Out:
# Student index 6 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.006, Probability [1]: 0.994
# <div id='i52JIWJRRHKWFX9KE1HRB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.1587945814270237, "outValue": 5.1441811099488, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.7751496433233842, "value": 5.1}, "1": {"effect": 0.13958154109306634, "value": 5.1}, "2": {"effect": -0.16431685517076403, "value": 5.1}, "3": {"effect": 0.0474931066762656, "value": 5.1}, "4": {"effect": 0.6870494716707617, "value": 5.1}, "5": {"effect": 0.18576770966872572, "value": 5.1}, "6": {"effect": 0.08543806285597384, "value": 5.1}, "7": {"effect": 0.1837045169621706, "value": 5.1}, "8": {"effect": 0.6650973611231893, "value": 5.1}, "9": {"effect": 0.29193211181089285, "value": 5.1}, "10": {"effect": 0.08848985850811004, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i52JIWJRRHKWFX9KE1HRB')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=10, model_name='xgb')
# Out:
# Student index 10 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     4.0
# M03_2_N     3.0
# M04_2_N     3.0
# M05_2_N     2.7
# M06_2_N     2.0
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.0
# M12_2_N     5.1
# Status: 0, Prediction: [1], Probability [0]: 0.081, Probability [1]: 0.919
# <div id='iWY8X1X35IKU3ITBZNG5M'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 2.1587945814270237, "outValue": 2.431165354808577, "link": "logit", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.7751125557022169, "value": 5.1}, "1": {"effect": 0.10909335331991316, "value": 4.0}, "2": {"effect": 0.4711654415447265, "value": 3.0}, "3": {"effect": -0.4065917759388685, "value": 3.0}, "4": {"effect": -0.0727234993968159, "value": 2.7}, "5": {"effect": -1.3470919120684266, "value": 2.0}, "6": {"effect": 0.08651368655264377, "value": 5.1}, "7": {"effect": 0.06788583631627261, "value": 5.1}, "8": {"effect": 0.4424039190262556, "value": 5.1}, "9": {"effect": 0.27895946212112904, "value": 5.1}, "10": {"effect": -0.13235629379749297, "value": 5.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iWY8X1X35IKU3ITBZNG5M')
#   );
# </script>

# %% [markdown]
# ## THL semester 3

# %%
# Count occurrences of each unique value in the 'status' column
counter_3 = Counter(THL_3['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_3[1]} | 0: {counter_3[0]}')

hpo3 = ModelTrainer(random_state=42)
x3, y3 = hpo3.split_data(THL_3, module3)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 203 | 0: 85

# %%
models_3, feature_importance3 = hpo3.cross_validation_hpo(
    x=x3, y=y3,
    search_space=search_space, 
    folds=5,
    algo='xgb'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.59trial/s, best loss: -0.7235108641358641]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               04
# 	 actual 1            07               34
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9989760547377892, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.17558428433375844, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 9, 'max_leaves': None, 'min_child_weight': 1.1311641149459069, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.18534969175244637, 'sampling_method': None, 'scale_pos_weight': 0.15890137319973824, 'subsample': 0.7902927476066253, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 79.69871%
# Validation accuracy.: 81.03448%
# Sensitivity score (for 1): 82.92683%
# Specificity score (for 0): 76.47059%
# F1 score.: 86.07595%
# False prediction: 18.96552%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  4.31trial/s, best loss: -0.6939831002331003]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            14               03
# 	 actual 1            08               33
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8400660892687479, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.1955297796636217, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 8, 'max_leaves': None, 'min_child_weight': 1.353497853939345, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.28763370933183835, 'sampling_method': None, 'scale_pos_weight': 1.020980784456824, 'subsample': 0.7111050720857979, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 81.42037%
# Validation accuracy.: 81.03448%
# Sensitivity score (for 1): 80.48780%
# Specificity score (for 0): 82.35294%
# F1 score.: 85.71429%
# False prediction: 18.96552%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  2.72trial/s, best loss: -0.7535131535131535]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            07               34
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.7610708572037608, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.6026319038495057, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 0.7590244177531174, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.11105863935413167, 'sampling_method': None, 'scale_pos_weight': 1.5644671102051946, 'subsample': 0.502269592162892, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 73.81636%
# Validation accuracy.: 77.58621%
# Sensitivity score (for 1): 82.92683%
# Specificity score (for 0): 64.70588%
# F1 score.: 83.95062%
# False prediction: 22.41379%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:02<00:00,  4.17trial/s, best loss: -0.7923118548118548]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            08               32
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.4961773471426188, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.676238807385562, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': 1.5259281648498846, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.0971901080614288, 'sampling_method': None, 'scale_pos_weight': 1.3444274632809383, 'subsample': 0.6857085998561436, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 72.35294%
# Validation accuracy.: 75.43860%
# Sensitivity score (for 1): 80.00000%
# Specificity score (for 0): 64.70588%
# F1 score.: 82.05128%
# False prediction: 24.56140%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:03<00:00,  3.27trial/s, best loss: -0.7669715700965701]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            12               05
# 	 actual 1            09               31
#
# Model parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': 'gbtree', 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8983610436248608, 'device': None, 'eval_metric': None, 'gamma': None, 'grow_policy': None, 'interaction_constraints': None, 'learning_rate': 0.3453652789704544, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 8, 'max_leaves': None, 'min_child_weight': 1.2097663050214547, 'monotone_constraints': None, 'multi_strategy': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': 0.19998582019366618, 'sampling_method': None, 'scale_pos_weight': 0.22151814764477978, 'subsample': 0.6005042949754832, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# Balanced acc.: 74.04412%
# Validation accuracy.: 75.43860%
# Sensitivity score (for 1): 77.50000%
# Specificity score (for 0): 70.58824%
# F1 score.: 81.57895%
# False prediction: 24.56140%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 76.26650%
# Standard Deviation of Balanced Accuracy: +/- 3.594
#
# Mean Accuracy: 78.10647%
# Standard Deviation of Accuracy: +/- 2.516
#
# Mean Sensitivity: 80.76829%
# Standard Deviation of Sensitivity: +/- 2.033
#
# Mean Specificity: 71.76471%
# Standard Deviation of Specificity: +/- 6.860
#
# Mean False Predictions: 21.89353%
# Standard Deviation of False Predictions: +/- 2.516
#
# best model is from 2 fold: XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8400660892687479, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1955297796636217,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=1.353497853939345, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=50,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %%
feature_importance3
# Out:
# <style type="text/css">
# #T_7bedc_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_7bedc_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 57.9%, transparent 57.9%);
# }
# #T_7bedc_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 43.0%, transparent 43.0%);
# }
# #T_7bedc_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 42.5%, transparent 42.5%);
# }
# #T_7bedc_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 35.1%, transparent 35.1%);
# }
# #T_7bedc_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 34.6%, transparent 34.6%);
# }
# #T_7bedc_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 33.2%, transparent 33.2%);
# }
# #T_7bedc_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.6%, transparent 32.6%);
# }
# #T_7bedc_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 30.6%, transparent 30.6%);
# }
# #T_7bedc_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 30.2%, transparent 30.2%);
# }
# #T_7bedc_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 28.3%, transparent 28.3%);
# }
# #T_7bedc_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 27.1%, transparent 27.1%);
# }
# #T_7bedc_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 24.9%, transparent 24.9%);
# }
# #T_7bedc_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 22.2%, transparent 22.2%);
# }
# #T_7bedc_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 19.1%, transparent 19.1%);
# }
# #T_7bedc_row15_col1, #T_7bedc_row16_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_7bedc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bedc_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_7bedc_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bedc_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_7bedc_row0_col0" class="data row0 col0" >M16_3_N</td>
#       <td id="T_7bedc_row0_col1" class="data row0 col1" >0.178182</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_7bedc_row1_col0" class="data row1 col0" >M10_3_N</td>
#       <td id="T_7bedc_row1_col1" class="data row1 col1" >0.103143</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_7bedc_row2_col0" class="data row2 col0" >M11_3_N</td>
#       <td id="T_7bedc_row2_col1" class="data row2 col1" >0.076604</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_7bedc_row3_col0" class="data row3 col0" >M15_3_N</td>
#       <td id="T_7bedc_row3_col1" class="data row3 col1" >0.075756</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_7bedc_row4_col0" class="data row4 col0" >M09_3_N</td>
#       <td id="T_7bedc_row4_col1" class="data row4 col1" >0.062519</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_7bedc_row5_col0" class="data row5 col0" >M02_3_N</td>
#       <td id="T_7bedc_row5_col1" class="data row5 col1" >0.061700</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row6" class="row_heading level0 row6" >13</th>
#       <td id="T_7bedc_row6_col0" class="data row6 col0" >M14_3_N</td>
#       <td id="T_7bedc_row6_col1" class="data row6 col1" >0.059129</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_7bedc_row7_col0" class="data row7 col0" >M06_3_N</td>
#       <td id="T_7bedc_row7_col1" class="data row7 col1" >0.058025</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row8" class="row_heading level0 row8" >2</th>
#       <td id="T_7bedc_row8_col0" class="data row8 col0" >M03_3_N</td>
#       <td id="T_7bedc_row8_col1" class="data row8 col1" >0.054463</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row9" class="row_heading level0 row9" >0</th>
#       <td id="T_7bedc_row9_col0" class="data row9 col0" >M01_3_N</td>
#       <td id="T_7bedc_row9_col1" class="data row9 col1" >0.053871</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row10" class="row_heading level0 row10" >6</th>
#       <td id="T_7bedc_row10_col0" class="data row10 col0" >M07_3_N</td>
#       <td id="T_7bedc_row10_col1" class="data row10 col1" >0.050477</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row11" class="row_heading level0 row11" >7</th>
#       <td id="T_7bedc_row11_col0" class="data row11 col0" >M08_3_N</td>
#       <td id="T_7bedc_row11_col1" class="data row11 col1" >0.048299</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row12" class="row_heading level0 row12" >3</th>
#       <td id="T_7bedc_row12_col0" class="data row12 col0" >M04_3_N</td>
#       <td id="T_7bedc_row12_col1" class="data row12 col1" >0.044298</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_7bedc_row13_col0" class="data row13 col0" >M17_3_N</td>
#       <td id="T_7bedc_row13_col1" class="data row13 col1" >0.039569</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row14" class="row_heading level0 row14" >4</th>
#       <td id="T_7bedc_row14_col0" class="data row14 col0" >M05_3_N</td>
#       <td id="T_7bedc_row14_col1" class="data row14 col1" >0.033965</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row15" class="row_heading level0 row15" >11</th>
#       <td id="T_7bedc_row15_col0" class="data row15 col0" >M12_3_N</td>
#       <td id="T_7bedc_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7bedc_level0_row16" class="row_heading level0 row16" >12</th>
#       <td id="T_7bedc_row16_col0" class="data row16 col0" >M13_3_N</td>
#       <td id="T_7bedc_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Shap Global explainations
import shap
explainer3 = shap.Explainer(models_3['model'], models_3['x_train'])
shap_values3 = explainer3(models_3['x_test'])

plt.title('Shap Feature Importance (sem3)', fontsize=16)
shap.plots.bar(shap_values3)

# %%
shap.plots.violin(shap_values3, show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values3, link='logit')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iSEO3NW4ZU4HB1XOUB690'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 2.1748209221401886, "link": "logit", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "explanations": [{"outValue": -1.325738905163325, "simIndex": 21.0, "features": {"0": {"effect": 0.1303497971408069, "value": 2.3}, "1": {"effect": -0.9128125399164856, "value": 1.7}, "2": {"effect": 0.3467459952551872, "value": 5.1}, "3": {"effect": 0.10296287214849144, "value": 1.0}, "4": {"effect": 0.3419363588327542, "value": 5.1}, "5": {"effect": 0.19736889631021767, "value": 5.1}, "6": {"effect": -0.003873665630817413, "value": 5.1}, "7": {"effect": -0.010008952948264777, "value": 5.1}, "8": {"effect": -0.10753524540923536, "value": 5.1}, "9": {"effect": -1.9730015712976456, "value": 1.0}, "10": {"effect": 0.6161919308826327, "value": 1.0}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": -0.11885626004077494, "value": 5.1}, "14": {"effect": 0.07842398416250944, "value": 5.1}, "15": {"effect": -2.2116341699846087, "value": 1.3}, "16": {"effect": 0.023182743191719056, "value": 5.1}}}, {"outValue": -2.4435731888239562, "simIndex": 20.0, "features": {"0": {"effect": 0.1796691463701427, "value": 2.3}, "1": {"effect": -0.9030605229921639, "value": 3.3}, "2": {"effect": 0.22365132716484368, "value": 1.3}, "3": {"effect": 0.395737534398213, "value": 3.3}, "4": {"effect": -0.18638476776657625, "value": 2.0}, "5": {"effect": -0.7235987280076369, "value": 3.3}, "6": {"effect": 0.05893033741973341, "value": 5.1}, "7": {"effect": -0.07961849781218916, "value": 5.1}, "8": {"effect": 0.8533331369888038, "value": 3.3}, "9": {"effect": -1.6813594415225088, "value": 3.3}, "10": {"effect": -0.20107662744820118, "value": 5.0}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect": -0.2412542309705168, "value": 5.1}, "14": {"effect": 0.05415744408033788, "value": 5.1}, "15": {"effect": -2.392526215929538, "value": 1.7}, "16": {"effect": 0.025005995063111186, "value": 5.1}}}, {"outValue": -4.244031574214186, "simIndex": 27.0, "features": {"0": {"effect": 0.17271409454755485, "value": 2.7}, "1": {"effect": -0.2308180483058095, "value": 4.0}, "2": {"effect": -0.18704551039496436, "value": 1.7}, "3": {"effect": -0.07407336491625756, "value": 2.0}, "4": {"effect": 0.11748011993709952, "value": 5.1}, "5": {"effect": -0.4856962695810944, "value": 3.3}, "6": {"effect": -0.0013233315385878085, "value": 5.1}, "7": {"effect": -0.04965894822962582, "value": 5.1}, "8": {"effect": -1.3823699024692178, "value": 1.7}, "9": {"effect": -1.5338812802731991, "value": 3.7}, "10": {"effect": -0.1369959346577525, "value": 5.0}, "11": {"effect": 0.0, "value": 5.1}, "12": {"effect": 0.0, "value": 5.1}, "13": {"effect