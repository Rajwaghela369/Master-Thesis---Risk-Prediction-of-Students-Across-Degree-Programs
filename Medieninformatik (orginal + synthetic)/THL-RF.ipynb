# %%
from functions import *
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import shap
from sklearn.model_selection import train_test_split
from collections import Counter

# %% [markdown]
# ## Data Preprocessing

# %%
path_1 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL1_merged.csv"
path_2 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL2_merged.csv"
path_3 = "/Users/rajwaghela/Library/CloudStorage/GoogleDrive-rajwaghela4244@gmail.com/My Drive/Thesis/Practical/Data/Processed Data/Merged/THL3_merged.csv"

THL_1 = pd.read_csv(path_1, sep=',')
THL_2 = pd.read_csv(path_2, sep=',')
THL_3 = pd.read_csv(path_3, sep=',')

# %%
## set modules
module1 = ['M01_1_N', 'M02_1_N', 'M03_1_N', 'M04_1_N', 'M05_1_N', 'M06_1_N']

module2 = [
            'M01_2_N', 'M02_2_N', 'M03_2_N', 'M04_2_N', 'M05_2_N', 'M06_2_N',
            'M07_2_N', 'M08_2_N', 'M09_2_N', 'M10_2_N', 'M11_2_N', 'M12_2_N',]

module3 = ['M01_3_N', 'M02_3_N', 'M03_3_N', 'M04_3_N', 'M05_3_N', 'M06_3_N',
            'M07_3_N', 'M08_3_N', 'M09_3_N', 'M10_3_N', 'M11_3_N', 'M12_3_N',
            'M13_3_N', 'M14_3_N', 'M15_3_N', 'M16_3_N', 'M17_3_N']

# %% [markdown]
# ### Search Space / Param Grid

# %%
'''from hyperopt import *
search_space = {
    'n_estimators': hp.choice('n_estimators', np.arange(5, 50, 5)),  # Smaller number of trees for small datasets
    'max_depth': hp.choice('max_depth', np.arange(3, 20, 1)),  # Limit depth to prevent overfitting
    'max_features': hp.choice('max_features', ['sqrt', 'log2']),  # Control the number of features considered
    'min_samples_split': hp.uniform('min_samples_split', 0.05, 1),  # Increase to avoid splitting on very small samples
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.05, 1),  # Ensure min_samples_leaf is an integer
    'bootstrap': hp.choice('bootstrap', [True]),  # Set bootstrap to True to avoid overfitting
    'criterion': hp.choice('criterion', ['gini', 'entropy']),  # Criterion for splitting nodes
    'oob_score': hp.choice('oob_score', [True, False]),  # Out-of-bag samples estimation for validation
    'class_weight': 'balanced',
    'ccp_alpha': hp.loguniform('ccp_alpha', -7,0)
}'''
# Out:
# "from hyperopt import *\nsearch_space = {\n    'n_estimators': hp.choice('n_estimators', np.arange(5, 50, 5)),  # Smaller number of trees for small datasets\n    'max_depth': hp.choice('max_depth', np.arange(3, 20, 1)),  # Limit depth to prevent overfitting\n    'max_features': hp.choice('max_features', ['sqrt', 'log2']),  # Control the number of features considered\n    'min_samples_split': hp.uniform('min_samples_split', 0.05, 1),  # Increase to avoid splitting on very small samples\n    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.05, 1),  # Ensure min_samples_leaf is an integer\n    'bootstrap': hp.choice('bootstrap', [True]),  # Set bootstrap to True to avoid overfitting\n    'criterion': hp.choice('criterion', ['gini', 'entropy']),  # Criterion for splitting nodes\n    'oob_score': hp.choice('oob_score', [True, False]),  # Out-of-bag samples estimation for validation\n    'class_weight': 'balanced',\n    'ccp_alpha': hp.loguniform('ccp_alpha', -7,0)\n}"

# %%
from hyperopt import *
search_space = {
    'n_estimators': hp.choice('n_estimators', np.arange(5, 20, 2)),  # Smaller number of trees for small datasets
    'max_depth': hp.choice('max_depth', np.arange(4, 10)),  # Limit depth to prevent overfitting
    'max_features': hp.choice('max_features', [None]),  # Control the number of features considered
    'bootstrap': hp.choice('bootstrap', [True]),  # Set bootstrap to True to avoid overfitting
    'criterion': hp.choice('criterion', ['entropy']),  # Criterion for splitting node    
    'min_impurity_decrease': hp.uniform('min_impurity_decrease', 0.001, 0.03),
    'ccp_alpha': hp.uniform('ccp_alpha', 0.05, 0.13),
    'oob_score': hp.choice('oob_score', [True]),  # Out-of-bag samples estimation for validation
    'class_weight': 'balanced',
}

# %% [markdown]
# ## THL semester 1

# %%
# Count occurrences of each unique value in the 'status' column
counter_1 = Counter(THL_1['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_1[1]} | 0: {counter_1[0]}')
hpo = ModelTrainer(random_state=42)
x, y = hpo.split_data(THL_1, module1)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 502 | 0: 118

# %%
models_1, feature_importance1 = hpo.cross_validation_hpo(
    x=x, y=y,
    search_space=search_space, 
    algo='rf'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 15.06trial/s, best loss: -0.7687954840805717]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            18               05
# 	 actual 1            39               62
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.05791765853496598, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.005412958114539285, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 7, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 69.82350%
# Validation accuracy.: 64.51613%
# Sensitivity score (for 1): 61.38614%
# Specificity score (for 0): 78.26087%
# F1 score.: 73.80952%
# False prediction: 35.48387%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 13.69trial/s, best loss: -0.7050373619233269]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            21               02
# 	 actual 1            24               77
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.07256409144390362, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.015705294121176435, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 13, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 83.77099%
# Validation accuracy.: 79.03226%
# Sensitivity score (for 1): 76.23762%
# Specificity score (for 0): 91.30435%
# F1 score.: 85.55556%
# False prediction: 20.96774%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.28trial/s, best loss: -0.7520849577647823]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            20               04
# 	 actual 1            26               74
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.074580441700541, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.015367409568737521, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 5, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 78.66667%
# Validation accuracy.: 75.80645%
# Sensitivity score (for 1): 74.00000%
# Specificity score (for 0): 83.33333%
# F1 score.: 83.14607%
# False prediction: 24.19355%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.58trial/s, best loss: -0.7490090968161144]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            20               04
# 	 actual 1            36               64
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.08131473440657772, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.019692160284343035, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 19, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 73.66667%
# Validation accuracy.: 67.74194%
# Sensitivity score (for 1): 64.00000%
# Specificity score (for 0): 83.33333%
# F1 score.: 76.19048%
# False prediction: 32.25806%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.96trial/s, best loss: -0.7827834632878492]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            17               07
# 	 actual 1            33               67
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.07903271751667809, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.010735199240296495, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 5, 'n_jobs': None, 'oob_score': True, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 68.91667%
# Validation accuracy.: 67.74194%
# Sensitivity score (for 1): 67.00000%
# Specificity score (for 0): 70.83333%
# F1 score.: 77.01149%
# False prediction: 32.25806%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 74.96890%
# Standard Deviation of Balanced Accuracy: +/- 5.585
#
# Mean Accuracy: 70.96774%
# Standard Deviation of Accuracy: +/- 5.493
#
# Mean Sensitivity: 68.52475%
# Standard Deviation of Sensitivity: +/- 5.714
#
# Mean Specificity: 81.41304%
# Standard Deviation of Specificity: +/- 6.739
#
# Mean False Predictions: 29.03226%
# Standard Deviation of False Predictions: +/- 5.493
#
# best model is from 2 fold: RandomForestClassifier(ccp_alpha=0.07256409144390362, class_weight='balanced',
#                        criterion='entropy', max_depth=9, max_features=None,
#                        min_impurity_decrease=0.015705294121176435,
#                        n_estimators=13, oob_score=True, random_state=42)

# %%
feature_importance1
# Out:
# <style type="text/css">
# #T_2877c_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_2877c_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 94.8%, transparent 94.8%);
# }
# #T_2877c_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 70.9%, transparent 70.9%);
# }
# #T_2877c_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 42.8%, transparent 42.8%);
# }
# #T_2877c_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 20.4%, transparent 20.4%);
# }
# #T_2877c_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 9.9%, transparent 9.9%);
# }
# </style>
# <table id="T_2877c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2877c_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_2877c_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2877c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2877c_row0_col0" class="data row0 col0" >M01_1_N</td>
#       <td id="T_2877c_row0_col1" class="data row0 col1" >0.295098</td>
#     </tr>
#     <tr>
#       <th id="T_2877c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2877c_row1_col0" class="data row1 col0" >M02_1_N</td>
#       <td id="T_2877c_row1_col1" class="data row1 col1" >0.279724</td>
#     </tr>
#     <tr>
#       <th id="T_2877c_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_2877c_row2_col0" class="data row2 col0" >M05_1_N</td>
#       <td id="T_2877c_row2_col1" class="data row2 col1" >0.209212</td>
#     </tr>
#     <tr>
#       <th id="T_2877c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2877c_row3_col0" class="data row3 col0" >M04_1_N</td>
#       <td id="T_2877c_row3_col1" class="data row3 col1" >0.126272</td>
#     </tr>
#     <tr>
#       <th id="T_2877c_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_2877c_row4_col0" class="data row4 col0" >M03_1_N</td>
#       <td id="T_2877c_row4_col1" class="data row4 col1" >0.060333</td>
#     </tr>
#     <tr>
#       <th id="T_2877c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2877c_row5_col0" class="data row5 col0" >M06_1_N</td>
#       <td id="T_2877c_row5_col1" class="data row5 col1" >0.029361</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Shap analysis

# %%
## Shap Global explainations
import shap
explainer = shap.TreeExplainer(models_1['model'], models_1['x_train'])
shap_values = explainer(models_1['x_test'])

plt.title('Shap Feature Importance (sem1)', fontsize=16)
shap.plots.bar(shap_values[...,1])

# %%
shap.plots.violin(shap_values[...,1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_values[...,1], link='identity')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iXK8YWL7UTNMVFJJHAU2F'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6303416933933155, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "explanations": [{"outValue": 0.8680434320842729, "simIndex": 71.0, "features": {"0": {"effect": 0.06962401846423745, "value": 5.1}, "1": {"effect": 0.0660792651027441, "value": 5.1}, "2": {"effect": 0.019827236123383045, "value": 5.1}, "3": {"effect": 0.02106115870177746, "value": 5.1}, "4": {"effect": 0.055779886776581404, "value": 5.1}, "5": {"effect": 0.005330173522233963, "value": 5.1}}}, {"outValue": 0.8680434320842729, "simIndex": 72.0, "features": {"0": {"effect": 0.06962401846423745, "value": 5.1}, "1": {"effect": 0.0660792651027441, "value": 5.1}, "2": {"effect": 0.019827236123383045, "value": 5.1}, "3": {"effect": 0.02106115870177746, "value": 5.1}, "4": {"effect": 0.055779886776581404, "value": 5.1}, "5": {"effect": 0.005330173522233963, "value": 5.1}}}, {"outValue": 0.8680434320842729, "simIndex": 73.0, "features": {"0": {"effect": 0.06962401846423745, "value": 5.1}, "1": {"effect": 0.0660792651027441, "value": 5.1}, "2": {"effect": 0.019827236123383045, "value": 5.1}, "3": {"effect": 0.02106115870177746, "value": 5.1}, "4": {"effect": 0.055779886776581404, "value": 5.1}, "5": {"effect": 0.005330173522233963, "value": 5.1}}}, {"outValue": 0.3312598061630384
"value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i53MV5HB50PRPOWRIZH0A')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=14, link='identity', model_name='rf')
# Out:
# Student index 14 grades:
#          grades
# M01_1_N     5.0
# M02_1_N     5.1
# M03_1_N     2.0
# M04_1_N     5.1
# M05_1_N     2.3
# M06_1_N     5.0
# Status: 1, Prediction: [0], Probability [0]: 0.571, Probability [1]: 0.429
# <div id='iA5KWY2VL8BR7UN2OENHB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6303416933933155, "outValue": 0.4290404471730695, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": -0.07498204252216965, "value": 5.0}, "1": {"effect": 0.03270759149454534, "value": 5.1}, "2": {"effect": -0.04602773269638419, "value": 2.0}, "3": {"effect": 0.0173063050955534, "value": 5.1}, "4": {"effect": -0.09955436650197953, "value": 2.3}, "5": {"effect": -0.030751001089811325, "value": 5.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iA5KWY2VL8BR7UN2OENHB')
#   );
# </script>

# %%
hpo.plot_shap_force(model=models_1, 
           shap_values=shap_values, 
           student_index=4, link='identity', model_name='rf')
# Out:
# Student index 4 grades:
#          grades
# M01_1_N     3.0
# M02_1_N     3.3
# M03_1_N     2.7
# M04_1_N     5.0
# M05_1_N     1.3
# M06_1_N     2.0
# Status: 0, Prediction: [0], Probability [0]: 0.777, Probability [1]: 0.223
# <div id='iXA3Z5RGNT27BU88FK39K'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6303416933933155, "outValue": 0.22321078760306107, "link": "identity", "featureNames": ["M01_1_N", "M02_1_N", "M03_1_N", "M04_1_N", "M05_1_N", "M06_1_N"], "features": {"0": {"effect": -0.11813965356908739, "value": 3.0}, "1": {"effect": -0.10756232627667486, "value": 3.3}, "2": {"effect": -0.027023555943742394, "value": 2.7}, "3": {"effect": -0.06736881664954125, "value": 5.0}, "4": {"effect": -0.07330110619775951, "value": 1.3}, "5": {"effect": -0.013735447153449059, "value": 2.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iXA3Z5RGNT27BU88FK39K')
#   );
# </script>

# %% [markdown]
# ## THL semester 2

# %%
# Count occurrences of each unique value in the 'status' column
counter_2 = Counter(THL_2['status'])
print(f'Quantity of Drop Out and Degree in THL-2: \n 1: {counter_2[1]} | 0: {counter_2[0]}')
hpo2 = ModelTrainer(random_state=72)
x2, y2 = hpo2.split_data(THL_2, module2)
# Out:
# Quantity of Drop Out and Degree in THL-2:
#  1: 315 | 0: 88

# %%
models_2, feature_importance2 = hpo2.cross_validation_hpo(
    x=x2, y=y2,
    search_space=search_space, 
    algo='rf'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.68trial/s, best loss: -0.7889299719887954]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            12               06
# 	 actual 1            21               42
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.10905574697833131, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 8, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.014707500942109913, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 15, 'n_jobs': None, 'oob_score': True, 'random_state': 72, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 66.66667%
# Validation accuracy.: 66.66667%
# Sensitivity score (for 1): 66.66667%
# Specificity score (for 0): 66.66667%
# F1 score.: 75.67568%
# False prediction: 33.33333%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 11.93trial/s, best loss: -0.7542408963585434]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            14               04
# 	 actual 1            20               43
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.08442206822150711, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 6, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.026663854472336993, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 17, 'n_jobs': None, 'oob_score': True, 'random_state': 72, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 73.01587%
# Validation accuracy.: 70.37037%
# Sensitivity score (for 1): 68.25397%
# Specificity score (for 0): 77.77778%
# F1 score.: 78.18182%
# False prediction: 29.62963%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.67trial/s, best loss: -0.8025378151260505]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            15               03
# 	 actual 1            25               38
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.10121944853063214, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.011166944459287065, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 7, 'n_jobs': None, 'oob_score': True, 'random_state': 72, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 71.82540%
# Validation accuracy.: 65.43210%
# Sensitivity score (for 1): 60.31746%
# Specificity score (for 0): 83.33333%
# F1 score.: 73.07692%
# False prediction: 34.56790%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.83trial/s, best loss: -0.7504257703081232]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            22               41
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.06770996746789457, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.01624240118569942, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 17, 'n_jobs': None, 'oob_score': True, 'random_state': 72, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 64.89262%
# Validation accuracy.: 65.00000%
# Sensitivity score (for 1): 65.07937%
# Specificity score (for 0): 64.70588%
# F1 score.: 74.54545%
# False prediction: 35.00000%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.31trial/s, best loss: -0.7502128851540617]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            13               04
# 	 actual 1            15               48
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.06545252579949527, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.02067017568677965, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 7, 'n_jobs': None, 'oob_score': True, 'random_state': 72, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 76.33053%
# Validation accuracy.: 76.25000%
# Sensitivity score (for 1): 76.19048%
# Specificity score (for 0): 76.47059%
# F1 score.: 83.47826%
# False prediction: 23.75000%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 70.54622%
# Standard Deviation of Balanced Accuracy: +/- 4.200
#
# Mean Accuracy: 68.74383%
# Standard Deviation of Accuracy: +/- 4.202
#
# Mean Sensitivity: 67.30159%
# Standard Deviation of Sensitivity: +/- 5.178
#
# Mean Specificity: 73.79085%
# Standard Deviation of Specificity: +/- 7.035
#
# Mean False Predictions: 31.25617%
# Standard Deviation of False Predictions: +/- 4.202
#
# best model is from 5 fold: RandomForestClassifier(ccp_alpha=0.06545252579949527, class_weight='balanced',
#                        criterion='entropy', max_depth=7, max_features=None,
#                        min_impurity_decrease=0.02067017568677965,
#                        n_estimators=7, oob_score=True, random_state=72)

# %%
feature_importance2
# Out:
# <style type="text/css">
# #T_fd5c7_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_fd5c7_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 96.1%, transparent 96.1%);
# }
# #T_fd5c7_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 65.5%, transparent 65.5%);
# }
# #T_fd5c7_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 26.0%, transparent 26.0%);
# }
# #T_fd5c7_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 11.4%, transparent 11.4%);
# }
# #T_fd5c7_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 9.0%, transparent 9.0%);
# }
# #T_fd5c7_row6_col1, #T_fd5c7_row7_col1, #T_fd5c7_row8_col1, #T_fd5c7_row9_col1, #T_fd5c7_row10_col1, #T_fd5c7_row11_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_fd5c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd5c7_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_fd5c7_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd5c7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fd5c7_row0_col0" class="data row0 col0" >M02_2_N</td>
#       <td id="T_fd5c7_row0_col1" class="data row0 col1" >0.324622</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_fd5c7_row1_col0" class="data row1 col0" >M01_2_N</td>
#       <td id="T_fd5c7_row1_col1" class="data row1 col1" >0.311931</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_fd5c7_row2_col0" class="data row2 col0" >M05_2_N</td>
#       <td id="T_fd5c7_row2_col1" class="data row2 col1" >0.212781</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_fd5c7_row3_col0" class="data row3 col0" >M03_2_N</td>
#       <td id="T_fd5c7_row3_col1" class="data row3 col1" >0.084540</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_fd5c7_row4_col0" class="data row4 col0" >M10_2_N</td>
#       <td id="T_fd5c7_row4_col1" class="data row4 col1" >0.036910</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_fd5c7_row5_col0" class="data row5 col0" >M04_2_N</td>
#       <td id="T_fd5c7_row5_col1" class="data row5 col1" >0.029216</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_fd5c7_row6_col0" class="data row6 col0" >M06_2_N</td>
#       <td id="T_fd5c7_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd5c7_level0_
, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.983400705317186, "simIndex": 74.0, "features": {"0": {"effect": 0.11494526047259569, "value": 5.1}, "1": {"effect": 0.09569834217429161, "value": 5.1}, "2": {"effect": 0.0019496635347604752, "value": 2.7}, "3": {"effect": 0.0046612447500228886, "value": 5.1}, "4": {"effect": 0.08746181894093752, "value": 5.1}, "5": {"effect": 0.0, "value": 5.1}, "6": {"effect": 0.0, "value": 5.1}, "7": {"effect": 0.0, "value": 1.3}, "8": {"effect": 0.0, "value": 2.7}, "9": {"effect": 0.009967599511146546, "value": 5.1}, "10": {"effect": 0.0, "value": 5.1}, "11": {"effect": 0.0, "value": 5.1}}}, {"outValue": 0.9834007051309215, "simIndex": 60.0, "features": {"0": {"effect": 0.11 ...

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=16, link='identity', model_name='rf')
# Out:
# Student index 16 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.017, Probability [1]: 0.983
# <div id='i87FBAKKZ6N5O13IU7NQC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6687167759334313, "outValue": 0.9834007051309215, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.11494526047259569, "value": 5.1}, "1": {"effect": 0.09569834217429161, "value": 5.1}, "2": {"effect": 0.013549631163477897, "value": 5.1}, "3": {"effect": 0.0046612447500228886, "value": 5.1}, "4": {"effect": 0.07586185112595559, "value": 5.1}, "9": {"effect": 0.009967599511146546, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i87FBAKKZ6N5O13IU7NQC')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=11, link='identity', model_name='rf')
# Out:
# Student index 11 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.017, Probability [1]: 0.983
# <div id='iV5MLMX3O6D8M3T2DBW6T'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6687167759334313, "outValue": 0.9834007051309215, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.11494526047259569, "value": 5.1}, "1": {"effect": 0.09569834217429161, "value": 5.1}, "2": {"effect": 0.013549631163477897, "value": 5.1}, "3": {"effect": 0.0046612447500228886, "value": 5.1}, "4": {"effect": 0.07586185112595559, "value": 5.1}, "9": {"effect": 0.009967599511146546, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iV5MLMX3O6D8M3T2DBW6T')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=12, link='identity', model_name='rf')
# Out:
# Student index 12 grades:
#          grades
# M01_2_N     3.0
# M02_2_N     2.3
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     2.7
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [0], Probability [0]: 0.632, Probability [1]: 0.368
# <div id='iMWBO904ELLTPDO6OJJ4C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6687167759334313, "outValue": 0.3677821438109147, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": -0.16548109497874974, "value": 3.0}, "1": {"effect": -0.17360379949212074, "value": 2.3}, "2": {"effect": 0.005691558644175529, "value": 5.1}, "3": {"effect": 0.01165311187505722, "value": 5.1}, "4": {"effect": 0.019559641890227793, "value": 5.1}, "9": {"effect": 0.0012459499388933182, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMWBO904ELLTPDO6OJJ4C')
#   );
# </script>

# %%
hpo2.plot_shap_force(model=models_2, 
           shap_values=shap_values2, 
           student_index=26, link='identity', model_name='rf')
# Out:
# Student index 26 grades:
#          grades
# M01_2_N     5.1
# M02_2_N     5.1
# M03_2_N     5.1
# M04_2_N     5.1
# M05_2_N     5.1
# M06_2_N     5.1
# M07_2_N     5.1
# M08_2_N     5.1
# M09_2_N     5.1
# M10_2_N     5.1
# M11_2_N     5.1
# M12_2_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.017, Probability [1]: 0.983
# <div id='iLXZR4UZ7MQ7ZZGO8DWMB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6687167759334313, "outValue": 0.9834007051309215, "link": "identity", "featureNames": ["M01_2_N", "M02_2_N", "M03_2_N", "M04_2_N", "M05_2_N", "M06_2_N", "M07_2_N", "M08_2_N", "M09_2_N", "M10_2_N", "M11_2_N", "M12_2_N"], "features": {"0": {"effect": 0.11494526047259569, "value": 5.1}, "1": {"effect": 0.09569834217429161, "value": 5.1}, "2": {"effect": 0.013549631163477897, "value": 5.1}, "3": {"effect": 0.0046612447500228886, "value": 5.1}, "4": {"effect": 0.07586185112595559, "value": 5.1}, "9": {"effect": 0.009967599511146546, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iLXZR4UZ7MQ7ZZGO8DWMB')
#   );
# </script>

# %% [markdown]
# ## THL semester 3

# %%
# Count occurrences of each unique value in the 'status' column
counter_3 = Counter(THL_3['status'])
print(f'Quantity of Drop Out and Degree in THL-1: \n 1: {counter_3[1]} | 0: {counter_3[0]}')
hpo3 = ModelTrainer(random_state=55)
x3, y3 = hpo3.split_data(THL_3, module3)
# Out:
# Quantity of Drop Out and Degree in THL-1:
#  1: 203 | 0: 85

# %%
models_3, feature_importance3 = hpo3.cross_validation_hpo(
    x=x3, y=y3,
    search_space=search_space, 
    algo='rf'
    )
# Out:
# ------------------------------------- Fold 1 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.64trial/s, best loss: -0.7888954795204797]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            09               32
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.06696377179029167, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.02800367858828013, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 11, 'n_jobs': None, 'oob_score': True, 'random_state': 55, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 71.37733%
# Validation accuracy.: 74.13793%
# Sensitivity score (for 1): 78.04878%
# Specificity score (for 0): 64.70588%
# F1 score.: 81.01266%
# False prediction: 25.86207%
#
# ------------------------------------- Fold 2 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 11.47trial/s, best loss: -0.8151317432567433]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            11               06
# 	 actual 1            09               32
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.12941739562221816, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 7, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.02261643321299887, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 17, 'n_jobs': None, 'oob_score': True, 'random_state': 55, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 71.37733%
# Validation accuracy.: 74.13793%
# Sensitivity score (for 1): 78.04878%
# Specificity score (for 0): 64.70588%
# F1 score.: 81.01266%
# False prediction: 25.86207%
#
# ------------------------------------- Fold 3 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.67trial/s, best loss: -0.7912816350316352]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            16               01
# 	 actual 1            10               31
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.1063056230618247, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.004191075546861061, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 7, 'n_jobs': None, 'oob_score': True, 'random_state': 55, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 84.86370%
# Validation accuracy.: 81.03448%
# Sensitivity score (for 1): 75.60976%
# Specificity score (for 0): 94.11765%
# F1 score.: 84.93151%
# False prediction: 18.96552%
#
# ------------------------------------- Fold 4 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 12.79trial/s, best loss: -0.8058275058275057]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            14               03
# 	 actual 1            14               26
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.0814570570584946, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.014013448554234444, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 9, 'n_jobs': None, 'oob_score': True, 'random_state': 55, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 73.67647%
# Validation accuracy.: 70.17544%
# Sensitivity score (for 1): 65.00000%
# Specificity score (for 0): 82.35294%
# F1 score.: 75.36232%
# False prediction: 29.82456%
#
# ------------------------------------- Fold 5 --------------------------------------------------
# 100%|██████████| 10/10 [00:00<00:00, 14.37trial/s, best loss: -0.8068660506160505]
#
# Confusion Matrix
# 	                 predicted 0     predicted 1
# 	 actual 0            15               02
# 	 actual 1            15               25
#
# Model parameters:
# {'bootstrap': True, 'ccp_alpha': 0.10315008756698169, 'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.003386173014883997, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 15, 'n_jobs': None, 'oob_score': True, 'random_state': 55, 'verbose': 0, 'warm_start': False}
#
# Balanced acc.: 75.36765%
# Validation accuracy.: 70.17544%
# Sensitivity score (for 1): 62.50000%
# Specificity score (for 0): 88.23529%
# F1 score.: 74.62687%
# False prediction: 29.82456%
#
# ====================== Summary ======================
# Mean Balanced Accuracy: 75.33250%
# Standard Deviation of Balanced Accuracy: +/- 4.997
#
# Mean Accuracy: 73.93224%
# Standard Deviation of Accuracy: +/- 3.969
#
# Mean Sensitivity: 71.84146%
# Standard Deviation of Sensitivity: +/- 6.713
#
# Mean Specificity: 78.82353%
# Standard Deviation of Specificity: +/- 12.113
#
# Mean False Predictions: 26.06776%
# Standard Deviation of False Predictions: +/- 3.969
#
# best model is from 3 fold: RandomForestClassifier(ccp_alpha=0.1063056230618247, class_weight='balanced',
#                        criterion='entropy', max_depth=5, max_features=None,
#                        min_impurity_decrease=0.004191075546861061,
#                        n_estimators=7, oob_score=True, random_state=55)

# %%
feature_importance3
# Out:
# <style type="text/css">
# #T_ace07_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_ace07_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 57.2%, transparent 57.2%);
# }
# #T_ace07_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.4%, transparent 21.4%);
# }
# #T_ace07_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 21.3%, transparent 21.3%);
# }
# #T_ace07_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 14.7%, transparent 14.7%);
# }
# #T_ace07_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 12.9%, transparent 12.9%);
# }
# #T_ace07_row6_col1, #T_ace07_row7_col1, #T_ace07_row8_col1, #T_ace07_row9_col1, #T_ace07_row10_col1, #T_ace07_row11_col1, #T_ace07_row12_col1, #T_ace07_row13_col1, #T_ace07_row14_col1, #T_ace07_row15_col1, #T_ace07_row16_col1 {
#   width: 10em;
# }
# </style>
# <table id="T_ace07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ace07_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_ace07_level0_col1" class="col_heading level0 col1" >Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ace07_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_ace07_row0_col0" class="data row0 col0" >M16_3_N</td>
#       <td id="T_ace07_row0_col1" class="data row0 col1" >0.439589</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_ace07_row1_col0" class="data row1 col0" >M11_3_N</td>
#       <td id="T_ace07_row1_col1" class="data row1 col1" >0.251600</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_ace07_row2_col0" class="data row2 col0" >M02_3_N</td>
#       <td id="T_ace07_row2_col1" class="data row2 col1" >0.093958</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_ace07_row3_col0" class="data row3 col0" >M10_3_N</td>
#       <td id="T_ace07_row3_col1" class="data row3 col1" >0.093799</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ace07_row4_col0" class="data row4 col0" >M06_3_N</td>
#       <td id="T_ace07_row4_col1" class="data row4 col1" >0.064519</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_ace07_row5_col0" class="data row5 col0" >M09_3_N</td>
#       <td id="T_ace07_row5_col1" class="data row5 col1" >0.056535</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row6" class="row_heading level0 row6" >14</th>
#       <td id="T_ace07_row6_col0" class="data row6 col0" >M15_3_N</td>
#       <td id="T_ace07_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_ace07_row7_col0" class="data row7 col0" >M14_3_N</td>
#       <td id="T_ace07_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_ace07_row8_col0" class="data row8 col0" >M13_3_N</td>
#       <td id="T_ace07_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_ace07_row9_col0" class="data row9 col0" >M12_3_N</td>
#       <td id="T_ace07_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row10" class="row_heading level0 row10" >0</th>
#       <td id="T_ace07_row10_col0" class="data row10 col0" >M01_3_N</td>
#       <td id="T_ace07_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row11" class="row_heading level0 row11" >7</th>
#       <td id="T_ace07_row11_col0" class="data row11 col0" >M08_3_N</td>
#       <td id="T_ace07_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row12" class="row_heading level0 row12" >6</th>
#       <td id="T_ace07_row12_col0" class="data row12 col0" >M07_3_N</td>
#       <td id="T_ace07_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row13" class="row_heading level0 row13" >4</th>
#       <td id="T_ace07_row13_col0" class="data row13 col0" >M05_3_N</td>
#       <td id="T_ace07_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row14" class="row_heading level0 row14" >3</th>
#       <td id="T_ace07_row14_col0" class="data row14 col0" >M04_3_N</td>
#       <td id="T_ace07_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row15" class="row_heading level0 row15" >2</th>
#       <td id="T_ace07_row15_col0" class="data row15 col0" >M03_3_N</td>
#       <td id="T_ace07_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ace07_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ace07_row16_col0" class="data row16 col0" >M17_3_N</td>
#       <td id="T_ace07_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
## Shap Global explainations
import shap
explainer3 = shap.TreeExplainer(models_3['model'], models_3['x_train'])
shap_values3 = explainer3(models_3['x_test'])

plt.title('Shap Feature Importance (sem3)', fontsize=16)
shap.plots.bar(shap_values3[..., 1])

# %%
shap.plots.violin(shap_values3[..., 1], show=True)

# %%
## Local explainations
shap.initjs()
shap.force_plot(shap_
# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=1, link='identity', model_name='rf')
# Out:
# Student index 1 grades:
#          grades
# M01_3_N     2.7
# M02_3_N     2.3
# M03_3_N     5.1
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     3.0
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     4.0
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 0, Prediction: [1], Probability [0]: 0.390, Probability [1]: 0.610
# <div id='iO784DI08UAUPRH9GT1RQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6029502993488972, "outValue": 0.6095075584428673, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": -0.07788517653942108, "value": 2.3}, "5": {"effect": -0.06132576316595077, "value": 3.0}, "8": {"effect": 0.01680245518684387, "value": 5.1}, "9": {"effect": -0.06787948608398438, "value": 4.0}, "10": {"effect": 0.06687894951552152, "value": 5.1}, "15": {"effect": 0.1299662801809609, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iO784DI08UAUPRH9GT1RQ')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=4, link='identity', model_name='rf')
# Out:
# Student index 4 grades:
#          grades
# M01_3_N     3.3
# M02_3_N     3.0
# M03_3_N     1.0
# M04_3_N     3.3
# M05_3_N     5.1
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     3.7
# M10_3_N     5.1
# M11_3_N     3.3
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     1.3
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.438, Probability [1]: 0.562
# <div id='i10KOTTO4PZXTVFHSLGMV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6029502993488972, "outValue": 0.5620150165485506, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": -0.030147526897490024, "value": 3.0}, "5": {"effect": 0.003942370489239693, "value": 5.1}, "8": {"effect": 0.005436088442802429, "value": 3.7}, "9": {"effect": 0.020636480450630188, "value": 5.1}, "10": {"effect": -0.1784331261739135, "value": 3.3}, "15": {"effect": 0.1376304308883846, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i10KOTTO4PZXTVFHSLGMV')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=5, link='identity', model_name='rf')
# Out:
# Student index 5 grades:
#          grades
# M01_3_N     5.1
# M02_3_N     5.1
# M03_3_N     2.7
# M04_3_N     5.1
# M05_3_N     5.1
# M06_3_N     5.1
# M07_3_N     5.1
# M08_3_N     5.1
# M09_3_N     5.1
# M10_3_N     5.1
# M11_3_N     5.1
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     5.1
# M15_3_N     5.1
# M16_3_N     5.1
# M17_3_N     5.1
# Status: 1, Prediction: [1], Probability [0]: 0.051, Probability [1]: 0.949
# <div id='i1I58RYFI4L90DJF7339T'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6029502993488972, "outValue": 0.9486731184313362, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": 0.03578958686441183, "value": 5.1}, "5": {"effect": 0.011827111467719078, "value": 5.1}, "8": {"effect": 0.01680245518684387, "value": 5.1}, "9": {"effect": 0.020636480450630188, "value": 5.1}, "10": {"effect": 0.08133430764079094, "value": 5.1}, "15": {"effect": 0.17933287747204305, "value": 5.1}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1I58RYFI4L90DJF7339T')
#   );
# </script>

# %%
hpo3.plot_shap_force(model=models_3, 
           shap_values=shap_values3, 
           student_index=6, link='identity', model_name='rf')
# Out:
# Student index 6 grades:
#          grades
# M01_3_N     2.3
# M02_3_N     1.0
# M03_3_N     1.7
# M04_3_N     2.0
# M05_3_N     1.7
# M06_3_N     1.3
# M07_3_N     1.0
# M08_3_N     1.3
# M09_3_N     1.7
# M10_3_N     2.3
# M11_3_N     4.0
# M12_3_N     5.1
# M13_3_N     5.1
# M14_3_N     1.0
# M15_3_N     5.1
# M16_3_N     1.3
# M17_3_N     1.0
# Status: 0, Prediction: [0], Probability [0]: 0.764, Probability [1]: 0.236
# <div id='iKM770HKZATENTLJBMXQY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6029502993488972, "outValue": 0.2357406730616753, "link": "identity", "featureNames": ["M01_3_N", "M02_3_N", "M03_3_N", "M04_3_N", "M05_3_N", "M06_3_N", "M07_3_N", "M08_3_N", "M09_3_N", "M10_3_N", "M11_3_N", "M12_3_N", "M13_3_N", "M14_3_N", "M15_3_N", "M16_3_N", "M17_3_N"], "features": {"1": {"effect": -0.03037679322063923, "value": 1.0}, "5": {"effect": -0.025406387597322465, "value": 1.3}, "8": {"effect": -0.028168821930885313, "value": 1.7}, "9": {"effect": -0.043500097393989565, "value": 2.3}, "10": {"effect": -0.08877647764980794, "value": 4.0}, "15": {"effect": -0.1509810484945774, "value": 1.3}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iKM770HKZATENTLJBMXQY')
#   );
# </script>
